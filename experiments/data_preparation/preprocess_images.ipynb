# %%
import os
from torchvision import transforms
from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt
os.chdir('../../scripts/')
from utils import preprocess_images
os.chdir('../experiments/data_preparation/')

# %% [markdown]
# ### Resize original training images to 224x224

# %%
data_dir = '../../data/images/train/'
target_dir = '../../data/images/train_224'

transform = transforms.Resize(size=(224, 224))

# %%
# preprocess_images(data_dir,
#                   transform,
#                   target_dir)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
image_path_list = list(Path(data_dir).glob("*.jpg"))
for image_path in image_path_list[:3]:
    img = Image.open(image_path)
    plt.subplot(1,2,1)
    plt.imshow(img)
    plt.title('Original')

    transformed_image_path = f'{target_dir}/{image_path.name}'
    transformed_img = Image.open(transformed_image_path)
    plt.subplot(1,2,2)
    plt.imshow(transformed_img)
    plt.title('Transformed')
    
    plt.show()
