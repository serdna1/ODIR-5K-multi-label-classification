# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/serdna1/ODIR-5K-multi-label-classification/blob/main/experiments/experiment_10/experiment_10.ipynb)

# %% [markdown]
# # Download GitHub repository and data
# The repo wont be downloading in my local machine, since i already have it there. It will if someone is running this notebook on their own machine, colab, ...

# %%
import os
import zipfile

# Unzip images (will only work after upload the file to colab working directory)
with zipfile.ZipFile('train_fov_cc_fov_512.zip', 'r') as zip_ref:
  print("Unzipping training images...")
  zip_ref.extractall(f'train_fov_cc_fov_512')
# !rm train_fov_cc_fov_512.zip

images_path = 'train_fov_cc_fov_512/'

# If the experiments folder doesnt exist im not in my local machine
if not os.path.exists('../../experiments'):
    # Clone project repository
    # !git clone https://github.com/serdna1/ODIR-5K-multi-label-classification.git

    # Move to the experiment folder
    # %cd ODIR-5K-multi-label-classification/experiments/experiment_10/
# Out:
# Unzipping training images...
# Cloning into 'ODIR-5K-multi-label-classification'...
# remote: Enumerating objects: 465, done.
# remote: Counting objects: 100% (220/220), done.
# remote: Compressing objects: 100% (139/139), done.
# remote: Total 465 (delta 111), reused 179 (delta 73), pack-reused 245
# Receiving objects: 100% (465/465), 82.00 MiB | 28.55 MiB/s, done.
# Resolving deltas: 100% (223/223), done.
# [Errno 2] No such file or directory: 'ODIR-5K-multi-label-classification/experiments/experiment_10/'
# /content

# %%
# !mkdir ODIR-5K-multi-label-classification/experiments/experiment_10/
# %cd ODIR-5K-multi-label-classification/experiments/experiment_10/
# Out:
# /content/ODIR-5K-multi-label-classification/experiments/experiment_10

# %%
# !pwd
# Out:
# /content/ODIR-5K-multi-label-classification/experiments/experiment_10

# %% [markdown]
# # Drop some special patients from the dataset
# The background of some images is quite different from the rest ones. Therefore they wont be used for training.

# %%
import matplotlib.pyplot as plt
from PIL import Image

images_path = '../../../train_fov_cc_fov_512/'

special_images = ['2174_right.jpg', '2175_left.jpg', '2176_left.jpg', '2177_left.jpg',
                  '2177_right.jpg', '2178_right.jpg', '2179_left.jpg', '2179_right.jpg',
                  '2180_left.jpg', '2180_right.jpg', '2181_left.jpg', '2181_right.jpg',
                  '2182_left.jpg', '2182_right.jpg', '2957_left.jpg', '2957_right.jpg']

# Show one of this special images
image_path = f'{images_path}/{special_images[7]}'
img = Image.open(image_path)
plt.imshow(img)
plt.axis(False)
plt.title('Example of special image')
# Out:
# Text(0.5, 1.0, 'Example of special image')

# %%
import pandas as pd

original_annotations_path = '../../data/annotations/annotations.xlsx'
annotations_path = 'data/annotations.xlsx'

odir_df = pd.read_excel(original_annotations_path)

patients_to_drop_df = odir_df[odir_df['Left-Fundus'].isin(special_images) | odir_df['Right-Fundus'].isin(special_images)]
patients_to_drop_df # This are all the patients with one ore more of this spetial images
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1634  2174           65      Female  2174_left.jpg  2174_right.jpg
# 1635  2175           63        Male  2175_left.jpg  2175_right.jpg
# 1636  2176           82      Female  2176_left.jpg  2176_right.jpg
# 1637  2177           87        Male  2177_left.jpg  2177_right.jpg
# 1638  2178           84        Male  2178_left.jpg  2178_right.jpg
# 1639  2179           70      Female  2179_left.jpg  2179_right.jpg
# 1640  2180           66      Female  2180_left.jpg  2180_right.jpg
# 1641  2181           79      Female  2181_left.jpg  2181_right.jpg
# 1642  2182           70        Male  2182_left.jpg  2182_right.jpg
# 2334  2957           62      Female  2957_left.jpg  2957_right.jpg
#
#      Left-Diagnostic Keywords Right-Diagnostic Keywords  N  D  G  C  A  H  M  \
# 1634            normal fundus                  cataract  0  0  0  1  0  0  0
# 1635                 cataract             normal fundus  0  0  0  1  0  0  0
# 1636                 cataract                  cataract  0  0  0  1  0  0  0
# 1637  normal fundus，lens dust                  cataract  0  0  0  1  0  0  0
# 1638                 cataract                  cataract  0  0  0  1  0  0  0
# 1639                 cataract                  cataract  0  0  0  1  0  0  0
# 1640                 cataract                  cataract  0  0  0  1  0  0  0
# 1641                 cataract                  cataract  0  0  0  1  0  0  0
# 1642                 cataract                  cataract  0  0  0  1  0  0  0
# 2334            normal fundus             normal fundus  1  0  0  0  0  0  0
#
#       O
# 1634  0
# 1635  0
# 1636  0
# 1637  0
# 1638  0
# 1639  0
# 1640  0
# 1641  0
# 1642  0
# 2334  0

# %%
from pathlib import Path

experiment_data_path = 'data/'

print(f'Annotations length before droping the rows with the special images: {len(odir_df)}')

odir_df = odir_df.drop(patients_to_drop_df.index) # Drop the special patients
Path(experiment_data_path).mkdir(parents=True, exist_ok=True) # Create the experiment data folder
odir_df.to_excel(annotations_path) # Save annotations without the special patients

print(f'Annotations length after droping the rows with the special images: {len(odir_df)}')
# Out:
# Annotations length before droping the rows with the special images: 3500
# Annotations length after droping the rows with the special images: 3490

# %% [markdown]
# # Check dataset label distribution

# %%
label_names = ['N','D','G','C','A','H','M','O']

total_label_list = []
for label in label_names:
    total_label = int(odir_df.loc[:, [label]].sum())
    total_label_list.append(total_label)

plt.figure(figsize=(16,4))

bar = plt.bar(label_names, total_label_list)

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f}', ha='center', va='bottom')

plt.xlabel(f'Label')
plt.ylabel(f'No. of images')
plt.title(f'Label distribution')
# Out:
# Text(0.5, 1.0, 'Label distribution')

# %% [markdown]
# # Split dataset into train and validation

# %%
os.chdir('../../scripts/')
from utils import split_annotations
os.chdir('../experiments/experiment_10/')

# %%
# Split the original annotations file into train and validation annotations files
# val_ratio = 0.2 (value by default)
split_annotations(annotations_path, experiment_data_path, test_split=False)

# Read the previous three created .xlsx files into dataframes
train_df = pd.read_excel(f'{experiment_data_path}/train_annotations.xlsx')
val_df = pd.read_excel(f'{experiment_data_path}/val_annotations.xlsx')

len(train_df), len(val_df)
# Out:
# (2792, 698)

# %% [markdown]
# # Check train and validation datasets label distribution

# %%
import numpy as np

barWidth = 0.3333
fig = plt.subplots(figsize =(16, 4))

# Set height of bars
total_label_train_list = [int(train_df.loc[:, [label]].sum()) for label in label_names]
total_label_val_list = [int(val_df.loc[:, [label]].sum()) for label in label_names]
 
# Set position of bar on X axis
br_train = np.arange(len(label_names))
br_val = [x + barWidth for x in br_train]
 
# Make the plot
bar_train = plt.bar(br_train, total_label_train_list, color ='r', width = barWidth,
                    edgecolor ='grey', label ='train')
bar_val = plt.bar(br_val, total_label_val_list, color ='b', width = barWidth,
                  edgecolor ='grey', label ='val')

# Plot the height label on top of each bar
for bar in [bar_train, bar_val]:
    for rect in bar:
        height = rect.get_height()
        plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f}', ha='center', va='bottom')

plt.title(f'Train/Validation distribution')
plt.xlabel('Label')
plt.ylabel('Nº of images')
plt.xticks([r + barWidth/2 for r in range(len(total_label_train_list))], label_names)
 
plt.legend()
plt.show()

# %% [markdown]
# # Train the model

# %%
# %run ../../scripts/train.py -h # Run this line to check the train script arguments
# Out:
# usage: train.py [-h] [--random_seed RANDOM_SEED] [--model_name MODEL_NAME]
#                 [--images_path IMAGES_PATH] [--use_data_augmentation]
#                 [--use_normalization]
#                 [--train_annotations_path TRAIN_ANNOTATIONS_PATH]
#                 [--val_annotations_path VAL_ANNOTATIONS_PATH]
#                 [--batch_size BATCH_SIZE] [--num_workers NUM_WORKERS]
#                 [--lr LR] [--momentum MOMENTUM] [--lr_scheduler LR_SCHEDULER]
#                 [--linear_lr_scheduler_total_iters LINEAR_LR_SCHEDULER_TOTAL_ITERS]
#                 [--linear_lr_scheduler_start_factor LINEAR_LR_SCHEDULER_START_FACTOR]
#                 [--linear_lr_scheduler_end_factor LINEAR_LR_SCHEDULER_END_FACTOR]
#                 [--cyclic_lr_scheduler_base_lr CYCLIC_LR_SCHEDULER_BASE_LR]
#                 [--cyclic_lr_scheduler_max_lr CYCLIC_LR_SCHEDULER_MAX_LR]
#                 [--cyclic_lr_scheduler_step_size_up CYCLIC_LR_SCHEDULER_STEP_SIZE_UP]
#                 [--epochs EPOCHS] [--patience PATIENCE]
#                 [--experiment_name EXPERIMENT_NAME] [--extra EXTRA]
#
# Train a network for image multi-label classification on ODIR-5K.
#
# options:
#   -h, --help            show this help message and exit
#   --random_seed RANDOM_SEED
#                         Sets random seed for reproducibility (default: 42).
#   --model_name MODEL_NAME
#                         Model arquitecture for training (default:
#                         resnet50_dual).
#   --images_path IMAGES_PATH
#                         Path of ODIR training images (default:
#                         /kaggle/input/odir-size-512/odir-size-512).
#   --use_data_augmentation
#                         If set augment training data.
#   --use_normalization   If set the images are normalized the same way the
#                         imagenet images where normalized to train the resnet50
#                         used here.
#   --train_annotations_path TRAIN_ANNOTATIONS_PATH
#                         Path of train annotations file (default:
#                         /kaggle/input/odir-size-512/train_annotations.xlsx).
#   --val_annotations_path VAL_ANNOTATIONS_PATH
#                         Path of validation annotations file (default:
#                         /kaggle/input/odir-size-512/val_annotations.xlsx).
#   --batch_size BATCH_SIZE
#                         Batch size for data loaders (default: 32).
#   --num_workers NUM_WORKERS
#                         Number of workers for data loaders (default:
#                         os.cpu_count()).
#   --lr LR               Specifies learning rate for optimizer (default: 1e-3).
#   --momentum MOMENTUM   Specifies momentum for optimizer (default: 0.9).
#   --lr_scheduler LR_SCHEDULER
#                         Learning rate scheduler (default: None)
#   --linear_lr_scheduler_total_iters LINEAR_LR_SCHEDULER_TOTAL_ITERS
#                         Number of steps that the linear lr scheduler decays
#                         the learning rate (default: 50).
#   --linear_lr_scheduler_start_factor LINEAR_LR_SCHEDULER_START_FACTOR
#                         Start factor of the linear lr scheduler (default: 1).
#   --linear_lr_scheduler_end_factor LINEAR_LR_SCHEDULER_END_FACTOR
#                         End factor of the linear lr scheduler (default: 0.1).
#   --cyclic_lr_scheduler_base_lr CYCLIC_LR_SCHEDULER_BASE_LR
#                         Initial learning rate which is the lower boundary in
#                         the cycle for each parameter group (default: 0.001).
#   --cyclic_lr_scheduler_max_lr CYCLIC_LR_SCHEDULER_MAX_LR
#                         Upper learning rate boundaries in the cycle for each
#                         parameter group (default: 0.1).
#   --cyclic_lr_scheduler_step_size_up CYCLIC_LR_SCHEDULER_STEP_SIZE_UP
#                         Number of training iterations in the increasing half
#                         of a cycle (default: 10).
#   --epochs EPOCHS       Number of training epochs (default: 5).
#   --patience PATIENCE   How long to wait after last time validation loss
#                         improved (default: 1).
#   --experiment_name EXPERIMENT_NAME
#                         Name of the experiment" (default: experiment_0).
#   --extra EXTRA         Extra info about the experiment (default: None).

# %%
# Arguments that will be passed to the train script
images_path = '../../../train_fov_cc_fov_512/'
train_annotations_path = 'data/train_annotations.xlsx'
val_annotations_path = 'data/val_annotations.xlsx'
lr = 0.05
lr_scheduler = 'LinearLR'
linear_lr_scheduler_total_iters = 50
batch_size = 32
epochs = 100
patience = 20
experiment_name = 'experiment_10'

# %%
# %run ../../scripts/train.py --images_path {images_path} --train_annotations_path {train_annotations_path} --val_annotations_path {val_annotations_path}\
                            --batch_size {batch_size} --epochs {epochs} --patience {patience} --experiment_name {experiment_name} --use_normalization\
                            --lr {lr} --lr_scheduler {lr_scheduler} --linear_lr_scheduler_total_iters {linear_lr_scheduler_total_iters}
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 60.8MB/s]
# [INFO] Created new resnet50_dual model.
# [INFO] Created SummaryWriter, saving to: ../runs/resnet50_dual/experiment_10...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ep: 0 | t_loss: 0.3551 | t_kappa: 0.0226 | t_f1: 0.0912 | t_auc: 0.5990 | t_final: 0.2376 | v_loss: 0.3266 | v_kappa: 0.0664 | v_f1: 0.1339 | v_auc: 0.6508 | v_final: 0.2837
# Validation loss decreased (inf --> 0.326641).  Saving model ...
# Ep: 1 | t_loss: 0.3068 | t_kappa: 0.1273 | t_f1: 0.2149 | t_auc: 0.7073 | t_final: 0.3498 | v_loss: 0.3135 | v_kappa: 0.1545 | v_f1: 0.1596 | v_auc: 0.6754 | v_final: 0.3298
# Validation loss decreased (0.326641 --> 0.313473).  Saving model ...
# Ep: 2 | t_loss: 0.2996 | t_kappa: 0.2031 | t_f1: 0.2951 | t_auc: 0.7168 | t_final: 0.4050 | v_loss: 0.3145 | v_kappa: 0.2205 | v_f1: 0.2564 | v_auc: 0.6851 | v_final: 0.3873
# EarlyStopping counter: 1 out of 20
# Ep: 3 | t_loss: 0.2879 | t_kappa: 0.2329 | t_f1: 0.3255 | t_auc: 0.7523 | t_final: 0.4369 | v_loss: 0.3206 | v_kappa: 0.2245 | v_f1: 0.2646 | v_auc: 0.6921 | v_final: 0.3937
# EarlyStopping counter: 2 out of 20
# Ep: 4 | t_loss: 0.2838 | t_kappa: 0.2379 | t_f1: 0.3369 | t_auc: 0.7615 | t_final: 0.4454 | v_loss: 0.3050 | v_kappa: 0.2270 | v_f1: 0.2999 | v_auc: 0.7031 | v_final: 0.4100
# Validation loss decreased (0.313473 --> 0.304954).  Saving model ...
# Ep: 5 | t_loss: 0.2769 | t_kappa: 0.2617 | t_f1: 0.3571 | t_auc: 0.7799 | t_final: 0.4662 | v_loss: 0.3081 | v_kappa: 0.2552 | v_f1: 0.2818 | v_auc: 0.7009 | v_final: 0.4127
# EarlyStopping counter: 1 out of 20
# Ep: 6 | t_loss: 0.2728 | t_kappa: 0.2764 | t_f1: 0.3885 | t_auc: 0.7884 | t_final: 0.4844 | v_loss: 0.3023 | v_kappa: 0.2406 | v_f1: 0.3367 | v_auc: 0.7032 | v_final: 0.4268
# Validation loss decreased (0.304954 --> 0.302316).  Saving model ...
# Ep: 7 | t_loss: 0.2699 | t_kappa: 0.2866 | t_f1: 0.3951 | t_auc: 0.7922 | t_final: 0.4913 | v_loss: 0.3009 | v_kappa: 0.2345 | v_f1: 0.3011 | v_auc: 0.7040 | v_final: 0.4132
# Validation loss decreased (0.302316 --> 0.300931).  Saving model ...
# Ep: 8 | t_loss: 0.2650 | t_kappa: 0.2951 | t_f1: 0.4171 | t_auc: 0.8043 | t_final: 0.5055 | v_loss: 0.2982 | v_kappa: 0.2577 | v_f1: 0.3463 | v_auc: 0.7083 | v_final: 0.4374
# Validation loss decreased (0.300931 --> 0.298237).  Saving model ...
# Ep: 9 | t_loss: 0.2632 | t_kappa: 0.2997 | t_f1: 0.4191 | t_auc: 0.8077 | t_final: 0.5088 | v_loss: 0.2986 | v_kappa: 0.2812 | v_f1: 0.3401 | v_auc: 0.7096 | v_final: 0.4436
# EarlyStopping counter: 1 out of 20
# Ep: 10 | t_loss: 0.2617 | t_kappa: 0.3119 | t_f1: 0.4248 | t_auc: 0.8115 | t_final: 0.5161 | v_loss: 0.3013 | v_kappa: 0.2557 | v_f1: 0.3439 | v_auc: 0.7102 | v_final: 0.4366
# EarlyStopping counter: 2 out of 20
# Ep: 11 | t_loss: 0.2559 | t_kappa: 0.3237 | t_f1: 0.4442 | t_auc: 0.8241 | t_final: 0.5307 | v_loss: 0.2965 | v_kappa: 0.2655 | v_f1: 0.3552 | v_auc: 0.7135 | v_final: 0.4447
# Validation loss decreased (0.298237 --> 0.296501).  Saving model ...
# Ep: 12 | t_loss: 0.2533 | t_kappa: 0.3321 | t_f1: 0.4513 | t_auc: 0.8316 | t_final: 0.5383 | v_loss: 0.3017 | v_kappa: 0.2468 | v_f1: 0.3074 | v_auc: 0.7115 | v_final: 0.4219
# EarlyStopping counter: 1 out of 20
# Ep: 13 | t_loss: 0.2532 | t_kappa: 0.3352 | t_f1: 0.4597 | t_auc: 0.8270 | t_final: 0.5406 | v_loss: 0.2963 | v_kappa: 0.2731 | v_f1: 0.2987 | v_auc: 0.7131 | v_final: 0.4283
# Validation loss decreased (0.296501 --> 0.296286).  Saving model ...
# Ep: 14 | t_loss: 0.2500 | t_kappa: 0.3476 | t_f1: 0.4728 | t_auc: 0.8359 | t_final: 0.5521 | v_loss: 0.2966 | v_kappa: 0.2637 | v_f1: 0.2960 | v_auc: 0.7167 | v_final: 0.4255
# EarlyStopping counter: 1 out of 20
# Ep: 15 | t_loss: 0.2479 | t_kappa: 0.3623 | t_f1: 0.4806 | t_auc: 0.8396 | t_final: 0.5608 | v_loss: 0.2998 | v_kappa: 0.2684 | v_f1: 0.3469 | v_auc: 0.7167 | v_final: 0.4440
# EarlyStopping counter: 2 out of 20
# Ep: 16 | t_loss: 0.2473 | t_kappa: 0.3436 | t_f1: 0.4722 | t_auc: 0.8426 | t_final: 0.5528 | v_loss: 0.2940 | v_kappa: 0.2997 | v_f1: 0.3740 | v_auc: 0.7183 | v_final: 0.4640
# Validation loss decreased (0.296286 --> 0.294038).  Saving model ...
# Ep: 17 | t_loss: 0.2441 | t_kappa: 0.3608 | t_f1: 0.4830 | t_auc: 0.8485 | t_final: 0.5641 | v_loss: 0.2930 | v_kappa: 0.2677 | v_f1: 0.3285 | v_auc: 0.7185 | v_final: 0.4382
# Validation loss decreased (0.294038 --> 0.293002).  Saving model ...
# Ep: 18 | t_loss: 0.2424 | t_kappa: 0.3697 | t_f1: 0.4951 | t_auc: 0.8500 | t_final: 0.5716 | v_loss: 0.2972 | v_kappa: 0.2659 | v_f1: 0.3141 | v_auc: 0.7195 | v_final: 0.4332
# EarlyStopping counter: 1 out of 20
# Ep: 19 | t_loss: 0.2413 | t_kappa: 0.3641 | t_f1: 0.4939 | t_auc: 0.8536 | t_final: 0.5705 | v_loss: 0.2961 | v_kappa: 0.2772 | v_f1: 0.3428 | v_auc: 0.7181 | v_final: 0.4460
# EarlyStopping counter: 2 out of 20
# Ep: 20 | t_loss: 0.2395 | t_kappa: 0.3774 | t_f1: 0.5031 | t_auc: 0.8576 | t_final: 0.5794 | v_loss: 0.2957 | v_kappa: 0.2761 | v_f1: 0.3559 | v_auc: 0.7202 | v_final: 0.4507
# EarlyStopping counter: 3 out of 20
# Ep: 21 | t_loss: 0.2403 | t_kappa: 0.3767 | t_f1: 0.5042 | t_auc: 0.8515 | t_final: 0.5775 | v_loss: 0.2978 | v_kappa: 0.2613 | v_f1: 0.3534 | v_auc: 0.7202 | v_final: 0.4450
# EarlyStopping counter: 4 out of 20
# Ep: 22 | t_loss: 0.2373 | t_kappa: 0.3798 | t_f1: 0.5067 | t_auc: 0.8639 | t_final: 0.5835 | v_loss: 0.2933 | v_kappa: 0.2592 | v_f1: 0.3487 | v_auc: 0.7188 | v_final: 0.4422
# EarlyStopping counter: 5 out of 20
# Ep: 23 | t_loss: 0.2361 | t_kappa: 0.3879 | t_f1: 0.5123 | t_auc: 0.8626 | t_final: 0.5876 | v_loss: 0.2930 | v_kappa: 0.2765 | v_f1: 0.3819 | v_auc: 0.7215 | v_final: 0.4599
# Validation loss decreased (0.293002 --> 0.292999).  Saving model ...
# Ep: 24 | t_loss: 0.2352 | t_kappa: 0.3829 | t_f1: 0.5208 | t_auc: 0.8632 | t_final: 0.5890 | v_loss: 0.2980 | v_kappa: 0.2810 | v_f1: 0.3519 | v_auc: 0.7194 | v_final: 0.4508
# EarlyStopping counter: 1 out of 20
# Ep: 25 | t_loss: 0.2337 | t_kappa: 0.3961 | t_f1: 0.5231 | t_auc: 0.8668 | t_final: 0.5953 | v_loss: 0.2945 | v_kappa: 0.2678 | v_f1: 0.3062 | v_auc: 0.7218 | v_final: 0.4319
# EarlyStopping counter: 2 out of 20
# Ep: 26 | t_loss: 0.2314 | t_kappa: 0.3986 | t_f1: 0.5308 | t_auc: 0.8679 | t_final: 0.5991 | v_loss: 0.2953 | v_kappa: 0.2784 | v_f1: 0.3494 | v_auc: 0.7186 | v_final: 0.4488
# EarlyStopping counter: 3 out of 20
# Ep: 27 | t_loss: 0.2311 | t_kappa: 0.3991 | t_f1: 0.5306 | t_auc: 0.8710 | t_final: 0.6002 | v_loss: 0.2915 | v_kappa: 0.2833 | v_f1: 0.3494 | v_auc: 0.7210 | v_final: 0.4512
# Validation loss decreased (0.292999 --> 0.291481).  Saving model ...
# Ep: 28 | t_loss: 0.2303 | t_kappa: 0.4023 | t_f1: 0.5327 | t_auc: 0.8732 | t_final: 0.6027 | v_loss: 0.2922 | v_kappa: 0.2855 | v_f1: 0.3401 | v_auc: 0.7219 | v_final: 0.4492
# EarlyStopping counter: 1 out of 20
# Ep: 29 | t_loss: 0.2287 | t_kappa: 0.4219 | t_f1: 0.5418 | t_auc: 0.8744 | t_final: 0.6127 | v_loss: 0.2919 | v_kappa: 0.2851 | v_f1: 0.3485 | v_auc: 0.7203 | v_final: 0.4513
# EarlyStopping counter: 2 out of 20
# Ep: 30 | t_loss: 0.2273 | t_kappa: 0.4137 | t_f1: 0.5446 | t_auc: 0.8763 | t_final: 0.6115 | v_loss: 0.2942 | v_kappa: 0.2701 | v_f1: 0.3628 | v_auc: 0.7217 | v_final: 0.4515
# EarlyStopping counter: 3 out of 20
# Ep: 31 | t_loss: 0.2284 | t_kappa: 0.4080 | t_f1: 0.5400 | t_auc: 0.8754 | t_final: 0.6078 | v_loss: 0.2932 | v_kappa: 0.2754 | v_f1: 0.3360 | v_auc: 0.7204 | v_final: 0.4439
# EarlyStopping counter: 4 out of 20
# Ep: 32 | t_loss: 0.2284 | t_kappa: 0.4105 | t_f1: 0.5438 | t_auc: 0.8760 | t_final: 0.6101 | v_loss: 0.2937 | v_kappa: 0.3010 | v_f1: 0.3747 | v_auc: 0.7218 | v_final: 0.4659
# EarlyStopping counter: 5 out of 20
# Ep: 33 | t_loss: 0.2258 | t_kappa: 0.4164 | t_f1: 0.5445 | t_auc: 0.8793 | t_final: 0.6134 | v_loss: 0.2971 | v_kappa: 0.2760 | v_f1: 0.3084 | v_auc: 0.7193 | v_final: 0.4345
# EarlyStopping counter: 6 out of 20
# Ep: 34 | t_loss: 0.2255 | t_kappa: 0.4236 | t_f1: 0.5465 | t_auc: 0.8776 | t_final: 0.6159 | v_loss: 0.2920 | v_kappa: 0.2813 | v_f1: 0.3494 | v_auc: 0.7204 | v_final: 0.4504
# EarlyStopping counter: 7 out of 20
# Ep: 35 | t_loss: 0.2241 | t_kappa: 0.4149 | t_f1: 0.5526 | t_auc: 0.8837 | t_final: 0.6171 | v_loss: 0.2948 | v_kappa: 0.2832 | v_f1: 0.3640 | v_auc: 0.7201 | v_final: 0.4558
# EarlyStopping counter: 8 out of 20
# Ep: 36 | t_loss: 0.2245 | t_kappa: 0.4265 | t_f1: 0.5509 | t_auc: 0.8818 | t_final: 0.6197 | v_loss: 0.2911 | v_kappa: 0.2777 | v_f1: 0.3381 | v_auc: 0.7225 | v_final: 0.4461
# Validation loss decreased (0.291481 --> 0.291146).  Saving model ...
# Ep: 37 | t_loss: 0.2218 | t_kappa: 0.4282 | t_f1: 0.5587 | t_auc: 0.8859 | t_final: 0.6243 | v_loss: 0.2911 | v_kappa: 0.2890 | v_f1: 0.3650 | v_auc: 0.7227 | v_final: 0.4589
# Validation loss decreased (0.291146 --> 0.291102).  Saving model ...
# Ep: 38 | t_loss: 0.2237 | t_kappa: 0.4228 | t_f1: 0.5533 | t_auc: 0.8847 | t_final: 0.6203 | v_loss: 0.2938 | v_kappa: 0.2765 | v_f1: 0.3672 | v_auc: 0.7186 | v_final: 0.4541
# EarlyStopping counter: 1 out of 20
# Ep: 39 | t_loss: 0.2222 | t_kappa: 0.4237 | t_f1: 0.5551 | t_auc: 0.8887 | t_final: 0.6225 | v_loss: 0.2913 | v_kappa: 0.2876 | v_f1: 0.3636 | v_auc: 0.7230 | v_final: 0.4581
# EarlyStopping counter: 2 out of 20
# Ep: 40 | t_loss: 0.2209 | t_kappa: 0.4380 | t_f1: 0.5668 | t_auc: 0.8876 | t_final: 0.6308 | v_loss: 0.2923 | v_kappa: 0.2935 | v_f1: 0.3600 | v_auc: 0.7218 | v_final: 0.4584
# EarlyStopping counter: 3 out of 20
# Ep: 41 | t_loss: 0.2208 | t_kappa: 0.4352 | t_f1: 0.5607 | t_auc: 0.8873 | t_final: 0.6277 | v_loss: 0.2928 | v_kappa: 0.2950 | v_f1: 0.3604 | v_auc: 0.7216 | v_final: 0.4590
# EarlyStopping counter: 4 out of 20
# Ep: 42 | t_loss: 0.2185 | t_kappa: 0.4316 | t_f1: 0.5660 | t_auc: 0.8920 | t_final: 0.6299 | v_loss: 0.2926 | v_kappa: 0.2760 | v_f1: 0.3555 | v_auc: 0.7225 | v_final: 0.4513
# EarlyStopping counter: 5 out of 20
# Ep: 43 | t_loss: 0.2183 | t_kappa: 0.4328 | t_f1: 0.5715 | t_auc: 0.8938 | t_final: 0.6327 | v_loss: 0.2937 | v_kappa: 0.2838 | v_f1: 0.3453 | v_auc: 0.7219 | v_final: 0.4503
# EarlyStopping counter: 6 out of 20
# Ep: 44 | t_loss: 0.2190 | t_kappa: 0.4403 | t_f1: 0.5633 | t_auc: 0.8904 | t_final: 0.6313 | v_loss: 0.2924 | v_kappa: 0.2854 | v_f1: 0.3449 | v_auc: 0.7221 | v_final: 0.4508
# EarlyStopping counter: 7 out of 20
# Ep: 45 | t_loss: 0.2192 | t_kappa: 0.4413 | t_f1: 0.5721 | t_auc: 0.8928 | t_final: 0.6354 | v_loss: 0.2964 | v_kappa: 0.2952 | v_f1: 0.3568 | v_auc: 0.7209 | v_final: 0.4576
# EarlyStopping counter: 8 out of 20
# Ep: 46 | t_loss: 0.2164 | t_kappa: 0.4497 | t_f1: 0.5810 | t_auc: 0.8973 | t_final: 0.6427 | v_loss: 0.2921 | v_kappa: 0.3060 | v_f1: 0.3745 | v_auc: 0.7246 | v_final: 0.4684
# EarlyStopping counter: 9 out of 20
# Ep: 47 | t_loss: 0.2184 | t_kappa: 0.4512 | t_f1: 0.5781 | t_auc: 0.8921 | t_final: 0.6404 | v_loss: 0.2922 | v_kappa: 0.2957 | v_f1: 0.3557 | v_auc: 0.7230 | v_final: 0.4581
# EarlyStopping counter: 10 out of 20
# Ep: 48 | t_loss: 0.2172 | t_kappa: 0.4505 | t_f1: 0.5745 | t_auc: 0.8945 | t_final: 0.6398 | v_loss: 0.2936 | v_kappa: 0.2922 | v_f1: 0.3673 | v_auc: 0.7219 | v_final: 0.4605
# EarlyStopping counter: 11 out of 20
# Ep: 49 | t_loss: 0.2168 | t_kappa: 0.4504 | t_f1: 0.5814 | t_auc: 0.8957 | t_final: 0.6425 | v_loss: 0.2902 | v_kappa: 0.2897 | v_f1: 0.3699 | v_auc: 0.7230 | v_final: 0.4609
# Validation loss decreased (0.291102 --> 0.290231).  Saving model ...
# Ep: 50 | t_loss: 0.2168 | t_kappa: 0.4515 | t_f1: 0.5758 | t_auc: 0.8940 | t_final: 0.6404 | v_loss: 0.2928 | v_kappa: 0.2943 | v_f1: 0.3639 | v_auc: 0.7227 | v_final: 0.4603
# EarlyStopping counter: 1 out of 20
# Ep: 51 | t_loss: 0.2177 | t_kappa: 0.4495 | t_f1: 0.5772 | t_auc: 0.8960 | t_final: 0.6409 | v_loss: 0.2949 | v_kappa: 0.2713 | v_f1: 0.3532 | v_auc: 0.7214 | v_final: 0.4486
# EarlyStopping counter: 2 out of 20
# Ep: 52 | t_loss: 0.2179 | t_kappa: 0.4392 | t_f1: 0.5699 | t_auc: 0.8962 | t_final: 0.6351 | v_loss: 0.2927 | v_kappa: 0.2893 | v_f1: 0.3686 | v_auc: 0.7217 | v_final: 0.4599
# EarlyStopping counter: 3 out of 20
# Ep: 53 | t_loss: 0.2166 | t_kappa: 0.4434 | t_f1: 0.5750 | t_auc: 0.8961 | t_final: 0.6381 | v_loss: 0.2940 | v_kappa: 0.3012 | v_f1: 0.3641 | v_auc: 0.7221 | v_final: 0.4625
# EarlyStopping counter: 4 out of 20
# Ep: 54 | t_loss: 0.2162 | t_kappa: 0.4461 | t_f1: 0.5727 | t_auc: 0.8950 | t_final: 0.6379 | v_loss: 0.2925 | v_kappa: 0.2962 | v_f1: 0.3714 | v_auc: 0.7229 | v_final: 0.4635
# EarlyStopping counter: 5 out of 20
# Ep: 55 | t_loss: 0.2173 | t_kappa: 0.4506 | t_f1: 0.5730 | t_auc: 0.8934 | t_final: 0.6390 | v_loss: 0.2914 | v_kappa: 0.3024 | v_f1: 0.3772 | v_auc: 0.7235 | v_final: 0.4677
# EarlyStopping counter: 6 out of 20
# Ep: 56 | t_loss: 0.2160 | t_kappa: 0.4431 | t_f1: 0.5746 | t_auc: 0.8970 | t_final: 0.6382 | v_loss: 0.2903 | v_kappa: 0.2938 | v_f1: 0.3705 | v_auc: 0.7249 | v_final: 0.4630
# EarlyStopping counter: 7 out of 20
# Ep: 57 | t_loss: 0.2161 | t_kappa: 0.4542 | t_f1: 0.5833 | t_auc: 0.8975 | t_final: 0.6450 | v_loss: 0.2909 | v_kappa: 0.2848 | v_f1: 0.3728 | v_auc: 0.7229 | v_final: 0.4602
# EarlyStopping counter: 8 out of 20
# Ep: 58 | t_loss: 0.2145 | t_kappa: 0.4521 | t_f1: 0.5811 | t_auc: 0.8973 | t_final: 0.6435 | v_loss: 0.2939 | v_kappa: 0.2905 | v_f1: 0.3645 | v_auc: 0.7221 | v_final: 0.4590
# EarlyStopping counter: 9 out of 20
# Ep: 59 | t_loss: 0.2170 | t_kappa: 0.4509 | t_f1: 0.5807 | t_auc: 0.8964 | t_final: 0.6427 | v_loss: 0.2932 | v_kappa: 0.2815 | v_f1: 0.3392 | v_auc: 0.7204 | v_final: 0.4470
# EarlyStopping counter: 10 out of 20
# Ep: 60 | t_loss: 0.2135 | t_kappa: 0.4539 | t_f1: 0.5839 | t_auc: 0.9003 | t_final: 0.6460 | v_loss: 0.2900 | v_kappa: 0.2841 | v_f1: 0.3629 | v_auc: 0.7236 | v_final: 0.4569
# Validation loss decreased (0.290231 --> 0.289970).  Saving model ...
# Ep: 61 | t_loss: 0.2149 | t_kappa: 0.4557 | t_f1: 0.5840 | t_auc: 0.8981 | t_final: 0.6459 | v_loss: 0.2925 | v_kappa: 0.2920 | v_f1: 0.3632 | v_auc: 0.7238 | v_final: 0.4597
# EarlyStopping counter: 1 out of 20
# Ep: 62 | t_loss: 0.2129 | t_kappa: 0.4550 | t_f1: 0.5868 | t_auc: 0.8999 | t_final: 0.6472 | v_loss: 0.2939 | v_kappa: 0.2797 | v_f1: 0.3602 | v_auc: 0.7212 | v_final: 0.4537
# EarlyStopping counter: 2 out of 20
# Ep: 63 | t_loss: 0.2156 | t_kappa: 0.4536 | t_f1: 0.5805 | t_auc: 0.8970 | t_final: 0.6437 | v_loss: 0.2911 | v_kappa: 0.2822 | v_f1: 0.3556 | v_auc: 0.7227 | v_final: 0.4535
# EarlyStopping counter: 3 out of 20
# Ep: 64 | t_loss: 0.2141 | t_kappa: 0.4581 | t_f1: 0.5824 | t_auc: 0.8991 | t_final: 0.6465 | v_loss: 0.2911 | v_kappa: 0.2909 | v_f1: 0.3688 | v_auc: 0.7239 | v_final: 0.4612
# EarlyStopping counter: 4 out of 20
# Ep: 65 | t_loss: 0.2158 | t_kappa: 0.4460 | t_f1: 0.5827 | t_auc: 0.8963 | t_final: 0.6417 | v_loss: 0.2951 | v_kappa: 0.2936 | v_f1: 0.3528 | v_auc: 0.7234 | v_final: 0.4566
# EarlyStopping counter: 5 out of 20
# Ep: 66 | t_loss: 0.2154 | t_kappa: 0.4480 | t_f1: 0.5803 | t_auc: 0.8975 | t_final: 0.6419 | v_loss: 0.2945 | v_kappa: 0.2852 | v_f1: 0.3664 | v_auc: 0.7211 | v_final: 0.4576
# EarlyStopping counter: 6 out of 20
# Ep: 67 | t_loss: 0.2157 | t_kappa: 0.4491 | t_f1: 0.5848 | t_auc: 0.8974 | t_final: 0.6438 | v_loss: 0.2937 | v_kappa: 0.2936 | v_f1: 0.3641 | v_auc: 0.7251 | v_final: 0.4610
# EarlyStopping counter: 7 out of 20
# Ep: 68 | t_loss: 0.2144 | t_kappa: 0.4569 | t_f1: 0.5847 | t_auc: 0.8972 | t_final: 0.6463 | v_loss: 0.2923 | v_kappa: 0.2907 | v_f1: 0.3682 | v_auc: 0.7219 | v_final: 0.4603
# EarlyStopping counter: 8 out of 20
# Ep: 69 | t_loss: 0.2143 | t_kappa: 0.4511 | t_f1: 0.5795 | t_auc: 0.8974 | t_final: 0.6426 | v_loss: 0.2913 | v_kappa: 0.2963 | v_f1: 0.3633 | v_auc: 0.7229 | v_final: 0.4608
# EarlyStopping counter: 9 out of 20
# Ep: 70 | t_loss: 0.2138 | t_kappa: 0.4574 | t_f1: 0.5844 | t_auc: 0.8976 | t_final: 0.6464 | v_loss: 0.2911 | v_kappa: 0.2880 | v_f1: 0.3594 | v_auc: 0.7235 | v_final: 0.4570
# EarlyStopping counter: 10 out of 20
# Ep: 71 | t_loss: 0.2144 | t_kappa: 0.4608 | t_f1: 0.5848 | t_auc: 0.8976 | t_final: 0.6477 | v_loss: 0.2918 | v_kappa: 0.2836 | v_f1: 0.3606 | v_auc: 0.7241 | v_final: 0.4561
# EarlyStopping counter: 11 out of 20
# Ep: 72 | t_loss: 0.2125 | t_kappa: 0.4732 | t_f1: 0.5989 | t_auc: 0.9004 | t_final: 0.6575 | v_loss: 0.2921 | v_kappa: 0.2853 | v_f1: 0.3585 | v_auc: 0.7230 | v_final: 0.4556
# EarlyStopping counter: 12 out of 20
# Ep: 73 | t_loss: 0.2143 | t_kappa: 0.4597 | t_f1: 0.5858 | t_auc: 0.8985 | t_final: 0.6480 | v_loss: 0.2918 | v_kappa: 0.2888 | v_f1: 0.3490 | v_auc: 0.7242 | v_final: 0.4540
# EarlyStopping counter: 13 out of 20
# Ep: 74 | t_loss: 0.2124 | t_kappa: 0.4653 | t_f1: 0.5912 | t_auc: 0.9010 | t_final: 0.6525 | v_loss: 0.2914 | v_kappa: 0.2974 | v_f1: 0.3786 | v_auc: 0.7228 | v_final: 0.4663
# EarlyStopping counter: 14 out of 20
# Ep: 75 | t_loss: 0.2126 | t_kappa: 0.4612 | t_f1: 0.5926 | t_auc: 0.9014 | t_final: 0.6517 | v_loss: 0.2927 | v_kappa: 0.2758 | v_f1: 0.3615 | v_auc: 0.7219 | v_final: 0.4531
# EarlyStopping counter: 15 out of 20
# Ep: 76 | t_loss: 0.2135 | t_kappa: 0.4587 | t_f1: 0.5911 | t_auc: 0.8996 | t_final: 0.6498 | v_loss: 0.2938 | v_kappa: 0.2975 | v_f1: 0.3512 | v_auc: 0.7246 | v_final: 0.4578
# EarlyStopping counter: 16 out of 20
# Ep: 77 | t_loss: 0.2142 | t_kappa: 0.4594 | t_f1: 0.5846 | t_auc: 0.8977 | t_final: 0.6472 | v_loss: 0.2922 | v_kappa: 0.2721 | v_f1: 0.3516 | v_auc: 0.7211 | v_final: 0.4483
# EarlyStopping counter: 17 out of 20
# Ep: 78 | t_loss: 0.2125 | t_kappa: 0.4674 | t_f1: 0.5853 | t_auc: 0.9018 | t_final: 0.6515 | v_loss: 0.2919 | v_kappa: 0.2820 | v_f1: 0.3767 | v_auc: 0.7222 | v_final: 0.4603
# EarlyStopping counter: 18 out of 20
# Ep: 79 | t_loss: 0.2128 | t_kappa: 0.4582 | t_f1: 0.5892 | t_auc: 0.9008 | t_final: 0.6494 | v_loss: 0.2924 | v_kappa: 0.2941 | v_f1: 0.3637 | v_auc: 0.7243 | v_final: 0.4607
# EarlyStopping counter: 19 out of 20
# Ep: 80 | t_loss: 0.2123 | t_kappa: 0.4532 | t_f1: 0.5826 | t_auc: 0.9010 | t_final: 0.6456 | v_loss: 0.2920 | v_kappa: 0.2894 | v_f1: 0.3725 | v_auc: 0.7220 | v_final: 0.4613
# EarlyStopping counter: 20 out of 20
# Early stopping

# %% [markdown]
# Run the next cell to see the metrics trough the epochs using the tensorboard interface

# %%
# %reload_ext tensorboard
# %tensorboard --logdir ../runs

# %% [markdown]
# # Test the model with the validation dataset
# Since there is no access to the test annotatations (only to the images) the test will be performed on the validation dataset, to be able to see some results.

# %%
# %run ../../scripts/test.py -h # Run this line to check the test script arguments
# Out:
# usage: test.py [-h] [--model_name MODEL_NAME] [--model_path MODEL_PATH]
#                [--images_path IMAGES_PATH]
#                [--test_annotations_path TEST_ANNOTATIONS_PATH]
#                [--use_normalization] [--batch_size BATCH_SIZE]
#                [--num_workers NUM_WORKERS]
#                [--ground_truth_path GROUND_TRUTH_PATH]
#                [--probs_path PROBS_PATH]
#
# Test a model with a dataset.
#
# options:
#   -h, --help            show this help message and exit
#   --model_name MODEL_NAME
#                         Model arquitecture for testing (default:
#                         resnet50_dual).
#   --model_path MODEL_PATH
#                         Path to the model to test the dataset with (default:
#                         outputs/resnet50_dual_experiment_0_model.pth).
#   --images_path IMAGES_PATH
#                         Path of test images (default:
#                         ../../data/train_fov_cc_fov_224/).
#   --test_annotations_path TEST_ANNOTATIONS_PATH
#                         Path of test annotations file (default:
#                         data/test_annotations.xlsx).
#   --use_normalization   If set the images are normalized the same way the
#                         imagenet images were normalized to train the resnet50
#                         used here.
#   --batch_size BATCH_SIZE
#                         Batch size for data loaders (default: 32).
#   --num_workers NUM_WORKERS
#                         Number of workers for data loaders (default:
#                         os.cpu_count()).
#   --ground_truth_path GROUND_TRUTH_PATH
#                         Path to store the ground truth labels used in test
#                         (default: None).
#   --probs_path PROBS_PATH
#                         Path to store the result probs of test (default:
#                         None).

# %%
test_annotations_path = 'data/val_annotations.xlsx' # val annotations are used for test
images_path = '../../../train_fov_cc_fov_512/'
model_path = 'outputs/resnet50_dual_experiment_10_model.pth'
ground_truth_path = 'outputs/ground_truth.xlsx'
probs_path = 'outputs/probs.xlsx'

# %%
# %run ../../scripts/test.py --model_path {model_path} --images_path {images_path} --test_annotations_path {test_annotations_path} --use_normalization\
                           --ground_truth_path {ground_truth_path} --probs_path {probs_path}
# Out:
# [INFO] Created new resnet50_dual model.
# test_loss: 0.2900 | test_kappa: 0.2841 | test_f1: 0.3629 | test_auc: 0.7236 | test_final: 0.4569

# %% [markdown]
# # Run the ODIR_evaluation.py script on test (validation) dataset
# This is a file provided along with the data by the challenge. And its supposed to have an example on how to compute the kappa, f1, auc, and final score metrics but i dont think they are well computed here as they are always too good (as shown later, the cualitative results for test are much worst). As a result of this, i use my own version of this metrics (see the function compute_challenge_metrics on the metrics script). Either way i'll run it.

# %%
ground_truth_path = 'outputs/ground_truth.xlsx'
probs_path = 'outputs/probs.xlsx'
probs_csv_path = 'outputs/probs.csv'

probs_df = pd.read_excel(probs_path)
probs_df.to_csv(probs_csv_path, index=False) # The ODIR_evaluation script asks the probs file to be in .csv format

# %run ../../scripts/ODIR_evaluation.py {ground_truth_path} {probs_csv_path}
# Out:
# kappa score: 0.32113914412958  f-1 score: 0.8664040114613181  AUC vlaue: 0.8710089132740475  Final Score: 0.6861840229549818

# %% [markdown]
# # Cuantitative results
# The test script prints some results as can be seen in the output of the previous cell. Now, lets see some more.

# %%
label_names = ['N','D','G','C','A','H','M','O']

ground_truth = pd.read_excel(ground_truth_path).loc[:, label_names].to_numpy()
probs = pd.read_excel(probs_path).loc[:, label_names].to_numpy()

# %%
from sklearn import metrics
os.chdir('../../scripts')
from metrics import plot_confusion_matrices
os.chdir('../experiments/experiment_10/')

# Print test classification report
print('Clasification report:')
print(
    metrics.classification_report(
        ground_truth,
        probs>0.5,
        output_dict=False,
        target_names=label_names,
        zero_division=0
    )
)

# Plot one confusion matrix for each label
plot_confusion_matrices(ground_truth, probs, label_names)
# Out:
# Clasification report:
#               precision    recall  f1-score   support
#
#            N       0.57      0.32      0.41       214
#            D       0.63      0.34      0.44       226
#            G       1.00      0.03      0.06        34
#            C       0.87      0.73      0.79        37
#            A       0.40      0.05      0.10        37
#            H       0.00      0.00      0.00        29
#            M       0.81      0.70      0.75        30
#            O       0.45      0.18      0.25       217
#
#    micro avg       0.60      0.28      0.39       824
#    macro avg       0.59      0.29      0.35       824
# weighted avg       0.57      0.28      0.36       824
#  samples avg       0.30      0.29      0.29       824

# %% [markdown]
# # Cualitative results
# One patient with each disease (at least) is predicted. The original images are ploted along with their ground truth and predicted labels.

# %%
import torch
from torchvision import transforms
os.chdir('../../scripts')
from utils import load_model
from predict import pred_and_plot_image
os.chdir('../experiments/experiment_10/')

# %%
model = load_model(model_path)

test_df = pd.read_excel(test_annotations_path)

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# [INFO] Created new resnet50_dual model.

# %% [markdown]
# You can run the next cell multiple times to see different results

# %%
for label in label_names:
    patient = test_df[test_df[label] == 1].sample(replace=True).reset_index(drop=True)
    pred_and_plot_image(model=model,
                        left_image_path=f'{images_path}/{patient.at[0, "Left-Fundus"]}',
                        right_image_path=f'{images_path}/{patient.at[0, "Right-Fundus"]}',
                        transform=transform,
                        device=device,
                        label_names=label_names,
                        ground_truth=patient.loc[0, label_names].to_numpy())

# %% [markdown]
# # Zip the experiment data folder, the SummaryWriter folder and the experiment outputs
# This is necessary in order to be able to download this folders

# %%
# import shutil

# shutil.make_archive('experiment_data_compressed',
#                     format="zip",
#                     root_dir='data/')

# shutil.make_archive('runs_compressed',
#                     format="zip",
#                     root_dir='../runs/')

# shutil.make_archive('outputs_compressed',
#                     format="zip",
#                     root_dir='outputs/')
# Out:
# '/content/ODIR-5K-multi-label-classification/experiments/experiment_10/outputs_compressed.zip'
