# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/serdna1/ODIR-5K-multi-label-classification/blob/main/experiments/experiment_6/experiment_6.ipynb)

# %% [markdown]
# # Download GitHub repository and data
# The repo wont be downloading in my local machine, since i already have it there. It will if someone is running this notebook on their own machine, colab, ...

# %%
import os
import zipfile

images_path = 'ODIR-5K-multi-label-classification/data/images/'

# If the experiments folder doesnt exist im not in my local machine
if not os.path.exists('../../experiments'):
    # Clone project repository
    # !git clone https://github.com/serdna1/ODIR-5K-multi-label-classification.git

    # Unzip images
    with zipfile.ZipFile(f'{images_path}/train_fov_cc_fov_224.zip', 'r') as zip_ref:
      print("Unzipping training images...")
      zip_ref.extractall(f'{images_path}/train_fov_cc_fov_224')
    # !rm ODIR-5K-multi-label-classification/data/images/train_fov_cc_fov_224.zip
    # !rm ODIR-5K-multi-label-classification/data/images/train_224.zip

    # Move to the experiment folder
    # %cd ODIR-5K-multi-label-classification/experiments/experiment_7/
# Out:
# Cloning into 'ODIR-5K-multi-label-classification'...
# remote: Enumerating objects: 403, done.
# remote: Counting objects: 100% (158/158), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 403 (delta 79), reused 129 (delta 53), pack-reused 245
# Receiving objects: 100% (403/403), 79.77 MiB | 16.99 MiB/s, done.
# Resolving deltas: 100% (191/191), done.
# Unzipping training images...
# /content/ODIR-5K-multi-label-classification/experiments/experiment_6

# %% [markdown]
# # Drop some special patients from the dataset
# The background of some images is quite different from the rest ones. Therefore they wont be used for training.

# %%
import matplotlib.pyplot as plt
from PIL import Image

images_path = '../../data/images/train_fov_cc_fov_224'

special_images = ['2174_right.jpg', '2175_left.jpg', '2176_left.jpg', '2177_left.jpg',
                  '2177_right.jpg', '2178_right.jpg', '2179_left.jpg', '2179_right.jpg',
                  '2180_left.jpg', '2180_right.jpg', '2181_left.jpg', '2181_right.jpg',
                  '2182_left.jpg', '2182_right.jpg', '2957_left.jpg', '2957_right.jpg']

# Show one of this special images
image_path = f'{images_path}/{special_images[7]}'
img = Image.open(image_path)
plt.imshow(img)
plt.axis(False)
plt.title('Example of special image')
# Out:
# Text(0.5, 1.0, 'Example of special image')

# %%
import pandas as pd

original_annotations_path = '../../data/annotations/annotations.xlsx'
annotations_path = 'data/annotations.xlsx'

odir_df = pd.read_excel(original_annotations_path)

patients_to_drop_df = odir_df[odir_df['Left-Fundus'].isin(special_images) | odir_df['Right-Fundus'].isin(special_images)]
patients_to_drop_df # This are all the patients with one ore more of this spetial images
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1634  2174           65      Female  2174_left.jpg  2174_right.jpg
# 1635  2175           63        Male  2175_left.jpg  2175_right.jpg
# 1636  2176           82      Female  2176_left.jpg  2176_right.jpg
# 1637  2177           87        Male  2177_left.jpg  2177_right.jpg
# 1638  2178           84        Male  2178_left.jpg  2178_right.jpg
# 1639  2179           70      Female  2179_left.jpg  2179_right.jpg
# 1640  2180           66      Female  2180_left.jpg  2180_right.jpg
# 1641  2181           79      Female  2181_left.jpg  2181_right.jpg
# 1642  2182           70        Male  2182_left.jpg  2182_right.jpg
# 2334  2957           62      Female  2957_left.jpg  2957_right.jpg
#
#      Left-Diagnostic Keywords Right-Diagnostic Keywords  N  D  G  C  A  H  M  \
# 1634            normal fundus                  cataract  0  0  0  1  0  0  0
# 1635                 cataract             normal fundus  0  0  0  1  0  0  0
# 1636                 cataract                  cataract  0  0  0  1  0  0  0
# 1637  normal fundus，lens dust                  cataract  0  0  0  1  0  0  0
# 1638                 cataract                  cataract  0  0  0  1  0  0  0
# 1639                 cataract                  cataract  0  0  0  1  0  0  0
# 1640                 cataract                  cataract  0  0  0  1  0  0  0
# 1641                 cataract                  cataract  0  0  0  1  0  0  0
# 1642                 cataract                  cataract  0  0  0  1  0  0  0
# 2334            normal fundus             normal fundus  1  0  0  0  0  0  0
#
#       O
# 1634  0
# 1635  0
# 1636  0
# 1637  0
# 1638  0
# 1639  0
# 1640  0
# 1641  0
# 1642  0
# 2334  0

# %%
from pathlib import Path

experiment_data_path = 'data/'

print(f'Annotations length before droping the rows with the special images: {len(odir_df)}')

odir_df = odir_df.drop(patients_to_drop_df.index) # Drop the special patients
Path(experiment_data_path).mkdir(parents=True, exist_ok=True) # Create the experiment data folder
odir_df.to_excel(annotations_path) # Save annotations without the special patients

print(f'Annotations length after droping the rows with the special images: {len(odir_df)}')
# Out:
# Annotations length before droping the rows with the special images: 3500
# Annotations length after droping the rows with the special images: 3490

# %% [markdown]
# # Check dataset label distribution

# %%
label_names = ['N','D','G','C','A','H','M','O']

total_label_list = []
for label in label_names:
    total_label = int(odir_df.loc[:, [label]].sum())
    total_label_list.append(total_label)

plt.figure(figsize=(16,4))

bar = plt.bar(label_names, total_label_list)

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f}', ha='center', va='bottom')

plt.xlabel(f'Label')
plt.ylabel(f'No. of images')
plt.title(f'Label distribution')
# Out:
# Text(0.5, 1.0, 'Label distribution')

# %% [markdown]
# # Split dataset into train and validation

# %%
os.chdir('../../scripts/')
from utils import split_annotations
os.chdir('../experiments/experiment_7/')

# %%
# Split the original annotations file into train and validation annotations files
# val_ratio = 0.2 (value by default)
split_annotations(annotations_path, experiment_data_path, test_split=False)

# Read the previous three created .xlsx files into dataframes
train_df = pd.read_excel(f'{experiment_data_path}/train_annotations.xlsx')
val_df = pd.read_excel(f'{experiment_data_path}/val_annotations.xlsx')

len(train_df), len(val_df)
# Out:
# (2792, 698)

# %% [markdown]
# # Check train and validation datasets label distribution

# %%
for i, label in enumerate(label_names):
    plt.figure(figsize=(4,4))

    total_label_train = int(train_df.loc[:, [label]].sum())
    total_label_val = int(val_df.loc[:, [label]].sum())

    bar = plt.bar(['Train', 'Val'], [total_label_train, total_label_val])

    for rect in bar:
        height = rect.get_height()
        plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f}', ha='center', va='bottom')

    plt.xlabel(f'Dataset')
    plt.ylabel(f'No. of images with label {label}')
    plt.title(f'Distribution of label {label} by dataset')

# %% [markdown]
# # Train the model

# %%
# %run ../../scripts/train.py -h # Run this line to check the train script arguments
# Out:
# usage: train.py [-h] [--random_seed RANDOM_SEED] [--model_name MODEL_NAME]
#                 [--images_path IMAGES_PATH] [--use_normalization]
#                 [--train_annotations_path TRAIN_ANNOTATIONS_PATH]
#                 [--val_annotations_path VAL_ANNOTATIONS_PATH]
#                 [--batch_size BATCH_SIZE] [--num_workers NUM_WORKERS]
#                 [--lr LR] [--momentum MOMENTUM] [--lr_scheduler LR_SCHEDULER]
#                 [--linear_lr_scheduler_total_iters LINEAR_LR_SCHEDULER_TOTAL_ITERS]
#                 [--linear_lr_scheduler_start_factor LINEAR_LR_SCHEDULER_START_FACTOR]
#                 [--linear_lr_scheduler_end_factor LINEAR_LR_SCHEDULER_END_FACTOR]
#                 [--cyclic_lr_scheduler_base_lr CYCLIC_LR_SCHEDULER_BASE_LR]
#                 [--cyclic_lr_scheduler_max_lr CYCLIC_LR_SCHEDULER_MAX_LR]
#                 [--cyclic_lr_scheduler_step_size_up CYCLIC_LR_SCHEDULER_STEP_SIZE_UP]
#                 [--epochs EPOCHS] [--patience PATIENCE]
#                 [--experiment_name EXPERIMENT_NAME] [--extra EXTRA]
#
# Train a network for image multi-label classification on ODIR-5K.
#
# options:
#   -h, --help            show this help message and exit
#   --random_seed RANDOM_SEED
#                         Sets random seed for reproducibility (default: 42).
#   --model_name MODEL_NAME
#                         Model arquitecture for training (default:
#                         resnet50_dual).
#   --images_path IMAGES_PATH
#                         Path of ODIR training images (default:
#                         /kaggle/input/odir-size-512/odir-size-512).
#   --use_normalization   If set the images are normalized the same way the
#                         imagenet images where normalized to train the resnet50
#                         used here.
#   --train_annotations_path TRAIN_ANNOTATIONS_PATH
#                         Path of train annotations file (default:
#                         /kaggle/input/odir-size-512/train_annotations.xlsx).
#   --val_annotations_path VAL_ANNOTATIONS_PATH
#                         Path of validation annotations file (default:
#                         /kaggle/input/odir-size-512/val_annotations.xlsx).
#   --batch_size BATCH_SIZE
#                         Batch size for data loaders (default: 32).
#   --num_workers NUM_WORKERS
#                         Number of workers for data loaders (default:
#                         os.cpu_count()).
#   --lr LR               Specifies learning rate for optimizer (default: 1e-3).
#   --momentum MOMENTUM   Specifies momentum for optimizer (default: 0.9).
#   --lr_scheduler LR_SCHEDULER
#                         Learning rate scheduler (default: None)
#   --linear_lr_scheduler_total_iters LINEAR_LR_SCHEDULER_TOTAL_ITERS
#                         Number of steps that the linear lr scheduler decays
#                         the learning rate (default: 50).
#   --linear_lr_scheduler_start_factor LINEAR_LR_SCHEDULER_START_FACTOR
#                         Start factor of the linear lr scheduler (default: 1).
#   --linear_lr_scheduler_end_factor LINEAR_LR_SCHEDULER_END_FACTOR
#                         End factor of the linear lr scheduler (default: 0.1).
#   --cyclic_lr_scheduler_base_lr CYCLIC_LR_SCHEDULER_BASE_LR
#                         Initial learning rate which is the lower boundary in
#                         the cycle for each parameter group (default: 0.001).
#   --cyclic_lr_scheduler_max_lr CYCLIC_LR_SCHEDULER_MAX_LR
#                         Upper learning rate boundaries in the cycle for each
#                         parameter group (default: 0.1).
#   --cyclic_lr_scheduler_step_size_up CYCLIC_LR_SCHEDULER_STEP_SIZE_UP
#                         Number of training iterations in the increasing half
#                         of a cycle (default: 10).
#   --epochs EPOCHS       Number of training epochs (default: 5).
#   --patience PATIENCE   How long to wait after last time validation loss
#                         improved (default: 1).
#   --experiment_name EXPERIMENT_NAME
#                         Name of the experiment" (default: experiment_0).
#   --extra EXTRA         Extra info about the experiment (default: None).

# %%
# Arguments that will be passed to the train script
model_name = 'resnet50_dual_v2'
images_path = '../../data/images/train_fov_cc_fov_224'
train_annotations_path = 'data/train_annotations.xlsx'
val_annotations_path = 'data/val_annotations.xlsx'
lr = 0.05
lr_scheduler = 'LinearLR'
batch_size = 32
epochs = 100
patience = 100
experiment_name = 'experiment_7'

# %%
# %run ../../scripts/train.py --model {model_name} --images_path {images_path} --train_annotations_path {train_annotations_path} --val_annotations_path {val_annotations_path}\
                            --batch_size {batch_size} --epochs {epochs} --patience {patience} --experiment_name {experiment_name} --use_normalization --lr {lr}\
                            --lr_scheduler {lr_scheduler}
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 363MB/s]
# [INFO] Created new resnet50_dual_v2 model.
# [INFO] Created SummaryWriter, saving to: ../runs/resnet50_dual_v2/experiment_6...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ep: 0 | t_loss: 0.4307 | t_kappa: -0.0010 | t_f1: 0.1342 | t_auc: 0.4982 | t_final: 0.2105 | v_loss: 0.3606 | v_kappa: 0.0000 | v_f1: 0.0000 | v_auc: 0.5280 | v_final: 0.1760
# Validation loss decreased (inf --> 0.360602).  Saving model ...
# Ep: 1 | t_loss: 0.3574 | t_kappa: 0.0002 | t_f1: 0.0018 | t_auc: 0.5225 | t_final: 0.1748 | v_loss: 0.3526 | v_kappa: 0.0000 | v_f1: 0.0000 | v_auc: 0.5838 | v_final: 0.1946
# Validation loss decreased (0.360602 --> 0.352614).  Saving model ...
# Ep: 2 | t_loss: 0.3495 | t_kappa: 0.0021 | t_f1: 0.0142 | t_auc: 0.5555 | t_final: 0.1906 | v_loss: 0.3451 | v_kappa: 0.0000 | v_f1: 0.0000 | v_auc: 0.6122 | v_final: 0.2041
# Validation loss decreased (0.352614 --> 0.345106).  Saving model ...
# Ep: 3 | t_loss: 0.3426 | t_kappa: 0.0010 | t_f1: 0.0118 | t_auc: 0.5835 | t_final: 0.1988 | v_loss: 0.3385 | v_kappa: 0.0000 | v_f1: 0.0000 | v_auc: 0.6230 | v_final: 0.2077
# Validation loss decreased (0.345106 --> 0.338493).  Saving model ...
# Ep: 4 | t_loss: 0.3322 | t_kappa: 0.0092 | t_f1: 0.0439 | t_auc: 0.6272 | t_final: 0.2268 | v_loss: 0.3333 | v_kappa: 0.0000 | v_f1: 0.0000 | v_auc: 0.6356 | v_final: 0.2119
# Validation loss decreased (0.338493 --> 0.333322).  Saving model ...
# Ep: 5 | t_loss: 0.3281 | t_kappa: 0.0294 | t_f1: 0.0774 | t_auc: 0.6542 | t_final: 0.2537 | v_loss: 0.3260 | v_kappa: 0.0000 | v_f1: 0.0000 | v_auc: 0.6442 | v_final: 0.2147
# Validation loss decreased (0.333322 --> 0.325987).  Saving model ...
# Ep: 6 | t_loss: 0.3207 | t_kappa: 0.0519 | t_f1: 0.1343 | t_auc: 0.6685 | t_final: 0.2849 | v_loss: 0.3247 | v_kappa: 0.0008 | v_f1: 0.0048 | v_auc: 0.6529 | v_final: 0.2195
# Validation loss decreased (0.325987 --> 0.324680).  Saving model ...
# Ep: 7 | t_loss: 0.3173 | t_kappa: 0.0645 | t_f1: 0.1420 | t_auc: 0.6797 | t_final: 0.2954 | v_loss: 0.3209 | v_kappa: 0.0065 | v_f1: 0.0228 | v_auc: 0.6595 | v_final: 0.2296
# Validation loss decreased (0.324680 --> 0.320897).  Saving model ...
# Ep: 8 | t_loss: 0.3078 | t_kappa: 0.0883 | t_f1: 0.1779 | t_auc: 0.7061 | t_final: 0.3241 | v_loss: 0.3164 | v_kappa: 0.0945 | v_f1: 0.1163 | v_auc: 0.6597 | v_final: 0.2902
# Validation loss decreased (0.320897 --> 0.316423).  Saving model ...
# Ep: 9 | t_loss: 0.3081 | t_kappa: 0.1189 | t_f1: 0.2107 | t_auc: 0.7026 | t_final: 0.3441 | v_loss: 0.3151 | v_kappa: 0.1369 | v_f1: 0.1011 | v_auc: 0.6635 | v_final: 0.3005
# Validation loss decreased (0.316423 --> 0.315110).  Saving model ...
# Ep: 10 | t_loss: 0.2999 | t_kappa: 0.1591 | t_f1: 0.2345 | t_auc: 0.7234 | t_final: 0.3723 | v_loss: 0.3106 | v_kappa: 0.1377 | v_f1: 0.1067 | v_auc: 0.6695 | v_final: 0.3046
# Validation loss decreased (0.315110 --> 0.310642).  Saving model ...
# Ep: 11 | t_loss: 0.2964 | t_kappa: 0.1950 | t_f1: 0.2745 | t_auc: 0.7323 | t_final: 0.4006 | v_loss: 0.3108 | v_kappa: 0.1472 | v_f1: 0.1548 | v_auc: 0.6748 | v_final: 0.3256
# EarlyStopping counter: 1 out of 100
# Ep: 12 | t_loss: 0.2905 | t_kappa: 0.2159 | t_f1: 0.2987 | t_auc: 0.7504 | t_final: 0.4217 | v_loss: 0.3123 | v_kappa: 0.1685 | v_f1: 0.1606 | v_auc: 0.6824 | v_final: 0.3372
# EarlyStopping counter: 2 out of 100
# Ep: 13 | t_loss: 0.2836 | t_kappa: 0.2283 | t_f1: 0.3120 | t_auc: 0.7572 | t_final: 0.4325 | v_loss: 0.3076 | v_kappa: 0.1850 | v_f1: 0.2442 | v_auc: 0.6801 | v_final: 0.3698
# Validation loss decreased (0.310642 --> 0.307559).  Saving model ...
# Ep: 14 | t_loss: 0.2787 | t_kappa: 0.2469 | t_f1: 0.3400 | t_auc: 0.7648 | t_final: 0.4506 | v_loss: 0.3068 | v_kappa: 0.1889 | v_f1: 0.2145 | v_auc: 0.6809 | v_final: 0.3615
# Validation loss decreased (0.307559 --> 0.306821).  Saving model ...
# Ep: 15 | t_loss: 0.2761 | t_kappa: 0.2583 | t_f1: 0.3570 | t_auc: 0.7783 | t_final: 0.4646 | v_loss: 0.3069 | v_kappa: 0.2341 | v_f1: 0.2664 | v_auc: 0.6800 | v_final: 0.3935
# EarlyStopping counter: 1 out of 100
# Ep: 16 | t_loss: 0.2716 | t_kappa: 0.2618 | t_f1: 0.3646 | t_auc: 0.7833 | t_final: 0.4699 | v_loss: 0.3094 | v_kappa: 0.2200 | v_f1: 0.2875 | v_auc: 0.6842 | v_final: 0.3972
# EarlyStopping counter: 2 out of 100
# Ep: 17 | t_loss: 0.2657 | t_kappa: 0.2751 | t_f1: 0.3950 | t_auc: 0.7957 | t_final: 0.4886 | v_loss: 0.3102 | v_kappa: 0.2151 | v_f1: 0.2827 | v_auc: 0.6836 | v_final: 0.3938
# EarlyStopping counter: 3 out of 100
# Ep: 18 | t_loss: 0.2614 | t_kappa: 0.3016 | t_f1: 0.4091 | t_auc: 0.8007 | t_final: 0.5038 | v_loss: 0.3068 | v_kappa: 0.2265 | v_f1: 0.2628 | v_auc: 0.6855 | v_final: 0.3916
# Validation loss decreased (0.306821 --> 0.306796).  Saving model ...
# Ep: 19 | t_loss: 0.2577 | t_kappa: 0.3109 | t_f1: 0.4289 | t_auc: 0.8060 | t_final: 0.5153 | v_loss: 0.3089 | v_kappa: 0.2389 | v_f1: 0.2767 | v_auc: 0.6844 | v_final: 0.4000
# EarlyStopping counter: 1 out of 100
# Ep: 20 | t_loss: 0.2555 | t_kappa: 0.3115 | t_f1: 0.4228 | t_auc: 0.8122 | t_final: 0.5155 | v_loss: 0.3091 | v_kappa: 0.2295 | v_f1: 0.3008 | v_auc: 0.6893 | v_final: 0.4065
# EarlyStopping counter: 2 out of 100
# Ep: 21 | t_loss: 0.2536 | t_kappa: 0.3181 | t_f1: 0.4314 | t_auc: 0.8133 | t_final: 0.5209 | v_loss: 0.3065 | v_kappa: 0.2353 | v_f1: 0.2894 | v_auc: 0.6823 | v_final: 0.4023
# Validation loss decreased (0.306796 --> 0.306456).  Saving model ...
# Ep: 22 | t_loss: 0.2442 | t_kappa: 0.3385 | t_f1: 0.4629 | t_auc: 0.8298 | t_final: 0.5437 | v_loss: 0.3106 | v_kappa: 0.2304 | v_f1: 0.3025 | v_auc: 0.6820 | v_final: 0.4049
# EarlyStopping counter: 1 out of 100
# Ep: 23 | t_loss: 0.2455 | t_kappa: 0.3356 | t_f1: 0.4577 | t_auc: 0.8301 | t_final: 0.5411 | v_loss: 0.3108 | v_kappa: 0.2349 | v_f1: 0.3057 | v_auc: 0.6755 | v_final: 0.4054
# EarlyStopping counter: 2 out of 100
# Ep: 24 | t_loss: 0.2426 | t_kappa: 0.3381 | t_f1: 0.4672 | t_auc: 0.8355 | t_final: 0.5469 | v_loss: 0.3244 | v_kappa: 0.2187 | v_f1: 0.2686 | v_auc: 0.6831 | v_final: 0.3901
# EarlyStopping counter: 3 out of 100
# Ep: 25 | t_loss: 0.2400 | t_kappa: 0.3607 | t_f1: 0.4832 | t_auc: 0.8380 | t_final: 0.5606 | v_loss: 0.3111 | v_kappa: 0.2314 | v_f1: 0.2908 | v_auc: 0.6825 | v_final: 0.4016
# EarlyStopping counter: 4 out of 100
# Ep: 26 | t_loss: 0.2341 | t_kappa: 0.3759 | t_f1: 0.4986 | t_auc: 0.8476 | t_final: 0.5740 | v_loss: 0.3223 | v_kappa: 0.2426 | v_f1: 0.3391 | v_auc: 0.6807 | v_final: 0.4208
# EarlyStopping counter: 5 out of 100
# Ep: 27 | t_loss: 0.2301 | t_kappa: 0.3780 | t_f1: 0.5166 | t_auc: 0.8513 | t_final: 0.5820 | v_loss: 0.3132 | v_kappa: 0.2376 | v_f1: 0.3141 | v_auc: 0.6832 | v_final: 0.4116
# EarlyStopping counter: 6 out of 100
# Ep: 28 | t_loss: 0.2284 | t_kappa: 0.3852 | t_f1: 0.5180 | t_auc: 0.8560 | t_final: 0.5864 | v_loss: 0.3229 | v_kappa: 0.2329 | v_f1: 0.3187 | v_auc: 0.6721 | v_final: 0.4079
# EarlyStopping counter: 7 out of 100
# Ep: 29 | t_loss: 0.2277 | t_kappa: 0.3903 | t_f1: 0.5169 | t_auc: 0.8568 | t_final: 0.5880 | v_loss: 0.3192 | v_kappa: 0.2552 | v_f1: 0.3265 | v_auc: 0.6834 | v_final: 0.4217
# EarlyStopping counter: 8 out of 100
# Ep: 30 | t_loss: 0.2202 | t_kappa: 0.4092 | t_f1: 0.5446 | t_auc: 0.8667 | t_final: 0.6068 | v_loss: 0.3272 | v_kappa: 0.2245 | v_f1: 0.3192 | v_auc: 0.6668 | v_final: 0.4035
# EarlyStopping counter: 9 out of 100
# Ep: 31 | t_loss: 0.2191 | t_kappa: 0.4152 | t_f1: 0.5480 | t_auc: 0.8656 | t_final: 0.6096 | v_loss: 0.3270 | v_kappa: 0.2464 | v_f1: 0.3386 | v_auc: 0.6840 | v_final: 0.4230
# EarlyStopping counter: 10 out of 100
# Ep: 32 | t_loss: 0.2149 | t_kappa: 0.4336 | t_f1: 0.5664 | t_auc: 0.8722 | t_final: 0.6241 | v_loss: 0.3437 | v_kappa: 0.2397 | v_f1: 0.3014 | v_auc: 0.6744 | v_final: 0.4051
# EarlyStopping counter: 11 out of 100
# Ep: 33 | t_loss: 0.2108 | t_kappa: 0.4288 | t_f1: 0.5688 | t_auc: 0.8792 | t_final: 0.6256 | v_loss: 0.3349 | v_kappa: 0.2427 | v_f1: 0.3190 | v_auc: 0.6837 | v_final: 0.4151
# EarlyStopping counter: 12 out of 100
# Ep: 34 | t_loss: 0.2094 | t_kappa: 0.4361 | t_f1: 0.5783 | t_auc: 0.8835 | t_final: 0.6326 | v_loss: 0.3366 | v_kappa: 0.2386 | v_f1: 0.3351 | v_auc: 0.6632 | v_final: 0.4123
# EarlyStopping counter: 13 out of 100
# Ep: 35 | t_loss: 0.2095 | t_kappa: 0.4560 | t_f1: 0.5918 | t_auc: 0.8806 | t_final: 0.6428 | v_loss: 0.3235 | v_kappa: 0.2585 | v_f1: 0.3367 | v_auc: 0.6774 | v_final: 0.4242
# EarlyStopping counter: 14 out of 100
# Ep: 36 | t_loss: 0.2093 | t_kappa: 0.4498 | t_f1: 0.5834 | t_auc: 0.8807 | t_final: 0.6380 | v_loss: 0.3360 | v_kappa: 0.2568 | v_f1: 0.3458 | v_auc: 0.6768 | v_final: 0.4265
# EarlyStopping counter: 15 out of 100
# Ep: 37 | t_loss: 0.2036 | t_kappa: 0.4692 | t_f1: 0.6154 | t_auc: 0.8888 | t_final: 0.6578 | v_loss: 0.3358 | v_kappa: 0.2451 | v_f1: 0.3405 | v_auc: 0.6763 | v_final: 0.4207
# EarlyStopping counter: 16 out of 100
# Ep: 38 | t_loss: 0.2029 | t_kappa: 0.4754 | t_f1: 0.6154 | t_auc: 0.8879 | t_final: 0.6596 | v_loss: 0.3263 | v_kappa: 0.2609 | v_f1: 0.3619 | v_auc: 0.6860 | v_final: 0.4363
# EarlyStopping counter: 17 out of 100
# Ep: 39 | t_loss: 0.1946 | t_kappa: 0.4898 | t_f1: 0.6396 | t_auc: 0.8962 | t_final: 0.6752 | v_loss: 0.3355 | v_kappa: 0.2519 | v_f1: 0.3482 | v_auc: 0.6858 | v_final: 0.4286
# EarlyStopping counter: 18 out of 100
# Ep: 40 | t_loss: 0.1910 | t_kappa: 0.4742 | t_f1: 0.6205 | t_auc: 0.9007 | t_final: 0.6651 | v_loss: 0.3333 | v_kappa: 0.2577 | v_f1: 0.3607 | v_auc: 0.6866 | v_final: 0.4350
# EarlyStopping counter: 19 out of 100
# Ep: 41 | t_loss: 0.1868 | t_kappa: 0.4949 | t_f1: 0.6415 | t_auc: 0.9041 | t_final: 0.6802 | v_loss: 0.3380 | v_kappa: 0.2673 | v_f1: 0.3631 | v_auc: 0.6819 | v_final: 0.4374
# EarlyStopping counter: 20 out of 100
# Ep: 42 | t_loss: 0.1885 | t_kappa: 0.5062 | t_f1: 0.6558 | t_auc: 0.9047 | t_final: 0.6889 | v_loss: 0.3308 | v_kappa: 0.2682 | v_f1: 0.3546 | v_auc: 0.6806 | v_final: 0.4345
# EarlyStopping counter: 21 out of 100
# Ep: 43 | t_loss: 0.1871 | t_kappa: 0.5108 | t_f1: 0.6537 | t_auc: 0.9037 | t_final: 0.6894 | v_loss: 0.3422 | v_kappa: 0.2294 | v_f1: 0.3531 | v_auc: 0.6762 | v_final: 0.4196
# EarlyStopping counter: 22 out of 100
# Ep: 44 | t_loss: 0.1840 | t_kappa: 0.5082 | t_f1: 0.6508 | t_auc: 0.9091 | t_final: 0.6894 | v_loss: 0.3413 | v_kappa: 0.2627 | v_f1: 0.3425 | v_auc: 0.6780 | v_final: 0.4277
# EarlyStopping counter: 23 out of 100
# Ep: 45 | t_loss: 0.1857 | t_kappa: 0.4973 | t_f1: 0.6457 | t_auc: 0.9087 | t_final: 0.6839 | v_loss: 0.3437 | v_kappa: 0.2622 | v_f1: 0.3618 | v_auc: 0.6767 | v_final: 0.4336
# EarlyStopping counter: 24 out of 100
# Ep: 46 | t_loss: 0.1767 | t_kappa: 0.5233 | t_f1: 0.6676 | t_auc: 0.9162 | t_final: 0.7024 | v_loss: 0.3478 | v_kappa: 0.2566 | v_f1: 0.3357 | v_auc: 0.6762 | v_final: 0.4228
# EarlyStopping counter: 25 out of 100
# Ep: 47 | t_loss: 0.1778 | t_kappa: 0.5152 | t_f1: 0.6686 | t_auc: 0.9154 | t_final: 0.6997 | v_loss: 0.3463 | v_kappa: 0.2657 | v_f1: 0.3600 | v_auc: 0.6772 | v_final: 0.4343
# EarlyStopping counter: 26 out of 100
# Ep: 48 | t_loss: 0.1784 | t_kappa: 0.5117 | t_f1: 0.6708 | t_auc: 0.9158 | t_final: 0.6994 | v_loss: 0.3531 | v_kappa: 0.2699 | v_f1: 0.3741 | v_auc: 0.6811 | v_final: 0.4417
# EarlyStopping counter: 27 out of 100
# Ep: 49 | t_loss: 0.1726 | t_kappa: 0.5381 | t_f1: 0.6862 | t_auc: 0.9222 | t_final: 0.7155 | v_loss: 0.3539 | v_kappa: 0.2705 | v_f1: 0.3789 | v_auc: 0.6818 | v_final: 0.4438
# EarlyStopping counter: 28 out of 100
# Ep: 50 | t_loss: 0.1728 | t_kappa: 0.5337 | t_f1: 0.6895 | t_auc: 0.9224 | t_final: 0.7152 | v_loss: 0.3481 | v_kappa: 0.2587 | v_f1: 0.3645 | v_auc: 0.6690 | v_final: 0.4307
# EarlyStopping counter: 29 out of 100
# Ep: 51 | t_loss: 0.1730 | t_kappa: 0.5353 | t_f1: 0.6918 | t_auc: 0.9200 | t_final: 0.7157 | v_loss: 0.3463 | v_kappa: 0.2737 | v_f1: 0.3742 | v_auc: 0.6786 | v_final: 0.4422
# EarlyStopping counter: 30 out of 100
# Ep: 52 | t_loss: 0.1727 | t_kappa: 0.5350 | t_f1: 0.6823 | t_auc: 0.9207 | t_final: 0.7127 | v_loss: 0.3395 | v_kappa: 0.2780 | v_f1: 0.3788 | v_auc: 0.6872 | v_final: 0.4480
# EarlyStopping counter: 31 out of 100
# Ep: 53 | t_loss: 0.1721 | t_kappa: 0.5348 | t_f1: 0.6885 | t_auc: 0.9244 | t_final: 0.7159 | v_loss: 0.3556 | v_kappa: 0.2597 | v_f1: 0.3753 | v_auc: 0.6673 | v_final: 0.4341
# EarlyStopping counter: 32 out of 100
# Ep: 54 | t_loss: 0.1703 | t_kappa: 0.5384 | t_f1: 0.6984 | t_auc: 0.9245 | t_final: 0.7204 | v_loss: 0.3545 | v_kappa: 0.2716 | v_f1: 0.3671 | v_auc: 0.6765 | v_final: 0.4384
# EarlyStopping counter: 33 out of 100
# Ep: 55 | t_loss: 0.1703 | t_kappa: 0.5365 | t_f1: 0.6853 | t_auc: 0.9238 | t_final: 0.7152 | v_loss: 0.3511 | v_kappa: 0.2666 | v_f1: 0.3886 | v_auc: 0.6816 | v_final: 0.4456
# EarlyStopping counter: 34 out of 100
# Ep: 56 | t_loss: 0.1716 | t_kappa: 0.5322 | t_f1: 0.6864 | t_auc: 0.9230 | t_final: 0.7139 | v_loss: 0.3554 | v_kappa: 0.2752 | v_f1: 0.3863 | v_auc: 0.6770 | v_final: 0.4461
# EarlyStopping counter: 35 out of 100
# Ep: 57 | t_loss: 0.1646 | t_kappa: 0.5463 | t_f1: 0.7027 | t_auc: 0.9299 | t_final: 0.7263 | v_loss: 0.3423 | v_kappa: 0.2974 | v_f1: 0.4010 | v_auc: 0.6889 | v_final: 0.4625
# EarlyStopping counter: 36 out of 100
# Ep: 58 | t_loss: 0.1681 | t_kappa: 0.5493 | t_f1: 0.7038 | t_auc: 0.9261 | t_final: 0.7264 | v_loss: 0.3529 | v_kappa: 0.2702 | v_f1: 0.3700 | v_auc: 0.6750 | v_final: 0.4384
# EarlyStopping counter: 37 out of 100
# Ep: 59 | t_loss: 0.1612 | t_kappa: 0.5579 | t_f1: 0.7168 | t_auc: 0.9323 | t_final: 0.7356 | v_loss: 0.3573 | v_kappa: 0.2680 | v_f1: 0.3687 | v_auc: 0.6790 | v_final: 0.4385
# EarlyStopping counter: 38 out of 100
# Ep: 60 | t_loss: 0.1697 | t_kappa: 0.5425 | t_f1: 0.6991 | t_auc: 0.9250 | t_final: 0.7222 | v_loss: 0.3618 | v_kappa: 0.2769 | v_f1: 0.3794 | v_auc: 0.6717 | v_final: 0.4427
# EarlyStopping counter: 39 out of 100
# Ep: 61 | t_loss: 0.1624 | t_kappa: 0.5413 | t_f1: 0.7101 | t_auc: 0.9337 | t_final: 0.7284 | v_loss: 0.3625 | v_kappa: 0.2705 | v_f1: 0.3891 | v_auc: 0.6760 | v_final: 0.4452
# EarlyStopping counter: 40 out of 100
# Ep: 62 | t_loss: 0.1654 | t_kappa: 0.5510 | t_f1: 0.7131 | t_auc: 0.9299 | t_final: 0.7314 | v_loss: 0.3587 | v_kappa: 0.2695 | v_f1: 0.3852 | v_auc: 0.6761 | v_final: 0.4436
# EarlyStopping counter: 41 out of 100
# Ep: 63 | t_loss: 0.1654 | t_kappa: 0.5451 | t_f1: 0.7052 | t_auc: 0.9301 | t_final: 0.7268 | v_loss: 0.3464 | v_kappa: 0.2625 | v_f1: 0.3673 | v_auc: 0.6861 | v_final: 0.4387
# EarlyStopping counter: 42 out of 100
# Ep: 64 | t_loss: 0.1642 | t_kappa: 0.5500 | t_f1: 0.7072 | t_auc: 0.9306 | t_final: 0.7293 | v_loss: 0.3606 | v_kappa: 0.2538 | v_f1: 0.3697 | v_auc: 0.6786 | v_final: 0.4340
# EarlyStopping counter: 43 out of 100
# Ep: 65 | t_loss: 0.1628 | t_kappa: 0.5492 | t_f1: 0.7102 | t_auc: 0.9323 | t_final: 0.7306 | v_loss: 0.3566 | v_kappa: 0.2847 | v_f1: 0.4002 | v_auc: 0.6849 | v_final: 0.4566
# EarlyStopping counter: 44 out of 100
# Ep: 66 | t_loss: 0.1610 | t_kappa: 0.5617 | t_f1: 0.7166 | t_auc: 0.9302 | t_final: 0.7362 | v_loss: 0.3575 | v_kappa: 0.2781 | v_f1: 0.3955 | v_auc: 0.6841 | v_final: 0.4526
# EarlyStopping counter: 45 out of 100
# Ep: 67 | t_loss: 0.1606 | t_kappa: 0.5572 | t_f1: 0.7178 | t_auc: 0.9317 | t_final: 0.7356 | v_loss: 0.3516 | v_kappa: 0.2571 | v_f1: 0.3661 | v_auc: 0.6851 | v_final: 0.4361
# EarlyStopping counter: 46 out of 100
# Ep: 68 | t_loss: 0.1572 | t_kappa: 0.5635 | t_f1: 0.7249 | t_auc: 0.9365 | t_final: 0.7416 | v_loss: 0.3603 | v_kappa: 0.2838 | v_f1: 0.3809 | v_auc: 0.6814 | v_final: 0.4487
# EarlyStopping counter: 47 out of 100
# Ep: 69 | t_loss: 0.1597 | t_kappa: 0.5530 | t_f1: 0.7161 | t_auc: 0.9345 | t_final: 0.7345 | v_loss: 0.3599 | v_kappa: 0.2840 | v_f1: 0.3912 | v_auc: 0.6753 | v_final: 0.4502
# EarlyStopping counter: 48 out of 100
# Ep: 70 | t_loss: 0.1597 | t_kappa: 0.5624 | t_f1: 0.7218 | t_auc: 0.9333 | t_final: 0.7392 | v_loss: 0.3780 | v_kappa: 0.2755 | v_f1: 0.3822 | v_auc: 0.6789 | v_final: 0.4455
# EarlyStopping counter: 49 out of 100
# Ep: 71 | t_loss: 0.1555 | t_kappa: 0.5641 | t_f1: 0.7202 | t_auc: 0.9354 | t_final: 0.7399 | v_loss: 0.3610 | v_kappa: 0.2726 | v_f1: 0.3875 | v_auc: 0.6835 | v_final: 0.4479
# EarlyStopping counter: 50 out of 100
# Ep: 72 | t_loss: 0.1552 | t_kappa: 0.5703 | t_f1: 0.7329 | t_auc: 0.9393 | t_final: 0.7475 | v_loss: 0.3773 | v_kappa: 0.2582 | v_f1: 0.3732 | v_auc: 0.6744 | v_final: 0.4352
# EarlyStopping counter: 51 out of 100
# Ep: 73 | t_loss: 0.1536 | t_kappa: 0.5771 | t_f1: 0.7364 | t_auc: 0.9374 | t_final: 0.7503 | v_loss: 0.3698 | v_kappa: 0.2706 | v_f1: 0.3794 | v_auc: 0.6808 | v_final: 0.4436
# EarlyStopping counter: 52 out of 100
# Ep: 74 | t_loss: 0.1517 | t_kappa: 0.5629 | t_f1: 0.7218 | t_auc: 0.9403 | t_final: 0.7417 | v_loss: 0.3688 | v_kappa: 0.2813 | v_f1: 0.3871 | v_auc: 0.6852 | v_final: 0.4512
# EarlyStopping counter: 53 out of 100
# Ep: 75 | t_loss: 0.1516 | t_kappa: 0.5742 | t_f1: 0.7366 | t_auc: 0.9412 | t_final: 0.7507 | v_loss: 0.3704 | v_kappa: 0.2736 | v_f1: 0.3841 | v_auc: 0.6822 | v_final: 0.4466
# EarlyStopping counter: 54 out of 100
# Ep: 76 | t_loss: 0.1500 | t_kappa: 0.5871 | t_f1: 0.7455 | t_auc: 0.9413 | t_final: 0.7579 | v_loss: 0.3663 | v_kappa: 0.2675 | v_f1: 0.3820 | v_auc: 0.6767 | v_final: 0.4421
# EarlyStopping counter: 55 out of 100
# Ep: 77 | t_loss: 0.1520 | t_kappa: 0.5688 | t_f1: 0.7373 | t_auc: 0.9414 | t_final: 0.7491 | v_loss: 0.3637 | v_kappa: 0.2733 | v_f1: 0.3745 | v_auc: 0.6841 | v_final: 0.4439
# EarlyStopping counter: 56 out of 100
# Ep: 78 | t_loss: 0.1595 | t_kappa: 0.5678 | t_f1: 0.7239 | t_auc: 0.9350 | t_final: 0.7422 | v_loss: 0.3649 | v_kappa: 0.2685 | v_f1: 0.3831 | v_auc: 0.6841 | v_final: 0.4452
# EarlyStopping counter: 57 out of 100
# Ep: 79 | t_loss: 0.1520 | t_kappa: 0.5786 | t_f1: 0.7388 | t_auc: 0.9416 | t_final: 0.7530 | v_loss: 0.3633 | v_kappa: 0.2712 | v_f1: 0.3997 | v_auc: 0.6888 | v_final: 0.4532
# EarlyStopping counter: 58 out of 100
# Ep: 80 | t_loss: 0.1514 | t_kappa: 0.5679 | t_f1: 0.7316 | t_auc: 0.9407 | t_final: 0.7467 | v_loss: 0.3674 | v_kappa: 0.2710 | v_f1: 0.3852 | v_auc: 0.6761 | v_final: 0.4441
# EarlyStopping counter: 59 out of 100
# Ep: 81 | t_loss: 0.1506 | t_kappa: 0.5749 | t_f1: 0.7390 | t_auc: 0.9426 | t_final: 0.7522 | v_loss: 0.3626 | v_kappa: 0.2880 | v_f1: 0.3980 | v_auc: 0.6892 | v_final: 0.4584
# EarlyStopping counter: 60 out of 100
# Ep: 82 | t_loss: 0.1458 | t_kappa: 0.5859 | t_f1: 0.7522 | t_auc: 0.9460 | t_final: 0.7614 | v_loss: 0.3696 | v_kappa: 0.2624 | v_f1: 0.3814 | v_auc: 0.6799 | v_final: 0.4412
# EarlyStopping counter: 61 out of 100
# Ep: 83 | t_loss: 0.1494 | t_kappa: 0.5869 | t_f1: 0.7471 | t_auc: 0.9445 | t_final: 0.7595 | v_loss: 0.3656 | v_kappa: 0.2917 | v_f1: 0.4126 | v_auc: 0.6865 | v_final: 0.4636
# EarlyStopping counter: 62 out of 100
# Ep: 84 | t_loss: 0.1504 | t_kappa: 0.5821 | t_f1: 0.7460 | t_auc: 0.9443 | t_final: 0.7575 | v_loss: 0.3856 | v_kappa: 0.2633 | v_f1: 0.3739 | v_auc: 0.6748 | v_final: 0.4374
# EarlyStopping counter: 63 out of 100
# Ep: 85 | t_loss: 0.1464 | t_kappa: 0.5950 | t_f1: 0.7533 | t_auc: 0.9454 | t_final: 0.7646 | v_loss: 0.3713 | v_kappa: 0.2739 | v_f1: 0.3806 | v_auc: 0.6837 | v_final: 0.4461
# EarlyStopping counter: 64 out of 100
# Ep: 86 | t_loss: 0.1471 | t_kappa: 0.5923 | t_f1: 0.7483 | t_auc: 0.9448 | t_final: 0.7618 | v_loss: 0.3709 | v_kappa: 0.2819 | v_f1: 0.3975 | v_auc: 0.6860 | v_final: 0.4551
# EarlyStopping counter: 65 out of 100
# Ep: 87 | t_loss: 0.1419 | t_kappa: 0.5982 | t_f1: 0.7597 | t_auc: 0.9493 | t_final: 0.7691 | v_loss: 0.3729 | v_kappa: 0.2679 | v_f1: 0.3815 | v_auc: 0.6776 | v_final: 0.4423
# EarlyStopping counter: 66 out of 100
# Ep: 88 | t_loss: 0.1472 | t_kappa: 0.5836 | t_f1: 0.7480 | t_auc: 0.9463 | t_final: 0.7593 | v_loss: 0.3719 | v_kappa: 0.2745 | v_f1: 0.3813 | v_auc: 0.6741 | v_final: 0.4433
# EarlyStopping counter: 67 out of 100
# Ep: 89 | t_loss: 0.1487 | t_kappa: 0.5914 | t_f1: 0.7504 | t_auc: 0.9468 | t_final: 0.7629 | v_loss: 0.3626 | v_kappa: 0.2802 | v_f1: 0.3921 | v_auc: 0.6850 | v_final: 0.4524
# EarlyStopping counter: 68 out of 100
# Ep: 90 | t_loss: 0.1443 | t_kappa: 0.5975 | t_f1: 0.7593 | t_auc: 0.9484 | t_final: 0.7684 | v_loss: 0.3797 | v_kappa: 0.2692 | v_f1: 0.3808 | v_auc: 0.6748 | v_final: 0.4416
# EarlyStopping counter: 69 out of 100
# Ep: 91 | t_loss: 0.1431 | t_kappa: 0.6006 | t_f1: 0.7619 | t_auc: 0.9497 | t_final: 0.7707 | v_loss: 0.3827 | v_kappa: 0.2717 | v_f1: 0.3912 | v_auc: 0.6772 | v_final: 0.4467
# EarlyStopping counter: 70 out of 100
# Ep: 92 | t_loss: 0.1409 | t_kappa: 0.6017 | t_f1: 0.7576 | t_auc: 0.9481 | t_final: 0.7691 | v_loss: 0.3740 | v_kappa: 0.2683 | v_f1: 0.3846 | v_auc: 0.6805 | v_final: 0.4445
# EarlyStopping counter: 71 out of 100
# Ep: 93 | t_loss: 0.1421 | t_kappa: 0.6004 | t_f1: 0.7587 | t_auc: 0.9492 | t_final: 0.7694 | v_loss: 0.3881 | v_kappa: 0.2634 | v_f1: 0.3830 | v_auc: 0.6717 | v_final: 0.4394
# EarlyStopping counter: 72 out of 100
# Ep: 94 | t_loss: 0.1473 | t_kappa: 0.6028 | t_f1: 0.7550 | t_auc: 0.9450 | t_final: 0.7676 | v_loss: 0.3779 | v_kappa: 0.2766 | v_f1: 0.3832 | v_auc: 0.6708 | v_final: 0.4435
# EarlyStopping counter: 73 out of 100
# Ep: 95 | t_loss: 0.1434 | t_kappa: 0.6038 | t_f1: 0.7568 | t_auc: 0.9477 | t_final: 0.7694 | v_loss: 0.3738 | v_kappa: 0.2801 | v_f1: 0.3886 | v_auc: 0.6831 | v_final: 0.4506
# EarlyStopping counter: 74 out of 100
# Ep: 96 | t_loss: 0.1438 | t_kappa: 0.6026 | t_f1: 0.7601 | t_auc: 0.9484 | t_final: 0.7704 | v_loss: 0.3846 | v_kappa: 0.2581 | v_f1: 0.3812 | v_auc: 0.6787 | v_final: 0.4393
# EarlyStopping counter: 75 out of 100
# Ep: 97 | t_loss: 0.1393 | t_kappa: 0.6121 | t_f1: 0.7752 | t_auc: 0.9524 | t_final: 0.7799 | v_loss: 0.3884 | v_kappa: 0.2674 | v_f1: 0.3780 | v_auc: 0.6713 | v_final: 0.4389
# EarlyStopping counter: 76 out of 100
# Ep: 98 | t_loss: 0.1416 | t_kappa: 0.6075 | t_f1: 0.7626 | t_auc: 0.9513 | t_final: 0.7738 | v_loss: 0.3902 | v_kappa: 0.2624 | v_f1: 0.3853 | v_auc: 0.6688 | v_final: 0.4388
# EarlyStopping counter: 77 out of 100
# Ep: 99 | t_loss: 0.1418 | t_kappa: 0.6077 | t_f1: 0.7635 | t_auc: 0.9496 | t_final: 0.7736 | v_loss: 0.3783 | v_kappa: 0.2662 | v_f1: 0.3779 | v_auc: 0.6837 | v_final: 0.4426
# EarlyStopping counter: 78 out of 100

# %% [markdown]
# Run the next cell to see the metrics trough the epochs using the tensorboard interface

# %%
# %reload_ext tensorboard
# %tensorboard --logdir ../runs

# %% [markdown]
# # Test the model with the validation dataset
# Since there is no access to the test annotatations (only to the images) the test will be performed on the validation dataset, to be able to see some results.

# %%
# %run ../../scripts/test.py -h # Run this line to check the test script arguments
# Out:
# usage: test.py [-h] [--model_name MODEL_NAME] [--model_path MODEL_PATH]
#                [--images_path IMAGES_PATH]
#                [--test_annotations_path TEST_ANNOTATIONS_PATH]
#                [--use_normalization] [--batch_size BATCH_SIZE]
#                [--num_workers NUM_WORKERS]
#                [--ground_truth_path GROUND_TRUTH_PATH]
#                [--probs_path PROBS_PATH]
#
# Test a model with a dataset.
#
# options:
#   -h, --help            show this help message and exit
#   --model_name MODEL_NAME
#                         Model arquitecture for testing (default:
#                         resnet50_dual).
#   --model_path MODEL_PATH
#                         Path to the model to test the dataset with (default:
#                         outputs/resnet50_dual_experiment_0_model.pth).
#   --images_path IMAGES_PATH
#                         Path of test images (default:
#                         ../../data/train_fov_cc_fov_224/).
#   --test_annotations_path TEST_ANNOTATIONS_PATH
#                         Path of test annotations file (default:
#                         data/test_annotations.xlsx).
#   --use_normalization   If set the images are normalized the same way the
#                         imagenet images were normalized to train the resnet50
#                         used here.
#   --batch_size BATCH_SIZE
#                         Batch size for data loaders (default: 32).
#   --num_workers NUM_WORKERS
#                         Number of workers for data loaders (default:
#                         os.cpu_count()).
#   --ground_truth_path GROUND_TRUTH_PATH
#                         Path to store the ground truth labels used in test
#                         (default: None).
#   --probs_path PROBS_PATH
#                         Path to store the result probs of test (default:
#                         None).

# %%
test_annotations_path = 'data/val_annotations.xlsx' # val annotations are used for test
images_path = '../../data/images/train_fov_cc_fov_224'
model_path = 'outputs/resnet50_dual_v2_experiment_7_model.pth'
ground_truth_path = 'outputs/ground_truth.xlsx'
probs_path = 'outputs/probs.xlsx'

# %%
# %run ../../scripts/test.py --model_path {model_path} --model_name {model_name} --images_path {images_path} --test_annotations_path {test_annotations_path} --use_normalization\
                           --ground_truth_path {ground_truth_path} --probs_path {probs_path}
# Out:
# [INFO] Created new resnet50_dual_v2 model.
# test_loss: 0.3065 | test_kappa: 0.2353 | test_f1: 0.2894 | test_auc: 0.6823 | test_final: 0.4023

# %% [markdown]
# # Run the ODIR_evaluation.py script on test (validation) dataset
# This is a file provided along with the data by the challenge. And its supposed to have an example on how to compute the kappa, f1, auc, and final score metrics but i dont think they are well computed here as they are always too good (as shown later, the cualitative results for test are much worst). As a result of this, i use my own version of this metrics (see the function compute_challenge_metrics on the metrics script). Either way i'll run it.

# %%
ground_truth_path = 'outputs/ground_truth.xlsx'
probs_path = 'outputs/probs.xlsx'
probs_csv_path = 'outputs/probs.csv'

probs_df = pd.read_excel(probs_path)
probs_df.to_csv(probs_csv_path, index=False) # The ODIR_evaluation script asks the probs file to be in .csv format

# %run ../../scripts/ODIR_evaluation.py {ground_truth_path} {probs_csv_path}
# Out:
# kappa score: 0.2764213096465933  f-1 score: 0.8588825214899714  AUC vlaue: 0.8540331545239455  Final Score: 0.6631123285535033

# %% [markdown]
# # Cuantitative results
# The test script prints some results as can be seen in the output of the previous cell. Now, lets see some more.

# %%
label_names = ['N','D','G','C','A','H','M','O']

ground_truth = pd.read_excel(ground_truth_path).loc[:, label_names].to_numpy()
probs = pd.read_excel(probs_path).loc[:, label_names].to_numpy()

# %%
from sklearn import metrics
os.chdir('../../scripts')
from metrics import plot_confusion_matrices
os.chdir('../experiments/experiment_7/')

# Print test classification report
print('Clasification report:')
print(
    metrics.classification_report(
        ground_truth,
        probs>0.5,
        output_dict=False,
        target_names=label_names,
        zero_division=0
    )
)

# Plot one confusion matrix for each label
plot_confusion_matrices(ground_truth, probs, label_names)
# Out:
# Clasification report:
#               precision    recall  f1-score   support
#
#            N       0.51      0.36      0.42       214
#            D       0.49      0.38      0.42       226
#            G       0.00      0.00      0.00        34
#            C       0.91      0.57      0.70        37
#            A       0.00      0.00      0.00        37
#            H       0.00      0.00      0.00        29
#            M       0.81      0.73      0.77        30
#            O       1.00      0.01      0.02       217
#
#    micro avg       0.55      0.25      0.34       824
#    macro avg       0.47      0.26      0.29       824
# weighted avg       0.60      0.25      0.29       824
#  samples avg       0.29      0.26      0.27       824

# %% [markdown]
# # Cualitative results
# One patient with each disease (at least) is predicted. The original images are ploted along with their ground truth and predicted labels.

# %%
import torch
from torchvision import transforms
os.chdir('../../scripts')
from utils import load_model
from predict import pred_and_plot_image
os.chdir('../experiments/experiment_7/')

# %%
model = load_model(model_path, model_name)

test_df = pd.read_excel(test_annotations_path)

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# [INFO] Created new resnet50_dual_v2 model.

# %% [markdown]
# You can run the next cell multiple times to see different results

# %%
for label in label_names:
    patient = test_df[test_df[label] == 1].sample(replace=True).reset_index(drop=True)
    pred_and_plot_image(model=model,
                        left_image_path=f'{images_path}/{patient.at[0, "Left-Fundus"]}',
                        right_image_path=f'{images_path}/{patient.at[0, "Right-Fundus"]}',
                        transform=transform,
                        device=device,
                        label_names=label_names,
                        ground_truth=patient.loc[0, label_names].to_numpy())

# %% [markdown]
# # Zip the experiment data folder, the SummaryWriter folder and the experiment outputs
# This is necessary in order to be able to download this folders

# %%
# import shutil

# shutil.make_archive('experiment_data_compressed',
#                     format="zip",
#                     root_dir='data/')

# shutil.make_archive('runs_compressed',
#                     format="zip",
#                     root_dir='../runs/')

# shutil.make_archive('outputs_compressed',
#                     format="zip",
#                     root_dir='outputs/')
# Out:
# '/content/ODIR-5K-multi-label-classification/experiments/experiment_6/outputs_compressed.zip'
