# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/serdna1/ODIR-5K-multi-label-classification/blob/main/experiments/experiment_16/experiment_16.ipynb)

# %% [markdown]
# # Download GitHub repository and data
# The repo wont be downloading in my local machine, since i already have it there. It will if someone is running this notebook on their own machine, colab, ...

# %%
import os
import zipfile

# Unzip images (will only work after upload the file to colab working directory)
with zipfile.ZipFile('train_fov_cc_fov_512.zip', 'r') as zip_ref:
  print("Unzipping training images...")
  zip_ref.extractall(f'train_fov_cc_fov_512')
# !rm train_fov_cc_fov_512.zip

images_path = 'train_fov_cc_fov_512/'

# If the experiments folder doesnt exist im not in my local machine
if not os.path.exists('../../experiments'):
    # Clone project repository
    # !git clone https://github.com/serdna1/ODIR-5K-multi-label-classification.git

    # Move to the experiment folder
    # %cd ODIR-5K-multi-label-classification/experiments/experiment_16/
# Out:
# Unzipping training images...
# Cloning into 'ODIR-5K-multi-label-classification'...
# remote: Enumerating objects: 648, done.
# remote: Counting objects: 100% (138/138), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 648 (delta 61), reused 95 (delta 26), pack-reused 510
# Receiving objects: 100% (648/648), 99.66 MiB | 25.53 MiB/s, done.
# Resolving deltas: 100% (314/314), done.
# /content/ODIR-5K-multi-label-classification/experiments/experiment_15

# %% [markdown]
# # Drop some special patients from the dataset
# The background of some images is quite different from the rest ones. Therefore they wont be used for training.

# %%
import matplotlib.pyplot as plt
from PIL import Image

images_path = '../../../train_fov_cc_fov_512/'

special_images = ['2174_right.jpg', '2175_left.jpg', '2176_left.jpg', '2177_left.jpg',
                  '2177_right.jpg', '2178_right.jpg', '2179_left.jpg', '2179_right.jpg',
                  '2180_left.jpg', '2180_right.jpg', '2181_left.jpg', '2181_right.jpg',
                  '2182_left.jpg', '2182_right.jpg', '2957_left.jpg', '2957_right.jpg']

# Show one of this special images
image_path = f'{images_path}/{special_images[7]}'
img = Image.open(image_path)
plt.imshow(img)
plt.axis(False)
plt.title('Example of special image')
# Out:
# Text(0.5, 1.0, 'Example of special image')

# %%
import pandas as pd

original_annotations_path = '../../data/annotations/annotations.xlsx'
annotations_path = 'data/annotations.xlsx'

odir_df = pd.read_excel(original_annotations_path)

patients_to_drop_df = odir_df[odir_df['Left-Fundus'].isin(special_images) | odir_df['Right-Fundus'].isin(special_images)]
patients_to_drop_df # This are all the patients with one ore more of this spetial images
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1634  2174           65      Female  2174_left.jpg  2174_right.jpg
# 1635  2175           63        Male  2175_left.jpg  2175_right.jpg
# 1636  2176           82      Female  2176_left.jpg  2176_right.jpg
# 1637  2177           87        Male  2177_left.jpg  2177_right.jpg
# 1638  2178           84        Male  2178_left.jpg  2178_right.jpg
# 1639  2179           70      Female  2179_left.jpg  2179_right.jpg
# 1640  2180           66      Female  2180_left.jpg  2180_right.jpg
# 1641  2181           79      Female  2181_left.jpg  2181_right.jpg
# 1642  2182           70        Male  2182_left.jpg  2182_right.jpg
# 2334  2957           62      Female  2957_left.jpg  2957_right.jpg
#
#      Left-Diagnostic Keywords Right-Diagnostic Keywords  N  D  G  C  A  H  M  \
# 1634            normal fundus                  cataract  0  0  0  1  0  0  0
# 1635                 cataract             normal fundus  0  0  0  1  0  0  0
# 1636                 cataract                  cataract  0  0  0  1  0  0  0
# 1637  normal fundus，lens dust                  cataract  0  0  0  1  0  0  0
# 1638                 cataract                  cataract  0  0  0  1  0  0  0
# 1639                 cataract                  cataract  0  0  0  1  0  0  0
# 1640                 cataract                  cataract  0  0  0  1  0  0  0
# 1641                 cataract                  cataract  0  0  0  1  0  0  0
# 1642                 cataract                  cataract  0  0  0  1  0  0  0
# 2334            normal fundus             normal fundus  1  0  0  0  0  0  0
#
#       O
# 1634  0
# 1635  0
# 1636  0
# 1637  0
# 1638  0
# 1639  0
# 1640  0
# 1641  0
# 1642  0
# 2334  0

# %%
from pathlib import Path

experiment_data_path = 'data/'

print(f'Annotations length before droping the rows with the special images: {len(odir_df)}')

odir_df = odir_df.drop(patients_to_drop_df.index) # Drop the special patients
Path(experiment_data_path).mkdir(parents=True, exist_ok=True) # Create the experiment data folder
odir_df.to_excel(annotations_path) # Save annotations without the special patients

print(f'Annotations length after droping the rows with the special images: {len(odir_df)}')
# Out:
# Annotations length before droping the rows with the special images: 3500
# Annotations length after droping the rows with the special images: 3490

# %% [markdown]
# # Check dataset label distribution

# %%
label_names = ['N','D','G','C','A','H','M','O']

total_label_list = []
for label in label_names:
    total_label = int(odir_df.loc[:, [label]].sum())
    total_label_list.append(total_label)

plt.figure(figsize=(16,4))

bar = plt.bar(label_names, total_label_list)

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f}', ha='center', va='bottom')

plt.xlabel(f'Label')
plt.ylabel(f'No. of images')
plt.title(f'Label distribution')
# Out:
# Text(0.5, 1.0, 'Label distribution')

# %% [markdown]
# # Split dataset into train and validation

# %%
os.chdir('../../scripts/')
from utils import split_annotations
os.chdir('../experiments/experiment_16/')

# %%
# Split the original annotations file into train and validation annotations files
# val_ratio = 0.2 (value by default)
split_annotations(annotations_path, experiment_data_path, test_split=False)

# Read the previous three created .xlsx files into dataframes
train_df = pd.read_excel(f'{experiment_data_path}/train_annotations.xlsx')
val_df = pd.read_excel(f'{experiment_data_path}/val_annotations.xlsx')

len(train_df), len(val_df)
# Out:
# (2792, 698)

# %% [markdown]
# # Check train and validation datasets label distribution

# %%
import numpy as np

barWidth = 0.3333
fig = plt.subplots(figsize =(16, 4))

# Set height of bars
total_label_train_list = [int(train_df.loc[:, [label]].sum()) for label in label_names]
total_label_val_list = [int(val_df.loc[:, [label]].sum()) for label in label_names]

# Set position of bar on X axis
br_train = np.arange(len(label_names))
br_val = [x + barWidth for x in br_train]

# Make the plot
bar_train = plt.bar(br_train, total_label_train_list, color ='r', width = barWidth,
                    edgecolor ='grey', label ='train')
bar_val = plt.bar(br_val, total_label_val_list, color ='b', width = barWidth,
                  edgecolor ='grey', label ='val')

# Plot the height label on top of each bar
for bar in [bar_train, bar_val]:
    for rect in bar:
        height = rect.get_height()
        plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f}', ha='center', va='bottom')

plt.title(f'Train/Validation distribution')
plt.xlabel('Label')
plt.ylabel('Nº of images')
plt.xticks([r + barWidth/2 for r in range(len(total_label_train_list))], label_names)

plt.legend()
plt.show()

# %% [markdown]
# # Train the model

# %%
# %run ../../scripts/train.py -h # Run this line to check the train script arguments
# Out:
# usage: train.py [-h] [--random_seed RANDOM_SEED] [--model_name MODEL_NAME] [--fine_tune]
#                 [--images_path IMAGES_PATH] [--use_data_augmentation] [--crop_size CROP_SIZE]
#                 [--use_normalization] [--train_annotations_path TRAIN_ANNOTATIONS_PATH]
#                 [--val_annotations_path VAL_ANNOTATIONS_PATH] [--batch_size BATCH_SIZE]
#                 [--use_multilabel_balanced_random_sampler] [--num_workers NUM_WORKERS]
#                 [--use_weighted_loss] [--lr LR] [--momentum MOMENTUM]
#                 [--lr_scheduler LR_SCHEDULER]
#                 [--linear_lr_scheduler_total_iters LINEAR_LR_SCHEDULER_TOTAL_ITERS]
#                 [--linear_lr_scheduler_start_factor LINEAR_LR_SCHEDULER_START_FACTOR]
#                 [--linear_lr_scheduler_end_factor LINEAR_LR_SCHEDULER_END_FACTOR]
#                 [--cyclic_lr_scheduler_base_lr CYCLIC_LR_SCHEDULER_BASE_LR]
#                 [--cyclic_lr_scheduler_max_lr CYCLIC_LR_SCHEDULER_MAX_LR]
#                 [--cyclic_lr_scheduler_step_size_up CYCLIC_LR_SCHEDULER_STEP_SIZE_UP]
#                 [--epochs EPOCHS] [--patience PATIENCE] [--experiment_name EXPERIMENT_NAME]
#                 [--extra EXTRA]
#
# Train a network for image multi-label classification on ODIR-5K.
#
# options:
#   -h, --help            show this help message and exit
#   --random_seed RANDOM_SEED
#                         Sets random seed for reproducibility (default: 42).
#   --model_name MODEL_NAME
#                         Model arquitecture for training (default: resnet50_dual).
#   --fine_tune           If set dont freeze the backbone weights
#   --images_path IMAGES_PATH
#                         Path of ODIR training images (default: /kaggle/input/odir-size-512/odir-
#                         size-512).
#   --use_data_augmentation
#                         If set augment training data.
#   --crop_size CROP_SIZE
#                         Crop size used in data augmentation. Random crop in train, center crop in
#                         validation (default: 224)
#   --use_normalization   If set the images are normalized the same way the imagenet images where
#                         normalized to train the resnet50 used here.
#   --train_annotations_path TRAIN_ANNOTATIONS_PATH
#                         Path of train annotations file (default: /kaggle/input/odir-
#                         size-512/train_annotations.xlsx).
#   --val_annotations_path VAL_ANNOTATIONS_PATH
#                         Path of validation annotations file (default: /kaggle/input/odir-
#                         size-512/val_annotations.xlsx).
#   --batch_size BATCH_SIZE
#                         Batch size for data loaders (default: 32).
#   --use_multilabel_balanced_random_sampler
#                         Use a custom multilabel random sampler that balance the train dataset.
#   --num_workers NUM_WORKERS
#                         Number of workers for data loaders (default: os.cpu_count()).
#   --use_weighted_loss   If set the loss function uses the pos_weight param to consider the dataset
#                         imbalance.
#   --lr LR               Specifies learning rate for optimizer (default: 1e-3).
#   --momentum MOMENTUM   Specifies momentum for optimizer (default: 0.9).
#   --lr_scheduler LR_SCHEDULER
#                         Learning rate scheduler (default: None)
#   --linear_lr_scheduler_total_iters LINEAR_LR_SCHEDULER_TOTAL_ITERS
#                         Number of steps that the linear lr scheduler decays the learning rate
#                         (default: 50).
#   --linear_lr_scheduler_start_factor LINEAR_LR_SCHEDULER_START_FACTOR
#                         Start factor of the linear lr scheduler (default: 1).
#   --linear_lr_scheduler_end_factor LINEAR_LR_SCHEDULER_END_FACTOR
#                         End factor of the linear lr scheduler (default: 0.1).
#   --cyclic_lr_scheduler_base_lr CYCLIC_LR_SCHEDULER_BASE_LR
#                         Initial learning rate which is the lower boundary in the cycle for each
#                         parameter group (default: 0.001).
#   --cyclic_lr_scheduler_max_lr CYCLIC_LR_SCHEDULER_MAX_LR
#                         Upper learning rate boundaries in the cycle for each parameter group
#                         (default: 0.1).
#   --cyclic_lr_scheduler_step_size_up CYCLIC_LR_SCHEDULER_STEP_SIZE_UP
#                         Number of training iterations in the increasing half of a cycle (default:
#                         10).
#   --epochs EPOCHS       Number of training epochs (default: 5).
#   --patience PATIENCE   How long to wait after last time validation loss improved (default: 1).
#   --experiment_name EXPERIMENT_NAME
#                         Name of the experiment" (default: experiment_0).
#   --extra EXTRA         Extra info about the experiment (default: None).

# %%
# Arguments that will be passed to the train script
images_path = '../../../train_fov_cc_fov_512/'
train_annotations_path = 'data/train_annotations.xlsx'
val_annotations_path = 'data/val_annotations.xlsx'
crop_size = 448
lr = 0.1
lr_scheduler = 'LinearLR'
batch_size = 16
epochs = 100
patience = 30
experiment_name = 'experiment_16'

# %%
# %run ../../scripts/train.py --images_path {images_path} --train_annotations_path {train_annotations_path} --val_annotations_path {val_annotations_path}\
                            --batch_size {batch_size} --epochs {epochs} --patience {patience} --experiment_name {experiment_name} --use_normalization\
                            --lr {lr} --lr_scheduler {lr_scheduler} --use_weighted_loss --fine_tune --use_data_augmentation --crop_size {crop_size}
# Out:
# [INFO] Created new resnet50_dual model.
# [INFO] Created SummaryWriter, saving to: ../runs/resnet50_dual/experiment_15...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ep: 0 | t_loss: 1.2021 | t_kappa: 0.0178 | t_f1: 0.3276 | t_auc: 0.5191 | t_final: 0.2881 | v_loss: 0.6162 | v_kappa: -0.0044 | v_f1: 0.3084 | v_auc: 0.5101 | v_final: 0.2714
# Validation loss decreased (inf --> 0.616156).  Saving model ...
# Ep: 1 | t_loss: 1.1900 | t_kappa: 0.0129 | t_f1: 0.3114 | t_auc: 0.5147 | t_final: 0.2796 | v_loss: 0.7152 | v_kappa: 0.0115 | v_f1: 0.1428 | v_auc: 0.5253 | v_final: 0.2265
# EarlyStopping counter: 1 out of 30
# Ep: 2 | t_loss: 1.1577 | t_kappa: 0.0230 | t_f1: 0.3263 | t_auc: 0.5205 | t_final: 0.2899 | v_loss: 0.6500 | v_kappa: 0.0191 | v_f1: 0.2404 | v_auc: 0.5339 | v_final: 0.2644
# EarlyStopping counter: 2 out of 30
# Ep: 3 | t_loss: 1.1328 | t_kappa: 0.0357 | t_f1: 0.3329 | t_auc: 0.5286 | t_final: 0.2991 | v_loss: 0.6632 | v_kappa: 0.0444 | v_f1: 0.3913 | v_auc: 0.5365 | v_final: 0.3241
# EarlyStopping counter: 3 out of 30
# Ep: 4 | t_loss: 1.1234 | t_kappa: 0.0515 | t_f1: 0.3570 | t_auc: 0.5504 | t_final: 0.3197 | v_loss: 0.6454 | v_kappa: 0.0517 | v_f1: 0.2385 | v_auc: 0.5793 | v_final: 0.2898
# EarlyStopping counter: 4 out of 30
# Ep: 5 | t_loss: 1.1042 | t_kappa: 0.0570 | t_f1: 0.3537 | t_auc: 0.5586 | t_final: 0.3231 | v_loss: 0.6818 | v_kappa: 0.0699 | v_f1: 0.2474 | v_auc: 0.5552 | v_final: 0.2908
# EarlyStopping counter: 5 out of 30
# Ep: 6 | t_loss: 1.0958 | t_kappa: 0.0692 | t_f1: 0.3568 | t_auc: 0.5616 | t_final: 0.3292 | v_loss: 0.6050 | v_kappa: 0.0866 | v_f1: 0.2927 | v_auc: 0.5615 | v_final: 0.3136
# Validation loss decreased (0.616156 --> 0.605008).  Saving model ...
# Ep: 7 | t_loss: 1.0832 | t_kappa: 0.0683 | t_f1: 0.3613 | t_auc: 0.5654 | t_final: 0.3316 | v_loss: 0.6608 | v_kappa: 0.0684 | v_f1: 0.3888 | v_auc: 0.5687 | v_final: 0.3420
# EarlyStopping counter: 1 out of 30
# Ep: 8 | t_loss: 1.0771 | t_kappa: 0.0765 | t_f1: 0.3646 | t_auc: 0.5761 | t_final: 0.3391 | v_loss: 0.5935 | v_kappa: 0.0765 | v_f1: 0.3136 | v_auc: 0.5624 | v_final: 0.3175
# Validation loss decreased (0.605008 --> 0.593458).  Saving model ...
# Ep: 9 | t_loss: 1.0753 | t_kappa: 0.0949 | t_f1: 0.3778 | t_auc: 0.5773 | t_final: 0.3500 | v_loss: 0.6568 | v_kappa: 0.0790 | v_f1: 0.3430 | v_auc: 0.5771 | v_final: 0.3330
# EarlyStopping counter: 1 out of 30
# Ep: 10 | t_loss: 1.0648 | t_kappa: 0.0811 | t_f1: 0.3666 | t_auc: 0.5715 | t_final: 0.3397 | v_loss: 0.6263 | v_kappa: 0.0838 | v_f1: 0.3891 | v_auc: 0.5773 | v_final: 0.3501
# EarlyStopping counter: 2 out of 30
# Ep: 11 | t_loss: 1.0538 | t_kappa: 0.0940 | t_f1: 0.3751 | t_auc: 0.5800 | t_final: 0.3497 | v_loss: 0.6095 | v_kappa: 0.1117 | v_f1: 0.3994 | v_auc: 0.5878 | v_final: 0.3663
# EarlyStopping counter: 3 out of 30
# Ep: 12 | t_loss: 1.0444 | t_kappa: 0.0949 | t_f1: 0.3797 | t_auc: 0.5758 | t_final: 0.3501 | v_loss: 0.6820 | v_kappa: 0.1172 | v_f1: 0.4083 | v_auc: 0.5919 | v_final: 0.3725
# EarlyStopping counter: 4 out of 30
# Ep: 13 | t_loss: 1.0484 | t_kappa: 0.1045 | t_f1: 0.3873 | t_auc: 0.5941 | t_final: 0.3620 | v_loss: 0.6691 | v_kappa: 0.1076 | v_f1: 0.3931 | v_auc: 0.5886 | v_final: 0.3631
# EarlyStopping counter: 5 out of 30
# Ep: 14 | t_loss: 1.0427 | t_kappa: 0.0944 | t_f1: 0.3821 | t_auc: 0.5817 | t_final: 0.3527 | v_loss: 0.6042 | v_kappa: 0.1146 | v_f1: 0.3877 | v_auc: 0.5778 | v_final: 0.3601
# EarlyStopping counter: 6 out of 30
# Ep: 15 | t_loss: 1.0295 | t_kappa: 0.1108 | t_f1: 0.3822 | t_auc: 0.5940 | t_final: 0.3623 | v_loss: 0.5585 | v_kappa: 0.1604 | v_f1: 0.4158 | v_auc: 0.5914 | v_final: 0.3892
# Validation loss decreased (0.593458 --> 0.558531).  Saving model ...
# Ep: 16 | t_loss: 1.0342 | t_kappa: 0.1097 | t_f1: 0.3867 | t_auc: 0.5891 | t_final: 0.3618 | v_loss: 0.6295 | v_kappa: 0.1143 | v_f1: 0.3854 | v_auc: 0.5939 | v_final: 0.3645
# EarlyStopping counter: 1 out of 30
# Ep: 17 | t_loss: 1.0188 | t_kappa: 0.1169 | t_f1: 0.3858 | t_auc: 0.5919 | t_final: 0.3649 | v_loss: 0.6382 | v_kappa: 0.1356 | v_f1: 0.3905 | v_auc: 0.6088 | v_final: 0.3783
# EarlyStopping counter: 2 out of 30
# Ep: 18 | t_loss: 1.0029 | t_kappa: 0.1275 | t_f1: 0.3935 | t_auc: 0.6025 | t_final: 0.3745 | v_loss: 0.6153 | v_kappa: 0.1192 | v_f1: 0.3615 | v_auc: 0.5978 | v_final: 0.3595
# EarlyStopping counter: 3 out of 30
# Ep: 19 | t_loss: 1.0097 | t_kappa: 0.1303 | t_f1: 0.4001 | t_auc: 0.6145 | t_final: 0.3816 | v_loss: 0.6094 | v_kappa: 0.1330 | v_f1: 0.3899 | v_auc: 0.5965 | v_final: 0.3732
# EarlyStopping counter: 4 out of 30
# Ep: 20 | t_loss: 1.0215 | t_kappa: 0.1158 | t_f1: 0.3894 | t_auc: 0.5991 | t_final: 0.3681 | v_loss: 0.5757 | v_kappa: 0.1413 | v_f1: 0.4271 | v_auc: 0.6030 | v_final: 0.3905
# EarlyStopping counter: 5 out of 30
# Ep: 21 | t_loss: 0.9961 | t_kappa: 0.1412 | t_f1: 0.4083 | t_auc: 0.6156 | t_final: 0.3883 | v_loss: 0.5818 | v_kappa: 0.1309 | v_f1: 0.3859 | v_auc: 0.6043 | v_final: 0.3737
# EarlyStopping counter: 6 out of 30
# Ep: 22 | t_loss: 0.9949 | t_kappa: 0.1366 | t_f1: 0.3990 | t_auc: 0.6093 | t_final: 0.3816 | v_loss: 0.5501 | v_kappa: 0.1508 | v_f1: 0.3795 | v_auc: 0.6117 | v_final: 0.3807
# Validation loss decreased (0.558531 --> 0.550093).  Saving model ...
# Ep: 23 | t_loss: 0.9887 | t_kappa: 0.1450 | t_f1: 0.4029 | t_auc: 0.6195 | t_final: 0.3892 | v_loss: 0.5314 | v_kappa: 0.1495 | v_f1: 0.4178 | v_auc: 0.6116 | v_final: 0.3930
# Validation loss decreased (0.550093 --> 0.531356).  Saving model ...
# Ep: 24 | t_loss: 0.9923 | t_kappa: 0.1392 | t_f1: 0.4044 | t_auc: 0.6115 | t_final: 0.3850 | v_loss: 0.5795 | v_kappa: 0.1663 | v_f1: 0.4473 | v_auc: 0.6114 | v_final: 0.4083
# EarlyStopping counter: 1 out of 30
# Ep: 25 | t_loss: 0.9650 | t_kappa: 0.1557 | t_f1: 0.4097 | t_auc: 0.6165 | t_final: 0.3940 | v_loss: 0.5808 | v_kappa: 0.1808 | v_f1: 0.3274 | v_auc: 0.6212 | v_final: 0.3765
# EarlyStopping counter: 2 out of 30
# Ep: 26 | t_loss: 0.9730 | t_kappa: 0.1555 | t_f1: 0.4139 | t_auc: 0.6301 | t_final: 0.3998 | v_loss: 0.5396 | v_kappa: 0.1812 | v_f1: 0.4039 | v_auc: 0.6241 | v_final: 0.4031
# EarlyStopping counter: 3 out of 30
# Ep: 27 | t_loss: 0.9615 | t_kappa: 0.1556 | t_f1: 0.4059 | t_auc: 0.6252 | t_final: 0.3956 | v_loss: 0.5436 | v_kappa: 0.1677 | v_f1: 0.3728 | v_auc: 0.6209 | v_final: 0.3871
# EarlyStopping counter: 4 out of 30
# Ep: 28 | t_loss: 0.9308 | t_kappa: 0.1816 | t_f1: 0.4274 | t_auc: 0.6386 | t_final: 0.4159 | v_loss: 0.5731 | v_kappa: 0.1860 | v_f1: 0.4296 | v_auc: 0.6175 | v_final: 0.4110
# EarlyStopping counter: 5 out of 30
# Ep: 29 | t_loss: 0.9259 | t_kappa: 0.1793 | t_f1: 0.4217 | t_auc: 0.6406 | t_final: 0.4139 | v_loss: 0.5545 | v_kappa: 0.1742 | v_f1: 0.4239 | v_auc: 0.6216 | v_final: 0.4066
# EarlyStopping counter: 6 out of 30
# Ep: 30 | t_loss: 0.9344 | t_kappa: 0.1814 | t_f1: 0.4281 | t_auc: 0.6399 | t_final: 0.4165 | v_loss: 0.5623 | v_kappa: 0.2163 | v_f1: 0.4229 | v_auc: 0.6201 | v_final: 0.4198
# EarlyStopping counter: 7 out of 30
# Ep: 31 | t_loss: 0.9221 | t_kappa: 0.1917 | t_f1: 0.4270 | t_auc: 0.6411 | t_final: 0.4199 | v_loss: 0.5565 | v_kappa: 0.1836 | v_f1: 0.4193 | v_auc: 0.6238 | v_final: 0.4089
# EarlyStopping counter: 8 out of 30
# Ep: 32 | t_loss: 0.9114 | t_kappa: 0.1973 | t_f1: 0.4362 | t_auc: 0.6439 | t_final: 0.4258 | v_loss: 0.5228 | v_kappa: 0.1906 | v_f1: 0.4095 | v_auc: 0.6296 | v_final: 0.4099
# Validation loss decreased (0.531356 --> 0.522811).  Saving model ...
# Ep: 33 | t_loss: 0.9042 | t_kappa: 0.1979 | t_f1: 0.4375 | t_auc: 0.6469 | t_final: 0.4274 | v_loss: 0.5792 | v_kappa: 0.2059 | v_f1: 0.4099 | v_auc: 0.6261 | v_final: 0.4139
# EarlyStopping counter: 1 out of 30
# Ep: 34 | t_loss: 0.9160 | t_kappa: 0.1913 | t_f1: 0.4268 | t_auc: 0.6433 | t_final: 0.4204 | v_loss: 0.5326 | v_kappa: 0.1952 | v_f1: 0.4225 | v_auc: 0.6296 | v_final: 0.4157
# EarlyStopping counter: 2 out of 30
# Ep: 35 | t_loss: 0.9023 | t_kappa: 0.1943 | t_f1: 0.4328 | t_auc: 0.6438 | t_final: 0.4236 | v_loss: 0.5537 | v_kappa: 0.1952 | v_f1: 0.3931 | v_auc: 0.6338 | v_final: 0.4074
# EarlyStopping counter: 3 out of 30
# Ep: 36 | t_loss: 0.9008 | t_kappa: 0.2023 | t_f1: 0.4382 | t_auc: 0.6519 | t_final: 0.4308 | v_loss: 0.5647 | v_kappa: 0.1777 | v_f1: 0.3917 | v_auc: 0.6314 | v_final: 0.4003
# EarlyStopping counter: 4 out of 30
# Ep: 37 | t_loss: 0.8965 | t_kappa: 0.2018 | t_f1: 0.4362 | t_auc: 0.6444 | t_final: 0.4274 | v_loss: 0.5881 | v_kappa: 0.2047 | v_f1: 0.4279 | v_auc: 0.6311 | v_final: 0.4212
# EarlyStopping counter: 5 out of 30
# Ep: 38 | t_loss: 0.8920 | t_kappa: 0.2104 | t_f1: 0.4371 | t_auc: 0.6445 | t_final: 0.4307 | v_loss: 0.4989 | v_kappa: 0.2278 | v_f1: 0.4345 | v_auc: 0.6248 | v_final: 0.4290
# Validation loss decreased (0.522811 --> 0.498869).  Saving model ...
# Ep: 39 | t_loss: 0.8846 | t_kappa: 0.2084 | t_f1: 0.4398 | t_auc: 0.6565 | t_final: 0.4349 | v_loss: 0.5365 | v_kappa: 0.2130 | v_f1: 0.4449 | v_auc: 0.6263 | v_final: 0.4281
# EarlyStopping counter: 1 out of 30
# Ep: 40 | t_loss: 0.8749 | t_kappa: 0.2163 | t_f1: 0.4428 | t_auc: 0.6518 | t_final: 0.4370 | v_loss: 0.5209 | v_kappa: 0.2225 | v_f1: 0.4356 | v_auc: 0.6273 | v_final: 0.4285
# EarlyStopping counter: 2 out of 30
# Ep: 41 | t_loss: 0.8716 | t_kappa: 0.2271 | t_f1: 0.4508 | t_auc: 0.6611 | t_final: 0.4464 | v_loss: 0.5143 | v_kappa: 0.2248 | v_f1: 0.4430 | v_auc: 0.6406 | v_final: 0.4361
# EarlyStopping counter: 3 out of 30
# Ep: 42 | t_loss: 0.8472 | t_kappa: 0.2346 | t_f1: 0.4561 | t_auc: 0.6655 | t_final: 0.4521 | v_loss: 0.5050 | v_kappa: 0.2292 | v_f1: 0.4467 | v_auc: 0.6329 | v_final: 0.4363
# EarlyStopping counter: 4 out of 30
# Ep: 43 | t_loss: 0.8660 | t_kappa: 0.2330 | t_f1: 0.4546 | t_auc: 0.6635 | t_final: 0.4503 | v_loss: 0.5293 | v_kappa: 0.2257 | v_f1: 0.4489 | v_auc: 0.6377 | v_final: 0.4374
# EarlyStopping counter: 5 out of 30
# Ep: 44 | t_loss: 0.8620 | t_kappa: 0.2282 | t_f1: 0.4534 | t_auc: 0.6653 | t_final: 0.4490 | v_loss: 0.5220 | v_kappa: 0.2338 | v_f1: 0.4452 | v_auc: 0.6331 | v_final: 0.4374
# EarlyStopping counter: 6 out of 30
# Ep: 45 | t_loss: 0.8596 | t_kappa: 0.2279 | t_f1: 0.4543 | t_auc: 0.6680 | t_final: 0.4500 | v_loss: 0.5473 | v_kappa: 0.2279 | v_f1: 0.4228 | v_auc: 0.6322 | v_final: 0.4276
# EarlyStopping counter: 7 out of 30
# Ep: 46 | t_loss: 0.8461 | t_kappa: 0.2366 | t_f1: 0.4549 | t_auc: 0.6682 | t_final: 0.4532 | v_loss: 0.5328 | v_kappa: 0.2340 | v_f1: 0.4424 | v_auc: 0.6402 | v_final: 0.4389
# EarlyStopping counter: 8 out of 30
# Ep: 47 | t_loss: 0.8541 | t_kappa: 0.2262 | t_f1: 0.4456 | t_auc: 0.6553 | t_final: 0.4424 | v_loss: 0.5325 | v_kappa: 0.2049 | v_f1: 0.4179 | v_auc: 0.6381 | v_final: 0.4203
# EarlyStopping counter: 9 out of 30
# Ep: 48 | t_loss: 0.8352 | t_kappa: 0.2459 | t_f1: 0.4583 | t_auc: 0.6682 | t_final: 0.4575 | v_loss: 0.5128 | v_kappa: 0.2288 | v_f1: 0.4350 | v_auc: 0.6415 | v_final: 0.4351
# EarlyStopping counter: 10 out of 30
# Ep: 49 | t_loss: 0.8392 | t_kappa: 0.2467 | t_f1: 0.4652 | t_auc: 0.6718 | t_final: 0.4613 | v_loss: 0.5417 | v_kappa: 0.2552 | v_f1: 0.4423 | v_auc: 0.6440 | v_final: 0.4472
# EarlyStopping counter: 11 out of 30
# Ep: 50 | t_loss: 0.8264 | t_kappa: 0.2472 | t_f1: 0.4577 | t_auc: 0.6707 | t_final: 0.4585 | v_loss: 0.5211 | v_kappa: 0.2463 | v_f1: 0.4611 | v_auc: 0.6488 | v_final: 0.4521
# EarlyStopping counter: 12 out of 30
# Ep: 51 | t_loss: 0.8292 | t_kappa: 0.2492 | t_f1: 0.4613 | t_auc: 0.6759 | t_final: 0.4621 | v_loss: 0.4908 | v_kappa: 0.2711 | v_f1: 0.4630 | v_auc: 0.6481 | v_final: 0.4608
# Validation loss decreased (0.498869 --> 0.490806).  Saving model ...
# Ep: 52 | t_loss: 0.8265 | t_kappa: 0.2579 | t_f1: 0.4667 | t_auc: 0.6726 | t_final: 0.4658 | v_loss: 0.5144 | v_kappa: 0.2509 | v_f1: 0.4504 | v_auc: 0.6496 | v_final: 0.4503
# EarlyStopping counter: 1 out of 30
# Ep: 53 | t_loss: 0.8198 | t_kappa: 0.2529 | t_f1: 0.4630 | t_auc: 0.6717 | t_final: 0.4625 | v_loss: 0.5191 | v_kappa: 0.2497 | v_f1: 0.4463 | v_auc: 0.6457 | v_final: 0.4472
# EarlyStopping counter: 2 out of 30
# Ep: 54 | t_loss: 0.8143 | t_kappa: 0.2542 | t_f1: 0.4631 | t_auc: 0.6707 | t_final: 0.4627 | v_loss: 0.5150 | v_kappa: 0.2716 | v_f1: 0.4682 | v_auc: 0.6499 | v_final: 0.4632
# EarlyStopping counter: 3 out of 30
# Ep: 55 | t_loss: 0.8138 | t_kappa: 0.2571 | t_f1: 0.4637 | t_auc: 0.6735 | t_final: 0.4648 | v_loss: 0.5406 | v_kappa: 0.2519 | v_f1: 0.4591 | v_auc: 0.6450 | v_final: 0.4520
# EarlyStopping counter: 4 out of 30
# Ep: 56 | t_loss: 0.8158 | t_kappa: 0.2555 | t_f1: 0.4658 | t_auc: 0.6753 | t_final: 0.4655 | v_loss: 0.4985 | v_kappa: 0.2677 | v_f1: 0.4658 | v_auc: 0.6528 | v_final: 0.4621
# EarlyStopping counter: 5 out of 30
# Ep: 57 | t_loss: 0.8081 | t_kappa: 0.2644 | t_f1: 0.4705 | t_auc: 0.6823 | t_final: 0.4724 | v_loss: 0.4867 | v_kappa: 0.2555 | v_f1: 0.4567 | v_auc: 0.6493 | v_final: 0.4538
# Validation loss decreased (0.490806 --> 0.486709).  Saving model ...
# Ep: 58 | t_loss: 0.8109 | t_kappa: 0.2632 | t_f1: 0.4705 | t_auc: 0.6733 | t_final: 0.4690 | v_loss: 0.5147 | v_kappa: 0.2465 | v_f1: 0.4510 | v_auc: 0.6495 | v_final: 0.4490
# EarlyStopping counter: 1 out of 30
# Ep: 59 | t_loss: 0.8219 | t_kappa: 0.2595 | t_f1: 0.4690 | t_auc: 0.6793 | t_final: 0.4692 | v_loss: 0.5074 | v_kappa: 0.2532 | v_f1: 0.4482 | v_auc: 0.6517 | v_final: 0.4510
# EarlyStopping counter: 2 out of 30
# Ep: 60 | t_loss: 0.8028 | t_kappa: 0.2711 | t_f1: 0.4737 | t_auc: 0.6846 | t_final: 0.4765 | v_loss: 0.5363 | v_kappa: 0.2461 | v_f1: 0.4570 | v_auc: 0.6555 | v_final: 0.4529
# EarlyStopping counter: 3 out of 30
# Ep: 61 | t_loss: 0.8000 | t_kappa: 0.2780 | t_f1: 0.4785 | t_auc: 0.6861 | t_final: 0.4809 | v_loss: 0.5146 | v_kappa: 0.2511 | v_f1: 0.4496 | v_auc: 0.6511 | v_final: 0.4506
# EarlyStopping counter: 4 out of 30
# Ep: 62 | t_loss: 0.8083 | t_kappa: 0.2645 | t_f1: 0.4739 | t_auc: 0.6839 | t_final: 0.4741 | v_loss: 0.5462 | v_kappa: 0.2520 | v_f1: 0.4615 | v_auc: 0.6612 | v_final: 0.4583
# EarlyStopping counter: 5 out of 30
# Ep: 63 | t_loss: 0.8054 | t_kappa: 0.2611 | t_f1: 0.4709 | t_auc: 0.6804 | t_final: 0.4708 | v_loss: 0.5054 | v_kappa: 0.2469 | v_f1: 0.4528 | v_auc: 0.6592 | v_final: 0.4530
# EarlyStopping counter: 6 out of 30
# Ep: 64 | t_loss: 0.7970 | t_kappa: 0.2665 | t_f1: 0.4703 | t_auc: 0.6824 | t_final: 0.4731 | v_loss: 0.4861 | v_kappa: 0.2629 | v_f1: 0.4611 | v_auc: 0.6558 | v_final: 0.4599
# Validation loss decreased (0.486709 --> 0.486102).  Saving model ...
# Ep: 65 | t_loss: 0.8134 | t_kappa: 0.2643 | t_f1: 0.4676 | t_auc: 0.6777 | t_final: 0.4698 | v_loss: 0.4962 | v_kappa: 0.2586 | v_f1: 0.4559 | v_auc: 0.6575 | v_final: 0.4573
# EarlyStopping counter: 1 out of 30
# Ep: 66 | t_loss: 0.8075 | t_kappa: 0.2608 | t_f1: 0.4678 | t_auc: 0.6803 | t_final: 0.4697 | v_loss: 0.4847 | v_kappa: 0.2779 | v_f1: 0.4698 | v_auc: 0.6583 | v_final: 0.4686
# Validation loss decreased (0.486102 --> 0.484713).  Saving model ...
# Ep: 67 | t_loss: 0.8007 | t_kappa: 0.2708 | t_f1: 0.4751 | t_auc: 0.6854 | t_final: 0.4771 | v_loss: 0.5087 | v_kappa: 0.2709 | v_f1: 0.4708 | v_auc: 0.6574 | v_final: 0.4664
# EarlyStopping counter: 1 out of 30
# Ep: 68 | t_loss: 0.8057 | t_kappa: 0.2651 | t_f1: 0.4718 | t_auc: 0.6817 | t_final: 0.4728 | v_loss: 0.4880 | v_kappa: 0.2763 | v_f1: 0.4713 | v_auc: 0.6638 | v_final: 0.4705
# EarlyStopping counter: 2 out of 30
# Ep: 69 | t_loss: 0.7943 | t_kappa: 0.2708 | t_f1: 0.4749 | t_auc: 0.6815 | t_final: 0.4757 | v_loss: 0.5069 | v_kappa: 0.2759 | v_f1: 0.4832 | v_auc: 0.6681 | v_final: 0.4757
# EarlyStopping counter: 3 out of 30
# Ep: 70 | t_loss: 0.7904 | t_kappa: 0.2699 | t_f1: 0.4721 | t_auc: 0.6856 | t_final: 0.4759 | v_loss: 0.4975 | v_kappa: 0.2553 | v_f1: 0.4632 | v_auc: 0.6673 | v_final: 0.4619
# EarlyStopping counter: 4 out of 30
# Ep: 71 | t_loss: 0.7874 | t_kappa: 0.2798 | t_f1: 0.4774 | t_auc: 0.6864 | t_final: 0.4812 | v_loss: 0.5172 | v_kappa: 0.2554 | v_f1: 0.4626 | v_auc: 0.6655 | v_final: 0.4612
# EarlyStopping counter: 5 out of 30
# Ep: 72 | t_loss: 0.7811 | t_kappa: 0.2774 | t_f1: 0.4793 | t_auc: 0.6895 | t_final: 0.4821 | v_loss: 0.4686 | v_kappa: 0.2851 | v_f1: 0.4720 | v_auc: 0.6671 | v_final: 0.4747
# Validation loss decreased (0.484713 --> 0.468569).  Saving model ...
# Ep: 73 | t_loss: 0.7962 | t_kappa: 0.2740 | t_f1: 0.4802 | t_auc: 0.6893 | t_final: 0.4812 | v_loss: 0.5409 | v_kappa: 0.2440 | v_f1: 0.4535 | v_auc: 0.6668 | v_final: 0.4547
# EarlyStopping counter: 1 out of 30
# Ep: 74 | t_loss: 0.7779 | t_kappa: 0.2717 | t_f1: 0.4733 | t_auc: 0.6920 | t_final: 0.4790 | v_loss: 0.4710 | v_kappa: 0.2975 | v_f1: 0.4714 | v_auc: 0.6665 | v_final: 0.4785
# EarlyStopping counter: 2 out of 30
# Ep: 75 | t_loss: 0.7877 | t_kappa: 0.2792 | t_f1: 0.4772 | t_auc: 0.6935 | t_final: 0.4833 | v_loss: 0.4964 | v_kappa: 0.2689 | v_f1: 0.4678 | v_auc: 0.6655 | v_final: 0.4674
# EarlyStopping counter: 3 out of 30
# Ep: 76 | t_loss: 0.7688 | t_kappa: 0.2884 | t_f1: 0.4853 | t_auc: 0.6946 | t_final: 0.4895 | v_loss: 0.4938 | v_kappa: 0.2843 | v_f1: 0.4633 | v_auc: 0.6649 | v_final: 0.4708
# EarlyStopping counter: 4 out of 30
# Ep: 77 | t_loss: 0.7935 | t_kappa: 0.2782 | t_f1: 0.4812 | t_auc: 0.7006 | t_final: 0.4866 | v_loss: 0.5142 | v_kappa: 0.2693 | v_f1: 0.4639 | v_auc: 0.6674 | v_final: 0.4669
# EarlyStopping counter: 5 out of 30
# Ep: 78 | t_loss: 0.7714 | t_kappa: 0.2933 | t_f1: 0.4839 | t_auc: 0.6990 | t_final: 0.4921 | v_loss: 0.5743 | v_kappa: 0.2507 | v_f1: 0.4604 | v_auc: 0.6669 | v_final: 0.4594
# EarlyStopping counter: 6 out of 30
# Ep: 79 | t_loss: 0.7706 | t_kappa: 0.2802 | t_f1: 0.4803 | t_auc: 0.6962 | t_final: 0.4856 | v_loss: 0.4820 | v_kappa: 0.2719 | v_f1: 0.4547 | v_auc: 0.6710 | v_final: 0.4659
# EarlyStopping counter: 7 out of 30
# Ep: 80 | t_loss: 0.7716 | t_kappa: 0.2857 | t_f1: 0.4785 | t_auc: 0.6900 | t_final: 0.4848 | v_loss: 0.5012 | v_kappa: 0.2917 | v_f1: 0.4815 | v_auc: 0.6713 | v_final: 0.4815
# EarlyStopping counter: 8 out of 30
# Ep: 81 | t_loss: 0.7559 | t_kappa: 0.2913 | t_f1: 0.4845 | t_auc: 0.6939 | t_final: 0.4899 | v_loss: 0.4842 | v_kappa: 0.2887 | v_f1: 0.4775 | v_auc: 0.6708 | v_final: 0.4790
# EarlyStopping counter: 9 out of 30
# Ep: 82 | t_loss: 0.7668 | t_kappa: 0.2979 | t_f1: 0.4884 | t_auc: 0.6993 | t_final: 0.4952 | v_loss: 0.5497 | v_kappa: 0.2479 | v_f1: 0.4643 | v_auc: 0.6727 | v_final: 0.4616
# EarlyStopping counter: 10 out of 30
# Ep: 83 | t_loss: 0.7523 | t_kappa: 0.3016 | t_f1: 0.4882 | t_auc: 0.6997 | t_final: 0.4965 | v_loss: 0.4685 | v_kappa: 0.2831 | v_f1: 0.4836 | v_auc: 0.6730 | v_final: 0.4799
# Validation loss decreased (0.468569 --> 0.468502).  Saving model ...
# Ep: 84 | t_loss: 0.7695 | t_kappa: 0.2963 | t_f1: 0.4928 | t_auc: 0.6998 | t_final: 0.4963 | v_loss: 0.4959 | v_kappa: 0.2895 | v_f1: 0.4716 | v_auc: 0.6774 | v_final: 0.4795
# EarlyStopping counter: 1 out of 30
# Ep: 85 | t_loss: 0.7677 | t_kappa: 0.2834 | t_f1: 0.4806 | t_auc: 0.6976 | t_final: 0.4872 | v_loss: 0.4619 | v_kappa: 0.3013 | v_f1: 0.4874 | v_auc: 0.6873 | v_final: 0.4920
# Validation loss decreased (0.468502 --> 0.461866).  Saving model ...
# Ep: 86 | t_loss: 0.7567 | t_kappa: 0.2933 | t_f1: 0.4875 | t_auc: 0.6972 | t_final: 0.4927 | v_loss: 0.4666 | v_kappa: 0.2966 | v_f1: 0.4793 | v_auc: 0.6817 | v_final: 0.4859
# EarlyStopping counter: 1 out of 30
# Ep: 87 | t_loss: 0.7615 | t_kappa: 0.3015 | t_f1: 0.4870 | t_auc: 0.6949 | t_final: 0.4945 | v_loss: 0.4561 | v_kappa: 0.2869 | v_f1: 0.4632 | v_auc: 0.6773 | v_final: 0.4758
# Validation loss decreased (0.461866 --> 0.456149).  Saving model ...
# Ep: 88 | t_loss: 0.7552 | t_kappa: 0.2953 | t_f1: 0.4872 | t_auc: 0.7047 | t_final: 0.4957 | v_loss: 0.4516 | v_kappa: 0.3045 | v_f1: 0.4843 | v_auc: 0.6801 | v_final: 0.4896
# Validation loss decreased (0.456149 --> 0.451577).  Saving model ...
# Ep: 89 | t_loss: 0.7436 | t_kappa: 0.3127 | t_f1: 0.4967 | t_auc: 0.7019 | t_final: 0.5038 | v_loss: 0.4762 | v_kappa: 0.2781 | v_f1: 0.4518 | v_auc: 0.6759 | v_final: 0.4686
# EarlyStopping counter: 1 out of 30
# Ep: 90 | t_loss: 0.7637 | t_kappa: 0.3009 | t_f1: 0.4928 | t_auc: 0.7074 | t_final: 0.5004 | v_loss: 0.4591 | v_kappa: 0.2941 | v_f1: 0.4675 | v_auc: 0.6809 | v_final: 0.4808
# EarlyStopping counter: 2 out of 30
# Ep: 91 | t_loss: 0.7457 | t_kappa: 0.3034 | t_f1: 0.4895 | t_auc: 0.7059 | t_final: 0.4996 | v_loss: 0.4867 | v_kappa: 0.2958 | v_f1: 0.4723 | v_auc: 0.6798 | v_final: 0.4826
# EarlyStopping counter: 3 out of 30
# Ep: 92 | t_loss: 0.7491 | t_kappa: 0.3000 | t_f1: 0.4897 | t_auc: 0.7064 | t_final: 0.4987 | v_loss: 0.4931 | v_kappa: 0.2708 | v_f1: 0.4613 | v_auc: 0.6781 | v_final: 0.4701
# EarlyStopping counter: 4 out of 30
# Ep: 93 | t_loss: 0.7402 | t_kappa: 0.3097 | t_f1: 0.4987 | t_auc: 0.7078 | t_final: 0.5054 | v_loss: 0.4953 | v_kappa: 0.2881 | v_f1: 0.4761 | v_auc: 0.6734 | v_final: 0.4792
# EarlyStopping counter: 5 out of 30
# Ep: 94 | t_loss: 0.7469 | t_kappa: 0.3026 | t_f1: 0.4936 | t_auc: 0.7045 | t_final: 0.5002 | v_loss: 0.5100 | v_kappa: 0.2969 | v_f1: 0.4870 | v_auc: 0.6853 | v_final: 0.4897
# EarlyStopping counter: 6 out of 30
# Ep: 95 | t_loss: 0.7374 | t_kappa: 0.3093 | t_f1: 0.4950 | t_auc: 0.7070 | t_final: 0.5038 | v_loss: 0.5000 | v_kappa: 0.3066 | v_f1: 0.4893 | v_auc: 0.6875 | v_final: 0.4945
# EarlyStopping counter: 7 out of 30
# Ep: 96 | t_loss: 0.7321 | t_kappa: 0.3113 | t_f1: 0.4955 | t_auc: 0.7059 | t_final: 0.5043 | v_loss: 0.4767 | v_kappa: 0.3114 | v_f1: 0.4840 | v_auc: 0.6881 | v_final: 0.4945
# EarlyStopping counter: 8 out of 30
# Ep: 97 | t_loss: 0.7298 | t_kappa: 0.3157 | t_f1: 0.4993 | t_auc: 0.7121 | t_final: 0.5091 | v_loss: 0.5060 | v_kappa: 0.2988 | v_f1: 0.4823 | v_auc: 0.6804 | v_final: 0.4872
# EarlyStopping counter: 9 out of 30
# Ep: 98 | t_loss: 0.7238 | t_kappa: 0.3180 | t_f1: 0.4981 | t_auc: 0.7097 | t_final: 0.5086 | v_loss: 0.4343 | v_kappa: 0.3237 | v_f1: 0.4877 | v_auc: 0.6910 | v_final: 0.5008
# Validation loss decreased (0.451577 --> 0.434309).  Saving model ...
# Ep: 99 | t_loss: 0.7339 | t_kappa: 0.3150 | t_f1: 0.5010 | t_auc: 0.7161 | t_final: 0.5107 | v_loss: 0.4546 | v_kappa: 0.3114 | v_f1: 0.4831 | v_auc: 0.6908 | v_final: 0.4951
# EarlyStopping counter: 1 out of 30

# %% [markdown]
# Run the next cell to see the metrics trough the epochs using the tensorboard interface

# %%
# %reload_ext tensorboard
# %tensorboard --logdir ../runs
# Out:
# Reusing TensorBoard on port 6006 (pid 77557), started 0:00:05 ago. (Use '!kill 77557' to kill it.)

# %% [markdown]
# # Test the model with the validation dataset
# Since there is no access to the test annotatations (only to the images) the test will be performed on the validation dataset, to be able to see some results.

# %%
# %run ../../scripts/test.py -h # Run this line to check the test script arguments
# Out:
# usage: test.py [-h] [--model_name MODEL_NAME] [--model_path MODEL_PATH]
#                [--images_path IMAGES_PATH] [--crop_size CROP_SIZE]
#                [--test_annotations_path TEST_ANNOTATIONS_PATH]
#                [--use_normalization] [--batch_size BATCH_SIZE]
#                [--num_workers NUM_WORKERS]
#                [--ground_truth_path GROUND_TRUTH_PATH]
#                [--probs_path PROBS_PATH]
#
# Test a model with a dataset.
#
# options:
#   -h, --help            show this help message and exit
#   --model_name MODEL_NAME
#                         Model arquitecture for testing (default:
#                         resnet50_dual).
#   --model_path MODEL_PATH
#                         Path to the model to test the dataset with (default:
#                         outputs/resnet50_dual_experiment_0_model.pth).
#   --images_path IMAGES_PATH
#                         Path of test images (default:
#                         ../../data/train_fov_cc_fov_224/).
#   --crop_size CROP_SIZE
#                         Crop size used for center cropping the test images
#                         (default: 224)
#   --test_annotations_path TEST_ANNOTATIONS_PATH
#                         Path of test annotations file (default:
#                         data/test_annotations.xlsx).
#   --use_normalization   If set the images are normalized the same way the
#                         imagenet images were normalized to train the resnet50
#                         used here.
#   --batch_size BATCH_SIZE
#                         Batch size for data loaders (default: 32).
#   --num_workers NUM_WORKERS
#                         Number of workers for data loaders (default:
#                         os.cpu_count()).
#   --ground_truth_path GROUND_TRUTH_PATH
#                         Path to store the ground truth labels used in test
#                         (default: None).
#   --probs_path PROBS_PATH
#                         Path to store the result probs of test (default:
#                         None).

# %%
test_annotations_path = 'data/val_annotations.xlsx' # val annotations are used for test
images_path = '../../../train_fov_cc_fov_512/'
model_path = 'outputs/resnet50_dual_experiment_16_model.pth'
ground_truth_path = 'outputs/ground_truth.xlsx'
probs_path = 'outputs/probs.xlsx'

# %%
# %run ../../scripts/test.py --model_path {model_path} --images_path {images_path} --test_annotations_path {test_annotations_path} --use_normalization\
                           --ground_truth_path {ground_truth_path} --probs_path {probs_path} --crop_size {crop_size}
# Out:
# [INFO] Created new resnet50_dual model.
# test_loss: 0.4339 | test_kappa: 0.3237 | test_f1: 0.4877 | test_auc: 0.6910 | test_final: 0.5008

# %% [markdown]
# # Run the ODIR_evaluation.py script on test (validation) dataset
# This is a file provided along with the data by the challenge. And its supposed to have an example on how to compute the kappa, f1, auc, and final score metrics but i dont think they are well computed here as they are always too good (as shown later, the cualitative results for test are much worst). As a result of this, i use my own version of this metrics (see the function compute_challenge_metrics on the metrics script). Either way i'll run it.

# %%
ground_truth_path = 'outputs/ground_truth.xlsx'
probs_path = 'outputs/probs.xlsx'
probs_csv_path = 'outputs/probs.csv'

probs_df = pd.read_excel(probs_path)
probs_df.to_csv(probs_csv_path, index=False) # The ODIR_evaluation script asks the probs file to be in .csv format

# %run ../../scripts/ODIR_evaluation.py {ground_truth_path} {probs_csv_path}
# Out:
# kappa score: 0.32651277359420083  f-1 score: 0.7544770773638969  AUC vlaue: 0.8267467059639391  Final Score: 0.635912185640679

# %% [markdown]
# # Cuantitative results
# The test script prints some results as can be seen in the output of the previous cell. Now, lets see some more.

# %%
label_names = ['N','D','G','C','A','H','M','O']

ground_truth = pd.read_excel(ground_truth_path).loc[:, label_names].to_numpy()
probs = pd.read_excel(probs_path).loc[:, label_names].to_numpy()

# %%
from sklearn import metrics
os.chdir('../../scripts')
from metrics import plot_confusion_matrices
os.chdir('../experiments/experiment_16/')

# Print test classification report
print('Clasification report:')
print(
    metrics.classification_report(
        ground_truth,
        probs>0.5,
        output_dict=False,
        target_names=label_names,
        zero_division=0
    )
)

# Plot one confusion matrix for each label
plot_confusion_matrices(ground_truth, probs, label_names)
# Out:
# Clasification report:
#               precision    recall  f1-score   support
#
#            N       0.39      0.81      0.52       214
#            D       0.40      0.77      0.53       226
#            G       0.23      0.76      0.35        34
#            C       0.49      0.95      0.64        37
#            A       0.24      0.65      0.35        37
#            H       0.09      0.72      0.17        29
#            M       0.61      0.90      0.73        30
#            O       0.37      0.48      0.42       217
#
#    micro avg       0.34      0.71      0.46       824
#    macro avg       0.35      0.76      0.46       824
# weighted avg       0.38      0.71      0.48       824
#  samples avg       0.38      0.72      0.47       824

# %% [markdown]
# # Cualitative results
# One patient with each disease (at least) is predicted. The original images are ploted along with their ground truth and predicted labels.

# %%
import torch
from torchvision import transforms
os.chdir('../../scripts')
from utils import load_model
from transforms import ToTensorDual, NormalizeDual, CenterCropDual
from predict import pred_and_plot_image
os.chdir('../experiments/experiment_16/')

# %%
model = load_model(model_path)

test_df = pd.read_excel(test_annotations_path)

transform = transforms.Compose([
    CenterCropDual(size=crop_size),
    ToTensorDual(),
    NormalizeDual(mean=[0.485, 0.456, 0.406],
                    std=[0.229, 0.224, 0.225])
])

device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# [INFO] Created new resnet50_dual model.

# %% [markdown]
# You can run the next cell multiple times to see different results

# %%
for label in label_names:
    patient = test_df[test_df[label] == 1].sample(replace=True).reset_index(drop=True)
    pred_and_plot_image(model=model,
                        left_image_path=f'{images_path}/{patient.at[0, "Left-Fundus"]}',
                        right_image_path=f'{images_path}/{patient.at[0, "Right-Fundus"]}',
                        transform=transform,
                        device=device,
                        label_names=label_names,
                        ground_truth=patient.loc[0, label_names].to_numpy())

# %% [markdown]
# # Zip the experiment data folder, the SummaryWriter folder and the experiment outputs
# This is necessary in order to be able to download this folders

# %%
# import shutil

# shutil.make_archive('experiment_data_compressed',
#                     format="zip",
#                     root_dir='data/')

# shutil.make_archive('runs_compressed',
#                     format="zip",
#                     root_dir='../runs/')

# shutil.make_archive('outputs_compressed',
#                     format="zip",
#                     root_dir='outputs/')
# Out:
# '/content/ODIR-5K-multi-label-classification/experiments/experiment_15/outputs_compressed.zip'
