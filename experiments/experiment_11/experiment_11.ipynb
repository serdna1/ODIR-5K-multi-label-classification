# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/serdna1/ODIR-5K-multi-label-classification/blob/main/experiments/experiment_3/experiment_11.ipynb)

# %% [markdown]
# # Download GitHub repository and data
# The repo wont be downloading in my local machine, since i already have it there. It will if someone is running this notebook on their own machine, colab, ...

# %%
import os
import zipfile

images_path = 'ODIR-5K-multi-label-classification/data/images/'

# If the experiments folder doesnt exist im not in my local machine
if not os.path.exists('../../experiments'):
    # Clone project repository
    # !git clone https://github.com/serdna1/ODIR-5K-multi-label-classification.git

    # Unzip images
    with zipfile.ZipFile(f'{images_path}/train_fov_cc_fov_224.zip', 'r') as zip_ref:
      print("Unzipping training images...")
      zip_ref.extractall(f'{images_path}/train_fov_cc_fov_224')
    # !rm ODIR-5K-multi-label-classification/data/images/train_fov_cc_fov_224.zip
    # !rm ODIR-5K-multi-label-classification/data/images/train_224.zip

    # Move to the experiment folder
    # %cd ODIR-5K-multi-label-classification/experiments/experiment_11/
# Out:
# Cloning into 'ODIR-5K-multi-label-classification'...
# remote: Enumerating objects: 329, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 329 (delta 37), reused 72 (delta 29), pack-reused 245
# Receiving objects: 100% (329/329), 75.29 MiB | 36.43 MiB/s, done.
# Resolving deltas: 100% (149/149), done.
# Unzipping training images...
# /content/ODIR-5K-multi-label-classification/experiments/experiment_2

# %% [markdown]
# # Drop some special patients from the dataset
# The background of some images is quite different from the rest ones. Therefore they wont be used for training.

# %%
import matplotlib.pyplot as plt
from PIL import Image

images_path = '../../data/images/train_fov_cc_fov_224'

special_images = ['2174_right.jpg', '2175_left.jpg', '2176_left.jpg', '2177_left.jpg',
                  '2177_right.jpg', '2178_right.jpg', '2179_left.jpg', '2179_right.jpg',
                  '2180_left.jpg', '2180_right.jpg', '2181_left.jpg', '2181_right.jpg',
                  '2182_left.jpg', '2182_right.jpg', '2957_left.jpg', '2957_right.jpg']

# Show one of this special images
image_path = f'{images_path}/{special_images[7]}'
img = Image.open(image_path)
plt.imshow(img)
plt.axis(False)
plt.title('Example of special image')
# Out:
# Text(0.5, 1.0, 'Example of special image')

# %%
import pandas as pd

original_annotations_path = '../../data/annotations/annotations.xlsx'
annotations_path = 'data/annotations.xlsx'

odir_df = pd.read_excel(original_annotations_path)

patients_to_drop_df = odir_df[odir_df['Left-Fundus'].isin(special_images) | odir_df['Right-Fundus'].isin(special_images)]
patients_to_drop_df # This are all the patients with one ore more of this spetial images
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1634  2174           65      Female  2174_left.jpg  2174_right.jpg
# 1635  2175           63        Male  2175_left.jpg  2175_right.jpg
# 1636  2176           82      Female  2176_left.jpg  2176_right.jpg
# 1637  2177           87        Male  2177_left.jpg  2177_right.jpg
# 1638  2178           84        Male  2178_left.jpg  2178_right.jpg
# 1639  2179           70      Female  2179_left.jpg  2179_right.jpg
# 1640  2180           66      Female  2180_left.jpg  2180_right.jpg
# 1641  2181           79      Female  2181_left.jpg  2181_right.jpg
# 1642  2182           70        Male  2182_left.jpg  2182_right.jpg
# 2334  2957           62      Female  2957_left.jpg  2957_right.jpg
#
#      Left-Diagnostic Keywords Right-Diagnostic Keywords  N  D  G  C  A  H  M  \
# 1634            normal fundus                  cataract  0  0  0  1  0  0  0
# 1635                 cataract             normal fundus  0  0  0  1  0  0  0
# 1636                 cataract                  cataract  0  0  0  1  0  0  0
# 1637  normal fundus，lens dust                  cataract  0  0  0  1  0  0  0
# 1638                 cataract                  cataract  0  0  0  1  0  0  0
# 1639                 cataract                  cataract  0  0  0  1  0  0  0
# 1640                 cataract                  cataract  0  0  0  1  0  0  0
# 1641                 cataract                  cataract  0  0  0  1  0  0  0
# 1642                 cataract                  cataract  0  0  0  1  0  0  0
# 2334            normal fundus             normal fundus  1  0  0  0  0  0  0
#
#       O
# 1634  0
# 1635  0
# 1636  0
# 1637  0
# 1638  0
# 1639  0
# 1640  0
# 1641  0
# 1642  0
# 2334  0

# %%
from pathlib import Path

experiment_data_path = 'data/'

print(f'Annotations length before droping the rows with the special images: {len(odir_df)}')

odir_df = odir_df.drop(patients_to_drop_df.index) # Drop the special patients
Path(experiment_data_path).mkdir(parents=True, exist_ok=True) # Create the experiment data folder
odir_df.to_excel(annotations_path) # Save annotations without the special patients

print(f'Annotations length after droping the rows with the special images: {len(odir_df)}')
# Out:
# Annotations length before droping the rows with the special images: 3500
# Annotations length after droping the rows with the special images: 3490

# %% [markdown]
# # Check dataset label distribution

# %%
label_names = ['N','D','G','C','A','H','M','O']

total_label_list = []
for label in label_names:
    total_label = int(odir_df.loc[:, [label]].sum())
    total_label_list.append(total_label)

plt.figure(figsize=(16,4))

bar = plt.bar(label_names, total_label_list)

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f}', ha='center', va='bottom')

plt.xlabel(f'Label')
plt.ylabel(f'No. of images')
plt.title(f'Label distribution')
# Out:
# Text(0.5, 1.0, 'Label distribution')

# %% [markdown]
# # Split dataset into train and validation

# %%
os.chdir('../../scripts/')
from utils import split_annotations
os.chdir('../experiments/experiment_11/')

# %%
# Split the original annotations file into train and validation annotations files
# val_ratio = 0.2 (value by default)
split_annotations(annotations_path, experiment_data_path, test_split=False)

# Read the previous three created .xlsx files into dataframes
train_df = pd.read_excel(f'{experiment_data_path}/train_annotations.xlsx')
val_df = pd.read_excel(f'{experiment_data_path}/val_annotations.xlsx')

len(train_df), len(val_df)
# Out:
# (2792, 698)

# %% [markdown]
# # Check train and validation datasets label distribution

# %%
import numpy as np

barWidth = 0.3333
fig = plt.subplots(figsize =(16, 4))

# Set height of bars
total_label_train_list = [int(train_df.loc[:, [label]].sum()) for label in label_names]
total_label_val_list = [int(val_df.loc[:, [label]].sum()) for label in label_names]
 
# Set position of bar on X axis
br_train = np.arange(len(label_names))
br_val = [x + barWidth for x in br_train]
 
# Make the plot
bar_train = plt.bar(br_train, total_label_train_list, color ='r', width = barWidth,
                    edgecolor ='grey', label ='train')
bar_val = plt.bar(br_val, total_label_val_list, color ='b', width = barWidth,
                  edgecolor ='grey', label ='val')

# Plot the height label on top of each bar
for bar in [bar_train, bar_val]:
    for rect in bar:
        height = rect.get_height()
        plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f}', ha='center', va='bottom')

plt.title(f'Train/Validation distribution')
plt.xlabel('Label')
plt.ylabel('Nº of images')
plt.xticks([r + barWidth/2 for r in range(len(total_label_train_list))], label_names)
 
plt.legend()
plt.show()

# %% [markdown]
# # Train the model

# %%
# %run ../../scripts/train.py -h # Run this line to check the train script arguments
# Out:
# usage: train.py [-h] [--random_seed RANDOM_SEED] [--images_path IMAGES_PATH]
#                 [--use_normalization]
#                 [--train_annotations_path TRAIN_ANNOTATIONS_PATH]
#                 [--val_annotations_path VAL_ANNOTATIONS_PATH]
#                 [--batch_size BATCH_SIZE] [--num_workers NUM_WORKERS]
#                 [--lr LR] [--momentum MOMENTUM] [--lr_scheduler LR_SCHEDULER]
#                 [--linear_lr_scheduler_total_iters LINEAR_LR_SCHEDULER_TOTAL_ITERS]
#                 [--linear_lr_scheduler_start_factor LINEAR_LR_SCHEDULER_START_FACTOR]
#                 [--linear_lr_scheduler_end_factor LINEAR_LR_SCHEDULER_END_FACTOR]
#                 [--epochs EPOCHS] [--patience PATIENCE]
#                 [--experiment_name EXPERIMENT_NAME] [--extra EXTRA]
#
# Train a network for image multi-label classification on ODIR-5K.
#
# options:
#   -h, --help            show this help message and exit
#   --random_seed RANDOM_SEED
#                         Sets random seed for reproducibility (default: 42).
#   --images_path IMAGES_PATH
#                         Path of ODIR training images (default:
#                         /kaggle/input/odir-size-512/odir-size-512).
#   --use_normalization   If set the images are normalized the same way the
#                         imagenet images where normalized to train the resnet50
#                         used here.
#   --train_annotations_path TRAIN_ANNOTATIONS_PATH
#                         Path of train annotations file (default:
#                         /kaggle/input/odir-size-512/train_annotations.xlsx).
#   --val_annotations_path VAL_ANNOTATIONS_PATH
#                         Path of validation annotations file (default:
#                         /kaggle/input/odir-size-512/val_annotations.xlsx).
#   --batch_size BATCH_SIZE
#                         Batch size for data loaders (default: 32).
#   --num_workers NUM_WORKERS
#                         Number of workers for data loaders (default:
#                         os.cpu_count()).
#   --lr LR               Specifies learning rate for optimizer (default: 1e-3).
#   --momentum MOMENTUM   Specifies momentum for optimizer (default: 0.9).
#   --lr_scheduler LR_SCHEDULER
#                         Learning rate scheduler (default: None)
#   --linear_lr_scheduler_total_iters LINEAR_LR_SCHEDULER_TOTAL_ITERS
#                         Number of steps that the linear lr scheduler decays
#                         the learning rate (default: 50).
#   --linear_lr_scheduler_start_factor LINEAR_LR_SCHEDULER_START_FACTOR
#                         Start factor of the linear lr scheduler (default: 1).
#   --linear_lr_scheduler_end_factor LINEAR_LR_SCHEDULER_END_FACTOR
#                         End factor of the linear lr scheduler (default: 0.1).
#   --epochs EPOCHS       Number of training epochs (default: 5).
#   --patience PATIENCE   How long to wait after last time validation loss
#                         improved (default: 1).
#   --experiment_name EXPERIMENT_NAME
#                         Name of the experiment" (default: experiment_0).
#   --extra EXTRA         Extra info about the experiment (default: None).

# %%
# Arguments that will be passed to the train script
images_path = '../../data/images/train_fov_cc_fov_224'
train_annotations_path = 'data/train_annotations.xlsx'
val_annotations_path = 'data/val_annotations.xlsx'
lr = 0.05
lr_scheduler = 'LinearLR'
batch_size = 32
epochs = 100
patience = 20
experiment_name = 'experiment_11'

# %%
# %run ../../scripts/train.py --images_path {images_path} --train_annotations_path {train_annotations_path} --val_annotations_path {val_annotations_path}\
                            --batch_size {batch_size} --epochs {epochs} --patience {patience} --experiment_name {experiment_name} --use_normalization\
                            --lr {lr} --lr_scheduler {lr_scheduler} --use_weighted_loss
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 152MB/s]
# [INFO] Created new resnet50_dual model.
# [INFO] Created SummaryWriter, saving to: ../runs/resnet50_dual/experiment_2...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ep: 0 | t_loss: 0.3588 | t_kappa: 0.0088 | t_f1: 0.0494 | t_auc: 0.5896 | t_final: 0.2159 | v_loss: 0.3389 | v_kappa: 0.0309 | v_f1: 0.0638 | v_auc: 0.6285 | v_final: 0.2411
# Validation loss decreased (inf --> 0.338917).  Saving model ...
# Ep: 1 | t_loss: 0.3074 | t_kappa: 0.1308 | t_f1: 0.2085 | t_auc: 0.7149 | t_final: 0.3514 | v_loss: 0.3267 | v_kappa: 0.1550 | v_f1: 0.1906 | v_auc: 0.6573 | v_final: 0.3343
# Validation loss decreased (0.338917 --> 0.326684).  Saving model ...
# Ep: 2 | t_loss: 0.2934 | t_kappa: 0.2089 | t_f1: 0.2894 | t_auc: 0.7466 | t_final: 0.4150 | v_loss: 0.3207 | v_kappa: 0.1970 | v_f1: 0.2303 | v_auc: 0.6753 | v_final: 0.3675
# Validation loss decreased (0.326684 --> 0.320711).  Saving model ...
# Ep: 3 | t_loss: 0.2813 | t_kappa: 0.2460 | t_f1: 0.3451 | t_auc: 0.7762 | t_final: 0.4558 | v_loss: 0.3182 | v_kappa: 0.2014 | v_f1: 0.2315 | v_auc: 0.6767 | v_final: 0.3699
# Validation loss decreased (0.320711 --> 0.318178).  Saving model ...
# Ep: 4 | t_loss: 0.2740 | t_kappa: 0.2604 | t_f1: 0.3639 | t_auc: 0.7948 | t_final: 0.4730 | v_loss: 0.3107 | v_kappa: 0.2256 | v_f1: 0.2819 | v_auc: 0.6900 | v_final: 0.3992
# Validation loss decreased (0.318178 --> 0.310730).  Saving model ...
# Ep: 5 | t_loss: 0.2668 | t_kappa: 0.2818 | t_f1: 0.3831 | t_auc: 0.8128 | t_final: 0.4926 | v_loss: 0.3133 | v_kappa: 0.2331 | v_f1: 0.2663 | v_auc: 0.6893 | v_final: 0.3962
# EarlyStopping counter: 1 out of 20
# Ep: 6 | t_loss: 0.2599 | t_kappa: 0.2995 | t_f1: 0.4241 | t_auc: 0.8283 | t_final: 0.5173 | v_loss: 0.3127 | v_kappa: 0.2288 | v_f1: 0.3037 | v_auc: 0.6913 | v_final: 0.4079
# EarlyStopping counter: 2 out of 20
# Ep: 7 | t_loss: 0.2545 | t_kappa: 0.3174 | t_f1: 0.4392 | t_auc: 0.8389 | t_final: 0.5318 | v_loss: 0.3068 | v_kappa: 0.2321 | v_f1: 0.3144 | v_auc: 0.6950 | v_final: 0.4138
# Validation loss decreased (0.310730 --> 0.306766).  Saving model ...
# Ep: 8 | t_loss: 0.2497 | t_kappa: 0.3325 | t_f1: 0.4599 | t_auc: 0.8445 | t_final: 0.5457 | v_loss: 0.3036 | v_kappa: 0.2366 | v_f1: 0.3150 | v_auc: 0.6962 | v_final: 0.4159
# Validation loss decreased (0.306766 --> 0.303603).  Saving model ...
# Ep: 9 | t_loss: 0.2457 | t_kappa: 0.3377 | t_f1: 0.4740 | t_auc: 0.8537 | t_final: 0.5551 | v_loss: 0.3090 | v_kappa: 0.2457 | v_f1: 0.3222 | v_auc: 0.6929 | v_final: 0.4203
# EarlyStopping counter: 1 out of 20
# Ep: 10 | t_loss: 0.2440 | t_kappa: 0.3605 | t_f1: 0.4789 | t_auc: 0.8530 | t_final: 0.5641 | v_loss: 0.3071 | v_kappa: 0.2226 | v_f1: 0.3071 | v_auc: 0.7024 | v_final: 0.4107
# EarlyStopping counter: 2 out of 20
# Ep: 11 | t_loss: 0.2380 | t_kappa: 0.3680 | t_f1: 0.4961 | t_auc: 0.8666 | t_final: 0.5769 | v_loss: 0.3074 | v_kappa: 0.2423 | v_f1: 0.3319 | v_auc: 0.6980 | v_final: 0.4241
# EarlyStopping counter: 3 out of 20
# Ep: 12 | t_loss: 0.2338 | t_kappa: 0.3797 | t_f1: 0.5201 | t_auc: 0.8736 | t_final: 0.5911 | v_loss: 0.3034 | v_kappa: 0.2425 | v_f1: 0.3215 | v_auc: 0.7050 | v_final: 0.4230
# Validation loss decreased (0.303603 --> 0.303382).  Saving model ...
# Ep: 13 | t_loss: 0.2338 | t_kappa: 0.3814 | t_f1: 0.5183 | t_auc: 0.8694 | t_final: 0.5897 | v_loss: 0.3054 | v_kappa: 0.2444 | v_f1: 0.3007 | v_auc: 0.7055 | v_final: 0.4169
# EarlyStopping counter: 1 out of 20
# Ep: 14 | t_loss: 0.2286 | t_kappa: 0.3976 | t_f1: 0.5332 | t_auc: 0.8807 | t_final: 0.6038 | v_loss: 0.3018 | v_kappa: 0.2726 | v_f1: 0.3229 | v_auc: 0.7037 | v_final: 0.4331
# Validation loss decreased (0.303382 --> 0.301761).  Saving model ...
# Ep: 15 | t_loss: 0.2270 | t_kappa: 0.4110 | t_f1: 0.5402 | t_auc: 0.8814 | t_final: 0.6109 | v_loss: 0.3041 | v_kappa: 0.2742 | v_f1: 0.3551 | v_auc: 0.7030 | v_final: 0.4441
# EarlyStopping counter: 1 out of 20
# Ep: 16 | t_loss: 0.2240 | t_kappa: 0.4195 | t_f1: 0.5520 | t_auc: 0.8866 | t_final: 0.6194 | v_loss: 0.3021 | v_kappa: 0.2684 | v_f1: 0.3429 | v_auc: 0.7047 | v_final: 0.4387
# EarlyStopping counter: 2 out of 20
# Ep: 17 | t_loss: 0.2226 | t_kappa: 0.4240 | t_f1: 0.5511 | t_auc: 0.8885 | t_final: 0.6212 | v_loss: 0.3023 | v_kappa: 0.2582 | v_f1: 0.3330 | v_auc: 0.7040 | v_final: 0.4317
# EarlyStopping counter: 3 out of 20
# Ep: 18 | t_loss: 0.2193 | t_kappa: 0.4483 | t_f1: 0.5752 | t_auc: 0.8921 | t_final: 0.6385 | v_loss: 0.3039 | v_kappa: 0.2425 | v_f1: 0.3426 | v_auc: 0.6993 | v_final: 0.4281
# EarlyStopping counter: 4 out of 20
# Ep: 19 | t_loss: 0.2167 | t_kappa: 0.4480 | t_f1: 0.5752 | t_auc: 0.8985 | t_final: 0.6406 | v_loss: 0.3033 | v_kappa: 0.2466 | v_f1: 0.3299 | v_auc: 0.7092 | v_final: 0.4286
# EarlyStopping counter: 5 out of 20
# Ep: 20 | t_loss: 0.2142 | t_kappa: 0.4566 | t_f1: 0.5868 | t_auc: 0.9019 | t_final: 0.6484 | v_loss: 0.3025 | v_kappa: 0.2609 | v_f1: 0.3433 | v_auc: 0.7038 | v_final: 0.4360
# EarlyStopping counter: 6 out of 20
# Ep: 21 | t_loss: 0.2143 | t_kappa: 0.4566 | t_f1: 0.5904 | t_auc: 0.9003 | t_final: 0.6491 | v_loss: 0.3016 | v_kappa: 0.2666 | v_f1: 0.3467 | v_auc: 0.6998 | v_final: 0.4377
# Validation loss decreased (0.301761 --> 0.301602).  Saving model ...
# Ep: 22 | t_loss: 0.2117 | t_kappa: 0.4734 | t_f1: 0.5957 | t_auc: 0.9055 | t_final: 0.6582 | v_loss: 0.3025 | v_kappa: 0.2309 | v_f1: 0.3377 | v_auc: 0.7033 | v_final: 0.4240
# EarlyStopping counter: 1 out of 20
# Ep: 23 | t_loss: 0.2082 | t_kappa: 0.4779 | t_f1: 0.6076 | t_auc: 0.9075 | t_final: 0.6643 | v_loss: 0.3022 | v_kappa: 0.2512 | v_f1: 0.3375 | v_auc: 0.7028 | v_final: 0.4305
# EarlyStopping counter: 2 out of 20
# Ep: 24 | t_loss: 0.2084 | t_kappa: 0.4749 | t_f1: 0.6057 | t_auc: 0.9073 | t_final: 0.6627 | v_loss: 0.3043 | v_kappa: 0.2726 | v_f1: 0.3539 | v_auc: 0.6992 | v_final: 0.4419
# EarlyStopping counter: 3 out of 20
# Ep: 25 | t_loss: 0.2065 | t_kappa: 0.4824 | t_f1: 0.6074 | t_auc: 0.9098 | t_final: 0.6666 | v_loss: 0.3047 | v_kappa: 0.2930 | v_f1: 0.3377 | v_auc: 0.6946 | v_final: 0.4418
# EarlyStopping counter: 4 out of 20
# Ep: 26 | t_loss: 0.2032 | t_kappa: 0.5081 | t_f1: 0.6198 | t_auc: 0.9113 | t_final: 0.6797 | v_loss: 0.2998 | v_kappa: 0.2610 | v_f1: 0.3474 | v_auc: 0.7067 | v_final: 0.4384
# Validation loss decreased (0.301602 --> 0.299847).  Saving model ...
# Ep: 27 | t_loss: 0.2060 | t_kappa: 0.4729 | t_f1: 0.6029 | t_auc: 0.9068 | t_final: 0.6609 | v_loss: 0.3002 | v_kappa: 0.2990 | v_f1: 0.3619 | v_auc: 0.7070 | v_final: 0.4560
# EarlyStopping counter: 1 out of 20
# Ep: 28 | t_loss: 0.2027 | t_kappa: 0.5075 | t_f1: 0.6284 | t_auc: 0.9139 | t_final: 0.6833 | v_loss: 0.3053 | v_kappa: 0.2639 | v_f1: 0.3544 | v_auc: 0.6986 | v_final: 0.4390
# EarlyStopping counter: 2 out of 20
# Ep: 29 | t_loss: 0.2031 | t_kappa: 0.5187 | t_f1: 0.6280 | t_auc: 0.9108 | t_final: 0.6858 | v_loss: 0.3009 | v_kappa: 0.2765 | v_f1: 0.3608 | v_auc: 0.7018 | v_final: 0.4464
# EarlyStopping counter: 3 out of 20
# Ep: 30 | t_loss: 0.1994 | t_kappa: 0.5230 | t_f1: 0.6460 | t_auc: 0.9156 | t_final: 0.6948 | v_loss: 0.3024 | v_kappa: 0.2580 | v_f1: 0.3421 | v_auc: 0.7041 | v_final: 0.4347
# EarlyStopping counter: 4 out of 20
# Ep: 31 | t_loss: 0.2018 | t_kappa: 0.5115 | t_f1: 0.6262 | t_auc: 0.9142 | t_final: 0.6840 | v_loss: 0.3011 | v_kappa: 0.2603 | v_f1: 0.3473 | v_auc: 0.7069 | v_final: 0.4382
# EarlyStopping counter: 5 out of 20
# Ep: 32 | t_loss: 0.1984 | t_kappa: 0.5215 | t_f1: 0.6382 | t_auc: 0.9189 | t_final: 0.6929 | v_loss: 0.3016 | v_kappa: 0.2864 | v_f1: 0.3590 | v_auc: 0.7035 | v_final: 0.4497
# EarlyStopping counter: 6 out of 20
# Ep: 33 | t_loss: 0.1955 | t_kappa: 0.5188 | t_f1: 0.6421 | t_auc: 0.9200 | t_final: 0.6936 | v_loss: 0.3038 | v_kappa: 0.2636 | v_f1: 0.3583 | v_auc: 0.7069 | v_final: 0.4429
# EarlyStopping counter: 7 out of 20
# Ep: 34 | t_loss: 0.1951 | t_kappa: 0.5248 | t_f1: 0.6444 | t_auc: 0.9224 | t_final: 0.6972 | v_loss: 0.3036 | v_kappa: 0.2542 | v_f1: 0.3492 | v_auc: 0.7037 | v_final: 0.4357
# EarlyStopping counter: 8 out of 20
# Ep: 35 | t_loss: 0.1970 | t_kappa: 0.5339 | t_f1: 0.6540 | t_auc: 0.9203 | t_final: 0.7027 | v_loss: 0.3049 | v_kappa: 0.2601 | v_f1: 0.3327 | v_auc: 0.7037 | v_final: 0.4322
# EarlyStopping counter: 9 out of 20
# Ep: 36 | t_loss: 0.1956 | t_kappa: 0.5270 | t_f1: 0.6419 | t_auc: 0.9216 | t_final: 0.6968 | v_loss: 0.3032 | v_kappa: 0.2739 | v_f1: 0.3466 | v_auc: 0.7000 | v_final: 0.4402
# EarlyStopping counter: 10 out of 20
# Ep: 37 | t_loss: 0.1915 | t_kappa: 0.5344 | t_f1: 0.6571 | t_auc: 0.9261 | t_final: 0.7059 | v_loss: 0.3048 | v_kappa: 0.2697 | v_f1: 0.3780 | v_auc: 0.7034 | v_final: 0.4504
# EarlyStopping counter: 11 out of 20
# Ep: 38 | t_loss: 0.1934 | t_kappa: 0.5478 | t_f1: 0.6612 | t_auc: 0.9260 | t_final: 0.7116 | v_loss: 0.2994 | v_kappa: 0.2814 | v_f1: 0.3762 | v_auc: 0.7076 | v_final: 0.4551
# Validation loss decreased (0.299847 --> 0.299373).  Saving model ...
# Ep: 39 | t_loss: 0.1928 | t_kappa: 0.5402 | t_f1: 0.6614 | t_auc: 0.9259 | t_final: 0.7092 | v_loss: 0.3047 | v_kappa: 0.2700 | v_f1: 0.3614 | v_auc: 0.7029 | v_final: 0.4448
# EarlyStopping counter: 1 out of 20
# Ep: 40 | t_loss: 0.1915 | t_kappa: 0.5550 | t_f1: 0.6646 | t_auc: 0.9244 | t_final: 0.7147 | v_loss: 0.3020 | v_kappa: 0.2827 | v_f1: 0.3633 | v_auc: 0.7043 | v_final: 0.4501
# EarlyStopping counter: 2 out of 20
# Ep: 41 | t_loss: 0.1917 | t_kappa: 0.5462 | t_f1: 0.6621 | t_auc: 0.9240 | t_final: 0.7108 | v_loss: 0.2996 | v_kappa: 0.2967 | v_f1: 0.3846 | v_auc: 0.7104 | v_final: 0.4639
# EarlyStopping counter: 3 out of 20
# Ep: 42 | t_loss: 0.1893 | t_kappa: 0.5642 | t_f1: 0.6683 | t_auc: 0.9283 | t_final: 0.7203 | v_loss: 0.3030 | v_kappa: 0.2747 | v_f1: 0.3591 | v_auc: 0.7010 | v_final: 0.4449
# EarlyStopping counter: 4 out of 20
# Ep: 43 | t_loss: 0.1901 | t_kappa: 0.5606 | t_f1: 0.6741 | t_auc: 0.9272 | t_final: 0.7206 | v_loss: 0.3037 | v_kappa: 0.2690 | v_f1: 0.3510 | v_auc: 0.6988 | v_final: 0.4396
# EarlyStopping counter: 5 out of 20
# Ep: 44 | t_loss: 0.1909 | t_kappa: 0.5475 | t_f1: 0.6660 | t_auc: 0.9259 | t_final: 0.7131 | v_loss: 0.3065 | v_kappa: 0.2568 | v_f1: 0.3392 | v_auc: 0.6971 | v_final: 0.4310
# EarlyStopping counter: 6 out of 20
# Ep: 45 | t_loss: 0.1903 | t_kappa: 0.5624 | t_f1: 0.6725 | t_auc: 0.9268 | t_final: 0.7206 | v_loss: 0.3028 | v_kappa: 0.2514 | v_f1: 0.3388 | v_auc: 0.7048 | v_final: 0.4317
# EarlyStopping counter: 7 out of 20
# Ep: 46 | t_loss: 0.1875 | t_kappa: 0.5823 | t_f1: 0.6820 | t_auc: 0.9302 | t_final: 0.7315 | v_loss: 0.3008 | v_kappa: 0.2756 | v_f1: 0.3697 | v_auc: 0.7083 | v_final: 0.4512
# EarlyStopping counter: 8 out of 20
# Ep: 47 | t_loss: 0.1881 | t_kappa: 0.5492 | t_f1: 0.6673 | t_auc: 0.9306 | t_final: 0.7157 | v_loss: 0.3024 | v_kappa: 0.2759 | v_f1: 0.3521 | v_auc: 0.7007 | v_final: 0.4429
# EarlyStopping counter: 9 out of 20
# Ep: 48 | t_loss: 0.1866 | t_kappa: 0.5732 | t_f1: 0.6805 | t_auc: 0.9335 | t_final: 0.7291 | v_loss: 0.3064 | v_kappa: 0.2553 | v_f1: 0.3461 | v_auc: 0.6975 | v_final: 0.4329
# EarlyStopping counter: 10 out of 20
# Ep: 49 | t_loss: 0.1869 | t_kappa: 0.5703 | t_f1: 0.6814 | t_auc: 0.9303 | t_final: 0.7273 | v_loss: 0.3041 | v_kappa: 0.2702 | v_f1: 0.3517 | v_auc: 0.6998 | v_final: 0.4406
# EarlyStopping counter: 11 out of 20
# Ep: 50 | t_loss: 0.1876 | t_kappa: 0.5694 | t_f1: 0.6735 | t_auc: 0.9304 | t_final: 0.7244 | v_loss: 0.3068 | v_kappa: 0.2719 | v_f1: 0.3631 | v_auc: 0.6975 | v_final: 0.4442
# EarlyStopping counter: 12 out of 20
# Ep: 51 | t_loss: 0.1863 | t_kappa: 0.5692 | t_f1: 0.6784 | t_auc: 0.9334 | t_final: 0.7270 | v_loss: 0.3028 | v_kappa: 0.2516 | v_f1: 0.3494 | v_auc: 0.7047 | v_final: 0.4352
# EarlyStopping counter: 13 out of 20
# Ep: 52 | t_loss: 0.1873 | t_kappa: 0.5650 | t_f1: 0.6766 | t_auc: 0.9313 | t_final: 0.7243 | v_loss: 0.3001 | v_kappa: 0.2896 | v_f1: 0.3759 | v_auc: 0.7073 | v_final: 0.4576
# EarlyStopping counter: 14 out of 20
# Ep: 53 | t_loss: 0.1859 | t_kappa: 0.5812 | t_f1: 0.6862 | t_auc: 0.9324 | t_final: 0.7333 | v_loss: 0.3023 | v_kappa: 0.2868 | v_f1: 0.3645 | v_auc: 0.7046 | v_final: 0.4520
# EarlyStopping counter: 15 out of 20
# Ep: 54 | t_loss: 0.1863 | t_kappa: 0.5544 | t_f1: 0.6754 | t_auc: 0.9314 | t_final: 0.7204 | v_loss: 0.3041 | v_kappa: 0.2446 | v_f1: 0.3500 | v_auc: 0.7045 | v_final: 0.4331
# EarlyStopping counter: 16 out of 20
# Ep: 55 | t_loss: 0.1873 | t_kappa: 0.5785 | t_f1: 0.6718 | t_auc: 0.9301 | t_final: 0.7268 | v_loss: 0.3057 | v_kappa: 0.2784 | v_f1: 0.3760 | v_auc: 0.6999 | v_final: 0.4514
# EarlyStopping counter: 17 out of 20
# Ep: 56 | t_loss: 0.1867 | t_kappa: 0.5694 | t_f1: 0.6788 | t_auc: 0.9298 | t_final: 0.7260 | v_loss: 0.3031 | v_kappa: 0.2658 | v_f1: 0.3667 | v_auc: 0.7040 | v_final: 0.4455
# EarlyStopping counter: 18 out of 20
# Ep: 57 | t_loss: 0.1851 | t_kappa: 0.5704 | t_f1: 0.6795 | t_auc: 0.9334 | t_final: 0.7278 | v_loss: 0.3017 | v_kappa: 0.2873 | v_f1: 0.3701 | v_auc: 0.7059 | v_final: 0.4544
# EarlyStopping counter: 19 out of 20
# Ep: 58 | t_loss: 0.1875 | t_kappa: 0.5657 | t_f1: 0.6744 | t_auc: 0.9298 | t_final: 0.7233 | v_loss: 0.3059 | v_kappa: 0.2739 | v_f1: 0.3586 | v_auc: 0.6988 | v_final: 0.4438
# EarlyStopping counter: 20 out of 20
# Early stopping

# %% [markdown]
# Run the next cell to see the metrics trough the epochs using the tensorboard interface

# %%
# %reload_ext tensorboard
# %tensorboard --logdir ../runs

# %% [markdown]
# # Test the model with the validation dataset
# Since there is no access to the test annotatations (only to the images) the test will be performed on the validation dataset, to be able to see some results.

# %%
# %run ../../scripts/test.py -h # Run this line to check the test script arguments
# Out:
# usage: test.py [-h] [--model_path MODEL_PATH] [--images_path IMAGES_PATH]
#                [--test_annotations_path TEST_ANNOTATIONS_PATH]
#                [--use_normalization] [--batch_size BATCH_SIZE]
#                [--num_workers NUM_WORKERS]
#                [--ground_truth_path GROUND_TRUTH_PATH]
#                [--probs_path PROBS_PATH]
#
# Test a model with a dataset.
#
# options:
#   -h, --help            show this help message and exit
#   --model_path MODEL_PATH
#                         Path to the model to test the dataset with (default:
#                         outputs/resnet50_dual_experiment_0_model.pth).
#   --images_path IMAGES_PATH
#                         Path of test images (default:
#                         ../../data/train_fov_cc_fov_224/).
#   --test_annotations_path TEST_ANNOTATIONS_PATH
#                         Path of test annotations file (default:
#                         data/test_annotations.xlsx).
#   --use_normalization   If set the images are normalized the same way the
#                         imagenet images were normalized to train the resnet50
#                         used here.
#   --batch_size BATCH_SIZE
#                         Batch size for data loaders (default: 32).
#   --num_workers NUM_WORKERS
#                         Number of workers for data loaders (default:
#                         os.cpu_count()).
#   --ground_truth_path GROUND_TRUTH_PATH
#                         Path to store the ground truth labels used in test
#                         (default: None).
#   --probs_path PROBS_PATH
#                         Path to store the result probs of test (default:
#                         None).

# %%
test_annotations_path = 'data/val_annotations.xlsx' # val annotations are used for test
images_path = '../../data/images/train_fov_cc_fov_224'
model_path = 'outputs/resnet50_dual_experiment_11_model.pth'
ground_truth_path = 'outputs/ground_truth.xlsx'
probs_path = 'outputs/probs.xlsx'

# %%
# %run ../../scripts/test.py --model_path {model_path} --images_path {images_path} --test_annotations_path {test_annotations_path} --use_normalization\
                           --ground_truth_path {ground_truth_path} --probs_path {probs_path}
# Out:
# [INFO] Created new resnet50_dual model.
# test_loss: 0.2994 | test_kappa: 0.2814 | test_f1: 0.3762 | test_auc: 0.7076 | test_final: 0.4551

# %% [markdown]
# # Run the ODIR_evaluation.py script on test (validation) dataset
# This is a file provided along with the data by the challenge. And its supposed to have an example on how to compute the kappa, f1, auc, and final score metrics but i dont think they are well computed here as they are always too good (as shown later, the cualitative results for test are much worst). As a result of this, i use my own version of this metrics (see the function compute_challenge_metrics on the metrics script). Either way i'll run it.

# %%
ground_truth_path = 'outputs/ground_truth.xlsx'
probs_path = 'outputs/probs.xlsx'
probs_csv_path = 'outputs/probs.csv'

probs_df = pd.read_excel(probs_path)
probs_df.to_csv(probs_csv_path, index=False) # The ODIR_evaluation script asks the probs file to be in .csv format

# %run ../../scripts/ODIR_evaluation.py {ground_truth_path} {probs_csv_path}
# Out:
# kappa score: 0.33318888680973435  f-1 score: 0.8610315186246418  AUC vlaue: 0.8628554091539529  Final Score: 0.6856919381961096

# %% [markdown]
# # Cuantitative results
# The test script prints some results as can be seen in the output of the previous cell. Now, lets see some more.

# %%
label_names = ['N','D','G','C','A','H','M','O']

ground_truth = pd.read_excel(ground_truth_path).loc[:, label_names].to_numpy()
probs = pd.read_excel(probs_path).loc[:, label_names].to_numpy()

# %%
from sklearn import metrics
os.chdir('../../scripts')
from metrics import plot_confusion_matrices
os.chdir('../experiments/experiment_11/')

# Print test classification report
print('Clasification report:')
print(
    metrics.classification_report(
        ground_truth,
        probs>0.5,
        output_dict=False,
        target_names=label_names,
        zero_division=0
    )
)

# Plot one confusion matrix for each label
plot_confusion_matrices(ground_truth, probs, label_names)
# Out:
# Clasification report:
#               precision    recall  f1-score   support
#
#            N       0.52      0.46      0.49       214
#            D       0.49      0.37      0.42       226
#            G       0.67      0.12      0.20        34
#            C       0.88      0.59      0.71        37
#            A       0.00      0.00      0.00        37
#            H       0.00      0.00      0.00        29
#            M       0.81      0.73      0.77        30
#            O       0.53      0.16      0.25       217
#
#    micro avg       0.55      0.32      0.41       824
#    macro avg       0.49      0.30      0.36       824
# weighted avg       0.51      0.32      0.38       824
#  samples avg       0.35      0.34      0.34       824

# %% [markdown]
# # Cualitative results
# One patient with each disease (at least) is predicted. The original images are ploted along with their ground truth and predicted labels.

# %%
import torch
from torchvision import transforms
os.chdir('../../scripts')
from utils import load_model
from predict import pred_and_plot_image
os.chdir('../experiments/experiment_11/')

# %%
model = load_model(model_path)

test_df = pd.read_excel(test_annotations_path)

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# [INFO] Created new resnet50_dual model.

# %% [markdown]
# You can run the next cell multiple times to see different results

# %%
for label in label_names:
    patient = test_df[test_df[label] == 1].sample(replace=True).reset_index(drop=True)
    pred_and_plot_image(model=model,
                        left_image_path=f'{images_path}/{patient.at[0, "Left-Fundus"]}',
                        right_image_path=f'{images_path}/{patient.at[0, "Right-Fundus"]}',
                        transform=transform,
                        device=device,
                        label_names=label_names,
                        ground_truth=patient.loc[0, label_names].to_numpy())

# %% [markdown]
# # Zip the experiment data folder, the SummaryWriter folder and the experiment outputs
# This is necessary in order to be able to download this folders

# %%
# import shutil

# shutil.make_archive('experiment_data_compressed',
#                     format="zip",
#                     root_dir='data/')

# shutil.make_archive('runs_compressed',
#                     format="zip",
#                     root_dir='../runs/')

# shutil.make_archive('outputs_compressed',
#                     format="zip",
#                     root_dir='outputs/')
# Out:
# '/content/ODIR-5K-multi-label-classification/experiments/experiment_2/outputs_compressed.zip'
