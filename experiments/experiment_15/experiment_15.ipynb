# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/serdna1/ODIR-5K-multi-label-classification/blob/main/experiments/experiment_15/experiment_15.ipynb)

# %% [markdown]
# # Download GitHub repository and data
# The repo wont be downloading in my local machine, since i already have it there. It will if someone is running this notebook on their own machine, colab, ...

# %%
import os
import zipfile

# Unzip images (will only work after upload the file to colab working directory)
with zipfile.ZipFile('train_fov_cc_fov_512.zip', 'r') as zip_ref:
  print("Unzipping training images...")
  zip_ref.extractall(f'train_fov_cc_fov_512')
# !rm train_fov_cc_fov_512.zip

images_path = 'train_fov_cc_fov_512/'

# If the experiments folder doesnt exist im not in my local machine
if not os.path.exists('../../experiments'):
    # Clone project repository
    # !git clone https://github.com/serdna1/ODIR-5K-multi-label-classification.git

    # Move to the experiment folder
    # %cd ODIR-5K-multi-label-classification/experiments/experiment_15/
# Out:
# Unzipping training images...
# Cloning into 'ODIR-5K-multi-label-classification'...
# remote: Enumerating objects: 648, done.
# remote: Counting objects: 100% (138/138), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 648 (delta 61), reused 95 (delta 26), pack-reused 510
# Receiving objects: 100% (648/648), 99.66 MiB | 25.53 MiB/s, done.
# Resolving deltas: 100% (314/314), done.
# /content/ODIR-5K-multi-label-classification/experiments/experiment_15

# %% [markdown]
# # Drop some special patients from the dataset
# The background of some images is quite different from the rest ones. Therefore they wont be used for training.

# %%
import matplotlib.pyplot as plt
from PIL import Image

images_path = '../../../train_fov_cc_fov_512/'

special_images = ['2174_right.jpg', '2175_left.jpg', '2176_left.jpg', '2177_left.jpg',
                  '2177_right.jpg', '2178_right.jpg', '2179_left.jpg', '2179_right.jpg',
                  '2180_left.jpg', '2180_right.jpg', '2181_left.jpg', '2181_right.jpg',
                  '2182_left.jpg', '2182_right.jpg', '2957_left.jpg', '2957_right.jpg']

# Show one of this special images
image_path = f'{images_path}/{special_images[7]}'
img = Image.open(image_path)
plt.imshow(img)
plt.axis(False)
plt.title('Example of special image')
# Out:
# Text(0.5, 1.0, 'Example of special image')

# %%
import pandas as pd

original_annotations_path = '../../data/annotations/annotations.xlsx'
annotations_path = 'data/annotations.xlsx'

odir_df = pd.read_excel(original_annotations_path)

patients_to_drop_df = odir_df[odir_df['Left-Fundus'].isin(special_images) | odir_df['Right-Fundus'].isin(special_images)]
patients_to_drop_df # This are all the patients with one ore more of this spetial images
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1634  2174           65      Female  2174_left.jpg  2174_right.jpg
# 1635  2175           63        Male  2175_left.jpg  2175_right.jpg
# 1636  2176           82      Female  2176_left.jpg  2176_right.jpg
# 1637  2177           87        Male  2177_left.jpg  2177_right.jpg
# 1638  2178           84        Male  2178_left.jpg  2178_right.jpg
# 1639  2179           70      Female  2179_left.jpg  2179_right.jpg
# 1640  2180           66      Female  2180_left.jpg  2180_right.jpg
# 1641  2181           79      Female  2181_left.jpg  2181_right.jpg
# 1642  2182           70        Male  2182_left.jpg  2182_right.jpg
# 2334  2957           62      Female  2957_left.jpg  2957_right.jpg
#
#      Left-Diagnostic Keywords Right-Diagnostic Keywords  N  D  G  C  A  H  M  \
# 1634            normal fundus                  cataract  0  0  0  1  0  0  0
# 1635                 cataract             normal fundus  0  0  0  1  0  0  0
# 1636                 cataract                  cataract  0  0  0  1  0  0  0
# 1637  normal fundus，lens dust                  cataract  0  0  0  1  0  0  0
# 1638                 cataract                  cataract  0  0  0  1  0  0  0
# 1639                 cataract                  cataract  0  0  0  1  0  0  0
# 1640                 cataract                  cataract  0  0  0  1  0  0  0
# 1641                 cataract                  cataract  0  0  0  1  0  0  0
# 1642                 cataract                  cataract  0  0  0  1  0  0  0
# 2334            normal fundus             normal fundus  1  0  0  0  0  0  0
#
#       O
# 1634  0
# 1635  0
# 1636  0
# 1637  0
# 1638  0
# 1639  0
# 1640  0
# 1641  0
# 1642  0
# 2334  0

# %%
from pathlib import Path

experiment_data_path = 'data/'

print(f'Annotations length before droping the rows with the special images: {len(odir_df)}')

odir_df = odir_df.drop(patients_to_drop_df.index) # Drop the special patients
Path(experiment_data_path).mkdir(parents=True, exist_ok=True) # Create the experiment data folder
odir_df.to_excel(annotations_path) # Save annotations without the special patients

print(f'Annotations length after droping the rows with the special images: {len(odir_df)}')
# Out:
# Annotations length before droping the rows with the special images: 3500
# Annotations length after droping the rows with the special images: 3490

# %% [markdown]
# # Check dataset label distribution

# %%
label_names = ['N','D','G','C','A','H','M','O']

total_label_list = []
for label in label_names:
    total_label = int(odir_df.loc[:, [label]].sum())
    total_label_list.append(total_label)

plt.figure(figsize=(16,4))

bar = plt.bar(label_names, total_label_list)

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f}', ha='center', va='bottom')

plt.xlabel(f'Label')
plt.ylabel(f'No. of images')
plt.title(f'Label distribution')
# Out:
# Text(0.5, 1.0, 'Label distribution')

# %% [markdown]
# # Split dataset into train and validation

# %%
os.chdir('../../scripts/')
from utils import split_annotations
os.chdir('../experiments/experiment_15/')

# %%
# Split the original annotations file into train and validation annotations files
# val_ratio = 0.2 (value by default)
split_annotations(annotations_path, experiment_data_path, test_split=False)

# Read the previous three created .xlsx files into dataframes
train_df = pd.read_excel(f'{experiment_data_path}/train_annotations.xlsx')
val_df = pd.read_excel(f'{experiment_data_path}/val_annotations.xlsx')

len(train_df), len(val_df)
# Out:
# (2792, 698)

# %% [markdown]
# # Check train and validation datasets label distribution

# %%
import numpy as np

barWidth = 0.3333
fig = plt.subplots(figsize =(16, 4))

# Set height of bars
total_label_train_list = [int(train_df.loc[:, [label]].sum()) for label in label_names]
total_label_val_list = [int(val_df.loc[:, [label]].sum()) for label in label_names]

# Set position of bar on X axis
br_train = np.arange(len(label_names))
br_val = [x + barWidth for x in br_train]

# Make the plot
bar_train = plt.bar(br_train, total_label_train_list, color ='r', width = barWidth,
                    edgecolor ='grey', label ='train')
bar_val = plt.bar(br_val, total_label_val_list, color ='b', width = barWidth,
                  edgecolor ='grey', label ='val')

# Plot the height label on top of each bar
for bar in [bar_train, bar_val]:
    for rect in bar:
        height = rect.get_height()
        plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f}', ha='center', va='bottom')

plt.title(f'Train/Validation distribution')
plt.xlabel('Label')
plt.ylabel('Nº of images')
plt.xticks([r + barWidth/2 for r in range(len(total_label_train_list))], label_names)

plt.legend()
plt.show()

# %% [markdown]
# # Train the model

# %%
# %run ../../scripts/train.py -h # Run this line to check the train script arguments
# Out:
# usage: train.py [-h] [--random_seed RANDOM_SEED] [--model_name MODEL_NAME] [--fine_tune]
#                 [--images_path IMAGES_PATH] [--use_data_augmentation] [--crop_size CROP_SIZE]
#                 [--use_normalization] [--train_annotations_path TRAIN_ANNOTATIONS_PATH]
#                 [--val_annotations_path VAL_ANNOTATIONS_PATH] [--batch_size BATCH_SIZE]
#                 [--use_multilabel_balanced_random_sampler] [--num_workers NUM_WORKERS]
#                 [--use_weighted_loss] [--lr LR] [--momentum MOMENTUM]
#                 [--lr_scheduler LR_SCHEDULER]
#                 [--linear_lr_scheduler_total_iters LINEAR_LR_SCHEDULER_TOTAL_ITERS]
#                 [--linear_lr_scheduler_start_factor LINEAR_LR_SCHEDULER_START_FACTOR]
#                 [--linear_lr_scheduler_end_factor LINEAR_LR_SCHEDULER_END_FACTOR]
#                 [--cyclic_lr_scheduler_base_lr CYCLIC_LR_SCHEDULER_BASE_LR]
#                 [--cyclic_lr_scheduler_max_lr CYCLIC_LR_SCHEDULER_MAX_LR]
#                 [--cyclic_lr_scheduler_step_size_up CYCLIC_LR_SCHEDULER_STEP_SIZE_UP]
#                 [--epochs EPOCHS] [--patience PATIENCE] [--experiment_name EXPERIMENT_NAME]
#                 [--extra EXTRA]
#
# Train a network for image multi-label classification on ODIR-5K.
#
# options:
#   -h, --help            show this help message and exit
#   --random_seed RANDOM_SEED
#                         Sets random seed for reproducibility (default: 42).
#   --model_name MODEL_NAME
#                         Model arquitecture for training (default: resnet50_dual).
#   --fine_tune           If set dont freeze the backbone weights
#   --images_path IMAGES_PATH
#                         Path of ODIR training images (default: /kaggle/input/odir-size-512/odir-
#                         size-512).
#   --use_data_augmentation
#                         If set augment training data.
#   --crop_size CROP_SIZE
#                         Crop size used in data augmentation. Random crop in train, center crop in
#                         validation (default: 224)
#   --use_normalization   If set the images are normalized the same way the imagenet images where
#                         normalized to train the resnet50 used here.
#   --train_annotations_path TRAIN_ANNOTATIONS_PATH
#                         Path of train annotations file (default: /kaggle/input/odir-
#                         size-512/train_annotations.xlsx).
#   --val_annotations_path VAL_ANNOTATIONS_PATH
#                         Path of validation annotations file (default: /kaggle/input/odir-
#                         size-512/val_annotations.xlsx).
#   --batch_size BATCH_SIZE
#                         Batch size for data loaders (default: 32).
#   --use_multilabel_balanced_random_sampler
#                         Use a custom multilabel random sampler that balance the train dataset.
#   --num_workers NUM_WORKERS
#                         Number of workers for data loaders (default: os.cpu_count()).
#   --use_weighted_loss   If set the loss function uses the pos_weight param to consider the dataset
#                         imbalance.
#   --lr LR               Specifies learning rate for optimizer (default: 1e-3).
#   --momentum MOMENTUM   Specifies momentum for optimizer (default: 0.9).
#   --lr_scheduler LR_SCHEDULER
#                         Learning rate scheduler (default: None)
#   --linear_lr_scheduler_total_iters LINEAR_LR_SCHEDULER_TOTAL_ITERS
#                         Number of steps that the linear lr scheduler decays the learning rate
#                         (default: 50).
#   --linear_lr_scheduler_start_factor LINEAR_LR_SCHEDULER_START_FACTOR
#                         Start factor of the linear lr scheduler (default: 1).
#   --linear_lr_scheduler_end_factor LINEAR_LR_SCHEDULER_END_FACTOR
#                         End factor of the linear lr scheduler (default: 0.1).
#   --cyclic_lr_scheduler_base_lr CYCLIC_LR_SCHEDULER_BASE_LR
#                         Initial learning rate which is the lower boundary in the cycle for each
#                         parameter group (default: 0.001).
#   --cyclic_lr_scheduler_max_lr CYCLIC_LR_SCHEDULER_MAX_LR
#                         Upper learning rate boundaries in the cycle for each parameter group
#                         (default: 0.1).
#   --cyclic_lr_scheduler_step_size_up CYCLIC_LR_SCHEDULER_STEP_SIZE_UP
#                         Number of training iterations in the increasing half of a cycle (default:
#                         10).
#   --epochs EPOCHS       Number of training epochs (default: 5).
#   --patience PATIENCE   How long to wait after last time validation loss improved (default: 1).
#   --experiment_name EXPERIMENT_NAME
#                         Name of the experiment" (default: experiment_0).
#   --extra EXTRA         Extra info about the experiment (default: None).

# %%
# Arguments that will be passed to the train script
images_path = '../../../train_fov_cc_fov_512/'
train_annotations_path = 'data/train_annotations.xlsx'
val_annotations_path = 'data/val_annotations.xlsx'
crop_size = 448
lr = 0.01
lr_scheduler = 'LinearLR'
batch_size = 16
epochs = 100
patience = 30
experiment_name = 'experiment_15'

# %%
# %run ../../scripts/train.py --images_path {images_path} --train_annotations_path {train_annotations_path} --val_annotations_path {val_annotations_path}\
                            --batch_size {batch_size} --epochs {epochs} --patience {patience} --experiment_name {experiment_name} --use_normalization\
                            --lr {lr} --lr_scheduler {lr_scheduler} --use_weighted_loss --fine_tune --use_data_augmentation --crop_size {crop_size}
# Out:
# [INFO] Created new resnet50_dual model.
# [INFO] Created SummaryWriter, saving to: ../runs/resnet50_dual/experiment_15...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ep: 0 | t_loss: 1.0361 | t_kappa: 0.1175 | t_f1: 0.3935 | t_auc: 0.6150 | t_final: 0.3754 | v_loss: 0.5496 | v_kappa: 0.2068 | v_f1: 0.4523 | v_auc: 0.6554 | v_final: 0.4382
# Validation loss decreased (inf --> 0.549636).  Saving model ...
# Ep: 1 | t_loss: 0.9060 | t_kappa: 0.2121 | t_f1: 0.4458 | t_auc: 0.6755 | t_final: 0.4445 | v_loss: 0.5888 | v_kappa: 0.2395 | v_f1: 0.4439 | v_auc: 0.6933 | v_final: 0.4589
# EarlyStopping counter: 1 out of 30
# Ep: 2 | t_loss: 0.8364 | t_kappa: 0.2760 | t_f1: 0.4913 | t_auc: 0.7235 | t_final: 0.4969 | v_loss: 0.4293 | v_kappa: 0.3496 | v_f1: 0.4941 | v_auc: 0.7406 | v_final: 0.5281
# Validation loss decreased (0.549636 --> 0.429337).  Saving model ...
# Ep: 3 | t_loss: 0.7770 | t_kappa: 0.3131 | t_f1: 0.5096 | t_auc: 0.7441 | t_final: 0.5223 | v_loss: 0.4701 | v_kappa: 0.3618 | v_f1: 0.5400 | v_auc: 0.7610 | v_final: 0.5543
# EarlyStopping counter: 1 out of 30
# Ep: 4 | t_loss: 0.7533 | t_kappa: 0.3323 | t_f1: 0.5252 | t_auc: 0.7587 | t_final: 0.5387 | v_loss: 0.4626 | v_kappa: 0.3480 | v_f1: 0.5216 | v_auc: 0.7606 | v_final: 0.5434
# EarlyStopping counter: 2 out of 30
# Ep: 5 | t_loss: 0.7351 | t_kappa: 0.3473 | t_f1: 0.5358 | t_auc: 0.7639 | t_final: 0.5490 | v_loss: 0.4207 | v_kappa: 0.3714 | v_f1: 0.5405 | v_auc: 0.7789 | v_final: 0.5636
# Validation loss decreased (0.429337 --> 0.420672).  Saving model ...
# Ep: 6 | t_loss: 0.7091 | t_kappa: 0.3726 | t_f1: 0.5579 | t_auc: 0.7861 | t_final: 0.5722 | v_loss: 0.4172 | v_kappa: 0.4057 | v_f1: 0.5429 | v_auc: 0.7790 | v_final: 0.5759
# Validation loss decreased (0.420672 --> 0.417194).  Saving model ...
# Ep: 7 | t_loss: 0.6881 | t_kappa: 0.3819 | t_f1: 0.5574 | t_auc: 0.7876 | t_final: 0.5756 | v_loss: 0.4239 | v_kappa: 0.3899 | v_f1: 0.5542 | v_auc: 0.7839 | v_final: 0.5760
# EarlyStopping counter: 1 out of 30
# Ep: 8 | t_loss: 0.6472 | t_kappa: 0.3994 | t_f1: 0.5696 | t_auc: 0.8010 | t_final: 0.5900 | v_loss: 0.3704 | v_kappa: 0.4501 | v_f1: 0.5863 | v_auc: 0.7953 | v_final: 0.6106
# Validation loss decreased (0.417194 --> 0.370393).  Saving model ...
# Ep: 9 | t_loss: 0.6423 | t_kappa: 0.4092 | t_f1: 0.5832 | t_auc: 0.8121 | t_final: 0.6015 | v_loss: 0.3808 | v_kappa: 0.4202 | v_f1: 0.5507 | v_auc: 0.7885 | v_final: 0.5865
# EarlyStopping counter: 1 out of 30
# Ep: 10 | t_loss: 0.6091 | t_kappa: 0.4273 | t_f1: 0.5858 | t_auc: 0.8164 | t_final: 0.6098 | v_loss: 0.4688 | v_kappa: 0.4222 | v_f1: 0.5617 | v_auc: 0.7935 | v_final: 0.5925
# EarlyStopping counter: 2 out of 30
# Ep: 11 | t_loss: 0.6044 | t_kappa: 0.4342 | t_f1: 0.5941 | t_auc: 0.8174 | t_final: 0.6152 | v_loss: 0.3994 | v_kappa: 0.4367 | v_f1: 0.5816 | v_auc: 0.8050 | v_final: 0.6077
# EarlyStopping counter: 3 out of 30
# Ep: 12 | t_loss: 0.5689 | t_kappa: 0.4611 | t_f1: 0.6076 | t_auc: 0.8269 | t_final: 0.6319 | v_loss: 0.4000 | v_kappa: 0.4491 | v_f1: 0.5798 | v_auc: 0.7992 | v_final: 0.6094
# EarlyStopping counter: 4 out of 30
# Ep: 13 | t_loss: 0.5536 | t_kappa: 0.4662 | t_f1: 0.6064 | t_auc: 0.8236 | t_final: 0.6321 | v_loss: 0.4296 | v_kappa: 0.4407 | v_f1: 0.5900 | v_auc: 0.8126 | v_final: 0.6144
# EarlyStopping counter: 5 out of 30
# Ep: 14 | t_loss: 0.5600 | t_kappa: 0.4612 | t_f1: 0.6077 | t_auc: 0.8309 | t_final: 0.6332 | v_loss: 0.3754 | v_kappa: 0.4421 | v_f1: 0.5845 | v_auc: 0.8142 | v_final: 0.6136
# EarlyStopping counter: 6 out of 30
# Ep: 15 | t_loss: 0.5287 | t_kappa: 0.4722 | t_f1: 0.6156 | t_auc: 0.8366 | t_final: 0.6415 | v_loss: 0.3521 | v_kappa: 0.4755 | v_f1: 0.5972 | v_auc: 0.8116 | v_final: 0.6281
# Validation loss decreased (0.370393 --> 0.352096).  Saving model ...
# Ep: 16 | t_loss: 0.5205 | t_kappa: 0.4798 | t_f1: 0.6235 | t_auc: 0.8416 | t_final: 0.6483 | v_loss: 0.3319 | v_kappa: 0.4802 | v_f1: 0.6075 | v_auc: 0.8245 | v_final: 0.6374
# Validation loss decreased (0.352096 --> 0.331911).  Saving model ...
# Ep: 17 | t_loss: 0.4879 | t_kappa: 0.5062 | t_f1: 0.6297 | t_auc: 0.8438 | t_final: 0.6599 | v_loss: 0.4102 | v_kappa: 0.4577 | v_f1: 0.5964 | v_auc: 0.8113 | v_final: 0.6218
# EarlyStopping counter: 1 out of 30
# Ep: 18 | t_loss: 0.4982 | t_kappa: 0.4944 | t_f1: 0.6278 | t_auc: 0.8466 | t_final: 0.6562 | v_loss: 0.3234 | v_kappa: 0.4934 | v_f1: 0.6044 | v_auc: 0.8173 | v_final: 0.6383
# Validation loss decreased (0.331911 --> 0.323360).  Saving model ...
# Ep: 19 | t_loss: 0.4889 | t_kappa: 0.5113 | t_f1: 0.6429 | t_auc: 0.8576 | t_final: 0.6706 | v_loss: 0.3581 | v_kappa: 0.4969 | v_f1: 0.6031 | v_auc: 0.8195 | v_final: 0.6398
# EarlyStopping counter: 1 out of 30
# Ep: 20 | t_loss: 0.4749 | t_kappa: 0.5184 | t_f1: 0.6432 | t_auc: 0.8587 | t_final: 0.6735 | v_loss: 0.3162 | v_kappa: 0.5052 | v_f1: 0.6103 | v_auc: 0.8303 | v_final: 0.6486
# Validation loss decreased (0.323360 --> 0.316229).  Saving model ...
# Ep: 21 | t_loss: 0.4593 | t_kappa: 0.5356 | t_f1: 0.6467 | t_auc: 0.8573 | t_final: 0.6799 | v_loss: 0.3301 | v_kappa: 0.4896 | v_f1: 0.6025 | v_auc: 0.8272 | v_final: 0.6398
# EarlyStopping counter: 1 out of 30
# Ep: 22 | t_loss: 0.4529 | t_kappa: 0.5458 | t_f1: 0.6574 | t_auc: 0.8649 | t_final: 0.6894 | v_loss: 0.3105 | v_kappa: 0.5333 | v_f1: 0.6230 | v_auc: 0.8326 | v_final: 0.6630
# Validation loss decreased (0.316229 --> 0.310536).  Saving model ...
# Ep: 23 | t_loss: 0.4232 | t_kappa: 0.5681 | t_f1: 0.6700 | t_auc: 0.8697 | t_final: 0.7026 | v_loss: 0.3054 | v_kappa: 0.5106 | v_f1: 0.6287 | v_auc: 0.8396 | v_final: 0.6596
# Validation loss decreased (0.310536 --> 0.305444).  Saving model ...
# Ep: 24 | t_loss: 0.4123 | t_kappa: 0.5677 | t_f1: 0.6664 | t_auc: 0.8724 | t_final: 0.7022 | v_loss: 0.3160 | v_kappa: 0.5254 | v_f1: 0.6322 | v_auc: 0.8418 | v_final: 0.6665
# EarlyStopping counter: 1 out of 30
# Ep: 25 | t_loss: 0.4147 | t_kappa: 0.5694 | t_f1: 0.6711 | t_auc: 0.8728 | t_final: 0.7044 | v_loss: 0.3826 | v_kappa: 0.4572 | v_f1: 0.6042 | v_auc: 0.8282 | v_final: 0.6299
# EarlyStopping counter: 2 out of 30
# Ep: 26 | t_loss: 0.4266 | t_kappa: 0.5533 | t_f1: 0.6639 | t_auc: 0.8718 | t_final: 0.6963 | v_loss: 0.2954 | v_kappa: 0.5436 | v_f1: 0.6286 | v_auc: 0.8335 | v_final: 0.6685
# Validation loss decreased (0.305444 --> 0.295404).  Saving model ...
# Ep: 27 | t_loss: 0.4013 | t_kappa: 0.5726 | t_f1: 0.6745 | t_auc: 0.8786 | t_final: 0.7086 | v_loss: 0.2883 | v_kappa: 0.5528 | v_f1: 0.6348 | v_auc: 0.8318 | v_final: 0.6731
# Validation loss decreased (0.295404 --> 0.288341).  Saving model ...
# Ep: 28 | t_loss: 0.3715 | t_kappa: 0.6204 | t_f1: 0.6937 | t_auc: 0.8858 | t_final: 0.7333 | v_loss: 0.3296 | v_kappa: 0.5180 | v_f1: 0.6273 | v_auc: 0.8438 | v_final: 0.6630
# EarlyStopping counter: 1 out of 30
# Ep: 29 | t_loss: 0.3453 | t_kappa: 0.6360 | t_f1: 0.7055 | t_auc: 0.8923 | t_final: 0.7446 | v_loss: 0.2929 | v_kappa: 0.5415 | v_f1: 0.6254 | v_auc: 0.8389 | v_final: 0.6686
# EarlyStopping counter: 2 out of 30
# Ep: 30 | t_loss: 0.3330 | t_kappa: 0.6449 | t_f1: 0.7081 | t_auc: 0.8936 | t_final: 0.7489 | v_loss: 0.2949 | v_kappa: 0.5635 | v_f1: 0.6336 | v_auc: 0.8329 | v_final: 0.6767
# EarlyStopping counter: 3 out of 30
# Ep: 31 | t_loss: 0.3306 | t_kappa: 0.6678 | t_f1: 0.7186 | t_auc: 0.8961 | t_final: 0.7609 | v_loss: 0.3064 | v_kappa: 0.5421 | v_f1: 0.6360 | v_auc: 0.8383 | v_final: 0.6721
# EarlyStopping counter: 4 out of 30
# Ep: 32 | t_loss: 0.3396 | t_kappa: 0.6456 | t_f1: 0.7126 | t_auc: 0.8969 | t_final: 0.7517 | v_loss: 0.3104 | v_kappa: 0.5458 | v_f1: 0.6463 | v_auc: 0.8450 | v_final: 0.6790
# EarlyStopping counter: 5 out of 30
# Ep: 33 | t_loss: 0.3174 | t_kappa: 0.6734 | t_f1: 0.7295 | t_auc: 0.9045 | t_final: 0.7691 | v_loss: 0.3176 | v_kappa: 0.5382 | v_f1: 0.6219 | v_auc: 0.8343 | v_final: 0.6648
# EarlyStopping counter: 6 out of 30
# Ep: 34 | t_loss: 0.3087 | t_kappa: 0.6829 | t_f1: 0.7313 | t_auc: 0.9047 | t_final: 0.7730 | v_loss: 0.2906 | v_kappa: 0.5689 | v_f1: 0.6463 | v_auc: 0.8384 | v_final: 0.6845
# EarlyStopping counter: 7 out of 30
# Ep: 35 | t_loss: 0.2990 | t_kappa: 0.6913 | t_f1: 0.7389 | t_auc: 0.9128 | t_final: 0.7810 | v_loss: 0.2838 | v_kappa: 0.5853 | v_f1: 0.6494 | v_auc: 0.8409 | v_final: 0.6919
# Validation loss decreased (0.288341 --> 0.283800).  Saving model ...
# Ep: 36 | t_loss: 0.3141 | t_kappa: 0.6776 | t_f1: 0.7314 | t_auc: 0.9108 | t_final: 0.7733 | v_loss: 0.2973 | v_kappa: 0.5500 | v_f1: 0.6400 | v_auc: 0.8445 | v_final: 0.6782
# EarlyStopping counter: 1 out of 30
# Ep: 37 | t_loss: 0.3111 | t_kappa: 0.6896 | t_f1: 0.7388 | t_auc: 0.9136 | t_final: 0.7807 | v_loss: 0.3062 | v_kappa: 0.5620 | v_f1: 0.6493 | v_auc: 0.8430 | v_final: 0.6848
# EarlyStopping counter: 2 out of 30
# Ep: 38 | t_loss: 0.2937 | t_kappa: 0.6932 | t_f1: 0.7418 | t_auc: 0.9151 | t_final: 0.7834 | v_loss: 0.2795 | v_kappa: 0.5796 | v_f1: 0.6527 | v_auc: 0.8470 | v_final: 0.6931
# Validation loss decreased (0.283800 --> 0.279466).  Saving model ...
# Ep: 39 | t_loss: 0.2841 | t_kappa: 0.7167 | t_f1: 0.7537 | t_auc: 0.9209 | t_final: 0.7971 | v_loss: 0.2831 | v_kappa: 0.5913 | v_f1: 0.6590 | v_auc: 0.8465 | v_final: 0.6989
# EarlyStopping counter: 1 out of 30
# Ep: 40 | t_loss: 0.2915 | t_kappa: 0.6995 | t_f1: 0.7459 | t_auc: 0.9198 | t_final: 0.7884 | v_loss: 0.2771 | v_kappa: 0.5940 | v_f1: 0.6551 | v_auc: 0.8452 | v_final: 0.6981
# Validation loss decreased (0.279466 --> 0.277053).  Saving model ...
# Ep: 41 | t_loss: 0.2658 | t_kappa: 0.7404 | t_f1: 0.7680 | t_auc: 0.9263 | t_final: 0.8116 | v_loss: 0.2854 | v_kappa: 0.5746 | v_f1: 0.6527 | v_auc: 0.8461 | v_final: 0.6911
# EarlyStopping counter: 1 out of 30
# Ep: 42 | t_loss: 0.2541 | t_kappa: 0.7483 | t_f1: 0.7728 | t_auc: 0.9297 | t_final: 0.8169 | v_loss: 0.2845 | v_kappa: 0.5956 | v_f1: 0.6572 | v_auc: 0.8423 | v_final: 0.6984
# EarlyStopping counter: 2 out of 30
# Ep: 43 | t_loss: 0.2436 | t_kappa: 0.7675 | t_f1: 0.7778 | t_auc: 0.9338 | t_final: 0.8264 | v_loss: 0.2772 | v_kappa: 0.5909 | v_f1: 0.6540 | v_auc: 0.8441 | v_final: 0.6963
# EarlyStopping counter: 3 out of 30
# Ep: 44 | t_loss: 0.2429 | t_kappa: 0.7739 | t_f1: 0.7799 | t_auc: 0.9332 | t_final: 0.8290 | v_loss: 0.2707 | v_kappa: 0.6014 | v_f1: 0.6586 | v_auc: 0.8489 | v_final: 0.7030
# Validation loss decreased (0.277053 --> 0.270681).  Saving model ...
# Ep: 45 | t_loss: 0.2375 | t_kappa: 0.7814 | t_f1: 0.7947 | t_auc: 0.9371 | t_final: 0.8377 | v_loss: 0.2855 | v_kappa: 0.6063 | v_f1: 0.6620 | v_auc: 0.8426 | v_final: 0.7036
# EarlyStopping counter: 1 out of 30
# Ep: 46 | t_loss: 0.2350 | t_kappa: 0.7764 | t_f1: 0.7895 | t_auc: 0.9392 | t_final: 0.8351 | v_loss: 0.2921 | v_kappa: 0.5860 | v_f1: 0.6588 | v_auc: 0.8468 | v_final: 0.6972
# EarlyStopping counter: 2 out of 30
# Ep: 47 | t_loss: 0.2233 | t_kappa: 0.7920 | t_f1: 0.7977 | t_auc: 0.9416 | t_final: 0.8438 | v_loss: 0.2790 | v_kappa: 0.6068 | v_f1: 0.6660 | v_auc: 0.8458 | v_final: 0.7062
# EarlyStopping counter: 3 out of 30
# Ep: 48 | t_loss: 0.2198 | t_kappa: 0.7946 | t_f1: 0.7999 | t_auc: 0.9420 | t_final: 0.8455 | v_loss: 0.2810 | v_kappa: 0.6099 | v_f1: 0.6606 | v_auc: 0.8452 | v_final: 0.7052
# EarlyStopping counter: 4 out of 30
# Ep: 49 | t_loss: 0.2048 | t_kappa: 0.8171 | t_f1: 0.8171 | t_auc: 0.9475 | t_final: 0.8606 | v_loss: 0.2819 | v_kappa: 0.6086 | v_f1: 0.6606 | v_auc: 0.8458 | v_final: 0.7050
# EarlyStopping counter: 5 out of 30
# Ep: 50 | t_loss: 0.2096 | t_kappa: 0.8088 | t_f1: 0.8136 | t_auc: 0.9490 | t_final: 0.8571 | v_loss: 0.2831 | v_kappa: 0.6185 | v_f1: 0.6641 | v_auc: 0.8441 | v_final: 0.7089
# EarlyStopping counter: 6 out of 30
# Ep: 51 | t_loss: 0.2092 | t_kappa: 0.8138 | t_f1: 0.8190 | t_auc: 0.9514 | t_final: 0.8614 | v_loss: 0.2824 | v_kappa: 0.6128 | v_f1: 0.6604 | v_auc: 0.8439 | v_final: 0.7057
# EarlyStopping counter: 7 out of 30
# Ep: 52 | t_loss: 0.2049 | t_kappa: 0.8156 | t_f1: 0.8168 | t_auc: 0.9511 | t_final: 0.8612 | v_loss: 0.2848 | v_kappa: 0.6042 | v_f1: 0.6635 | v_auc: 0.8463 | v_final: 0.7047
# EarlyStopping counter: 8 out of 30
# Ep: 53 | t_loss: 0.2071 | t_kappa: 0.7963 | t_f1: 0.8101 | t_auc: 0.9483 | t_final: 0.8516 | v_loss: 0.2855 | v_kappa: 0.6239 | v_f1: 0.6697 | v_auc: 0.8452 | v_final: 0.7129
# EarlyStopping counter: 9 out of 30
# Ep: 54 | t_loss: 0.1961 | t_kappa: 0.8172 | t_f1: 0.8222 | t_auc: 0.9537 | t_final: 0.8644 | v_loss: 0.2807 | v_kappa: 0.6157 | v_f1: 0.6657 | v_auc: 0.8449 | v_final: 0.7087
# EarlyStopping counter: 10 out of 30
# Ep: 55 | t_loss: 0.1998 | t_kappa: 0.8232 | t_f1: 0.8200 | t_auc: 0.9515 | t_final: 0.8649 | v_loss: 0.2851 | v_kappa: 0.6079 | v_f1: 0.6607 | v_auc: 0.8459 | v_final: 0.7048
# EarlyStopping counter: 11 out of 30
# Ep: 56 | t_loss: 0.1975 | t_kappa: 0.8153 | t_f1: 0.8262 | t_auc: 0.9564 | t_final: 0.8660 | v_loss: 0.2831 | v_kappa: 0.6154 | v_f1: 0.6664 | v_auc: 0.8472 | v_final: 0.7096
# EarlyStopping counter: 12 out of 30
# Ep: 57 | t_loss: 0.1893 | t_kappa: 0.8320 | t_f1: 0.8364 | t_auc: 0.9572 | t_final: 0.8752 | v_loss: 0.2815 | v_kappa: 0.6173 | v_f1: 0.6656 | v_auc: 0.8454 | v_final: 0.7095
# EarlyStopping counter: 13 out of 30
# Ep: 58 | t_loss: 0.1842 | t_kappa: 0.8366 | t_f1: 0.8300 | t_auc: 0.9562 | t_final: 0.8743 | v_loss: 0.2859 | v_kappa: 0.6113 | v_f1: 0.6622 | v_auc: 0.8457 | v_final: 0.7064
# EarlyStopping counter: 14 out of 30
# Ep: 59 | t_loss: 0.1860 | t_kappa: 0.8414 | t_f1: 0.8386 | t_auc: 0.9597 | t_final: 0.8799 | v_loss: 0.2865 | v_kappa: 0.6126 | v_f1: 0.6588 | v_auc: 0.8428 | v_final: 0.7047
# EarlyStopping counter: 15 out of 30
# Ep: 60 | t_loss: 0.1869 | t_kappa: 0.8321 | t_f1: 0.8323 | t_auc: 0.9592 | t_final: 0.8745 | v_loss: 0.3079 | v_kappa: 0.5839 | v_f1: 0.6472 | v_auc: 0.8378 | v_final: 0.6897
# EarlyStopping counter: 16 out of 30
# Ep: 61 | t_loss: 0.1832 | t_kappa: 0.8357 | t_f1: 0.8378 | t_auc: 0.9612 | t_final: 0.8783 | v_loss: 0.2922 | v_kappa: 0.6181 | v_f1: 0.6562 | v_auc: 0.8429 | v_final: 0.7057
# EarlyStopping counter: 17 out of 30
# Ep: 62 | t_loss: 0.1804 | t_kappa: 0.8502 | t_f1: 0.8415 | t_auc: 0.9608 | t_final: 0.8842 | v_loss: 0.2923 | v_kappa: 0.6156 | v_f1: 0.6657 | v_auc: 0.8424 | v_final: 0.7079
# EarlyStopping counter: 18 out of 30
# Ep: 63 | t_loss: 0.1781 | t_kappa: 0.8350 | t_f1: 0.8365 | t_auc: 0.9628 | t_final: 0.8781 | v_loss: 0.2967 | v_kappa: 0.5954 | v_f1: 0.6552 | v_auc: 0.8446 | v_final: 0.6984
# EarlyStopping counter: 19 out of 30
# Ep: 64 | t_loss: 0.1803 | t_kappa: 0.8344 | t_f1: 0.8342 | t_auc: 0.9613 | t_final: 0.8766 | v_loss: 0.2976 | v_kappa: 0.6164 | v_f1: 0.6572 | v_auc: 0.8407 | v_final: 0.7048
# EarlyStopping counter: 20 out of 30
# Ep: 65 | t_loss: 0.1706 | t_kappa: 0.8469 | t_f1: 0.8429 | t_auc: 0.9634 | t_final: 0.8844 | v_loss: 0.2906 | v_kappa: 0.6054 | v_f1: 0.6590 | v_auc: 0.8437 | v_final: 0.7027
# EarlyStopping counter: 21 out of 30
# Ep: 66 | t_loss: 0.1769 | t_kappa: 0.8473 | t_f1: 0.8395 | t_auc: 0.9607 | t_final: 0.8825 | v_loss: 0.2931 | v_kappa: 0.6153 | v_f1: 0.6589 | v_auc: 0.8423 | v_final: 0.7055
# EarlyStopping counter: 22 out of 30
# Ep: 67 | t_loss: 0.1711 | t_kappa: 0.8586 | t_f1: 0.8502 | t_auc: 0.9636 | t_final: 0.8908 | v_loss: 0.2916 | v_kappa: 0.6046 | v_f1: 0.6605 | v_auc: 0.8442 | v_final: 0.7031
# EarlyStopping counter: 23 out of 30
# Ep: 68 | t_loss: 0.1716 | t_kappa: 0.8531 | t_f1: 0.8491 | t_auc: 0.9647 | t_final: 0.8890 | v_loss: 0.2959 | v_kappa: 0.6152 | v_f1: 0.6612 | v_auc: 0.8421 | v_final: 0.7062
# EarlyStopping counter: 24 out of 30
# Ep: 69 | t_loss: 0.1640 | t_kappa: 0.8610 | t_f1: 0.8505 | t_auc: 0.9650 | t_final: 0.8922 | v_loss: 0.3015 | v_kappa: 0.6216 | v_f1: 0.6666 | v_auc: 0.8430 | v_final: 0.7104
# EarlyStopping counter: 25 out of 30
# Ep: 70 | t_loss: 0.1660 | t_kappa: 0.8581 | t_f1: 0.8515 | t_auc: 0.9681 | t_final: 0.8926 | v_loss: 0.3138 | v_kappa: 0.5962 | v_f1: 0.6570 | v_auc: 0.8424 | v_final: 0.6985
# EarlyStopping counter: 26 out of 30
# Ep: 71 | t_loss: 0.1682 | t_kappa: 0.8532 | t_f1: 0.8536 | t_auc: 0.9677 | t_final: 0.8915 | v_loss: 0.2982 | v_kappa: 0.6130 | v_f1: 0.6660 | v_auc: 0.8449 | v_final: 0.7080
# EarlyStopping counter: 27 out of 30
# Ep: 72 | t_loss: 0.1584 | t_kappa: 0.8614 | t_f1: 0.8598 | t_auc: 0.9706 | t_final: 0.8973 | v_loss: 0.3046 | v_kappa: 0.6122 | v_f1: 0.6648 | v_auc: 0.8448 | v_final: 0.7073
# EarlyStopping counter: 28 out of 30
# Ep: 73 | t_loss: 0.1640 | t_kappa: 0.8542 | t_f1: 0.8512 | t_auc: 0.9673 | t_final: 0.8909 | v_loss: 0.3021 | v_kappa: 0.6094 | v_f1: 0.6638 | v_auc: 0.8442 | v_final: 0.7058
# EarlyStopping counter: 29 out of 30
# Ep: 74 | t_loss: 0.1628 | t_kappa: 0.8435 | t_f1: 0.8524 | t_auc: 0.9709 | t_final: 0.8889 | v_loss: 0.3046 | v_kappa: 0.6114 | v_f1: 0.6662 | v_auc: 0.8439 | v_final: 0.7071
# EarlyStopping counter: 30 out of 30
# Early stopping

# %% [markdown]
# Run the next cell to see the metrics trough the epochs using the tensorboard interface

# %%
# %reload_ext tensorboard
# %tensorboard --logdir ../runs

# %% [markdown]
# # Test the model with the validation dataset
# Since there is no access to the test annotatations (only to the images) the test will be performed on the validation dataset, to be able to see some results.

# %%
# %run ../../scripts/test.py -h # Run this line to check the test script arguments
# Out:
# usage: test.py [-h] [--model_name MODEL_NAME] [--model_path MODEL_PATH]
#                [--images_path IMAGES_PATH] [--crop_size CROP_SIZE]
#                [--test_annotations_path TEST_ANNOTATIONS_PATH]
#                [--use_normalization] [--batch_size BATCH_SIZE]
#                [--num_workers NUM_WORKERS]
#                [--ground_truth_path GROUND_TRUTH_PATH]
#                [--probs_path PROBS_PATH]
#
# Test a model with a dataset.
#
# options:
#   -h, --help            show this help message and exit
#   --model_name MODEL_NAME
#                         Model arquitecture for testing (default:
#                         resnet50_dual).
#   --model_path MODEL_PATH
#                         Path to the model to test the dataset with (default:
#                         outputs/resnet50_dual_experiment_0_model.pth).
#   --images_path IMAGES_PATH
#                         Path of test images (default:
#                         ../../data/train_fov_cc_fov_224/).
#   --crop_size CROP_SIZE
#                         Crop size used for center cropping the test images
#                         (default: 224)
#   --test_annotations_path TEST_ANNOTATIONS_PATH
#                         Path of test annotations file (default:
#                         data/test_annotations.xlsx).
#   --use_normalization   If set the images are normalized the same way the
#                         imagenet images were normalized to train the resnet50
#                         used here.
#   --batch_size BATCH_SIZE
#                         Batch size for data loaders (default: 32).
#   --num_workers NUM_WORKERS
#                         Number of workers for data loaders (default:
#                         os.cpu_count()).
#   --ground_truth_path GROUND_TRUTH_PATH
#                         Path to store the ground truth labels used in test
#                         (default: None).
#   --probs_path PROBS_PATH
#                         Path to store the result probs of test (default:
#                         None).

# %%
test_annotations_path = 'data/val_annotations.xlsx' # val annotations are used for test
images_path = '../../../train_fov_cc_fov_512/'
model_path = 'outputs/resnet50_dual_experiment_15_model.pth'
ground_truth_path = 'outputs/ground_truth.xlsx'
probs_path = 'outputs/probs.xlsx'

# %%
# %run ../../scripts/test.py --model_path {model_path} --images_path {images_path} --test_annotations_path {test_annotations_path} --use_normalization\
                           --ground_truth_path {ground_truth_path} --probs_path {probs_path} --crop_size {crop_size}
# Out:
# [INFO] Created new resnet50_dual model.
# test_loss: 0.2704 | test_kappa: 0.6014 | test_f1: 0.6586 | test_auc: 0.8489 | test_final: 0.7030

# %% [markdown]
# # Run the ODIR_evaluation.py script on test (validation) dataset
# This is a file provided along with the data by the challenge. And its supposed to have an example on how to compute the kappa, f1, auc, and final score metrics but i dont think they are well computed here as they are always too good (as shown later, the cualitative results for test are much worst). As a result of this, i use my own version of this metrics (see the function compute_challenge_metrics on the metrics script). Either way i'll run it.

# %%
ground_truth_path = 'outputs/ground_truth.xlsx'
probs_path = 'outputs/probs.xlsx'
probs_csv_path = 'outputs/probs.csv'

probs_df = pd.read_excel(probs_path)
probs_df.to_csv(probs_csv_path, index=False) # The ODIR_evaluation script asks the probs file to be in .csv format

# %run ../../scripts/ODIR_evaluation.py {ground_truth_path} {probs_csv_path}
# Out:
# kappa score: 0.6014981085268922  f-1 score: 0.8941618911174785  AUC vlaue: 0.9279044627559762  Final Score: 0.8078548208001156

# %% [markdown]
# # Cuantitative results
# The test script prints some results as can be seen in the output of the previous cell. Now, lets see some more.

# %%
label_names = ['N','D','G','C','A','H','M','O']

ground_truth = pd.read_excel(ground_truth_path).loc[:, label_names].to_numpy()
probs = pd.read_excel(probs_path).loc[:, label_names].to_numpy()

# %%
from sklearn import metrics
os.chdir('../../scripts')
from metrics import plot_confusion_matrices
os.chdir('../experiments/experiment_15/')

# Print test classification report
print('Clasification report:')
print(
    metrics.classification_report(
        ground_truth,
        probs>0.5,
        output_dict=False,
        target_names=label_names,
        zero_division=0
    )
)

# Plot one confusion matrix for each label
plot_confusion_matrices(ground_truth, probs, label_names)
# Out:
# Clasification report:
#               precision    recall  f1-score   support
#
#            N       0.56      0.79      0.65       214
#            D       0.73      0.72      0.73       226
#            G       0.56      0.65      0.60        34
#            C       0.89      0.89      0.89        37
#            A       0.68      0.73      0.70        37
#            H       0.42      0.55      0.48        29
#            M       0.84      0.87      0.85        30
#            O       0.57      0.59      0.58       217
#
#    micro avg       0.62      0.71      0.66       824
#    macro avg       0.66      0.72      0.69       824
# weighted avg       0.64      0.71      0.67       824
#  samples avg       0.65      0.72      0.66       824

# %% [markdown]
# # Cualitative results
# One patient with each disease (at least) is predicted. The original images are ploted along with their ground truth and predicted labels.

# %%
import torch
from torchvision import transforms
os.chdir('../../scripts')
from utils import load_model
from transforms import ToTensorDual, NormalizeDual, CenterCropDual
from predict import pred_and_plot_image
os.chdir('../experiments/experiment_15/')

# %%
model = load_model(model_path)

test_df = pd.read_excel(test_annotations_path)

transform = transforms.Compose([
    CenterCropDual(size=crop_size),
    ToTensorDual(),
    NormalizeDual(mean=[0.485, 0.456, 0.406],
                    std=[0.229, 0.224, 0.225])
])

device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# [INFO] Created new resnet50_dual model.

# %% [markdown]
# You can run the next cell multiple times to see different results

# %%
for label in label_names:
    patient = test_df[test_df[label] == 1].sample(replace=True).reset_index(drop=True)
    pred_and_plot_image(model=model,
                        left_image_path=f'{images_path}/{patient.at[0, "Left-Fundus"]}',
                        right_image_path=f'{images_path}/{patient.at[0, "Right-Fundus"]}',
                        transform=transform,
                        device=device,
                        label_names=label_names,
                        ground_truth=patient.loc[0, label_names].to_numpy())

# %% [markdown]
# # Zip the experiment data folder, the SummaryWriter folder and the experiment outputs
# This is necessary in order to be able to download this folders

# %%
# import shutil

# shutil.make_archive('experiment_data_compressed',
#                     format="zip",
#                     root_dir='data/')

# shutil.make_archive('runs_compressed',
#                     format="zip",
#                     root_dir='../runs/')

# shutil.make_archive('outputs_compressed',
#                     format="zip",
#                     root_dir='outputs/')
# Out:
# '/content/ODIR-5K-multi-label-classification/experiments/experiment_15/outputs_compressed.zip'
