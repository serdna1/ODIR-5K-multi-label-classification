# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/serdna1/ODIR-5K-multi-label-classification/blob/main/experiments/experiment_5/experiment_5.ipynb)

# %% [markdown]
# # Download GitHub repository and data
# The repo wont be downloading in my local machine, since i already have it there. It will if someone is running this notebook on their own machine, colab, ...

# %%
import os
import zipfile

images_path = 'ODIR-5K-multi-label-classification/data/images/'

# If the experiments folder doesnt exist im not in my local machine
if not os.path.exists('../../experiments'):
    # Clone project repository
    # !git clone https://github.com/serdna1/ODIR-5K-multi-label-classification.git

    # Unzip images
    with zipfile.ZipFile(f'{images_path}/train_fov_cc_fov_224.zip', 'r') as zip_ref:
      print("Unzipping training images...")
      zip_ref.extractall(f'{images_path}/train_fov_cc_fov_224')
    # !rm ODIR-5K-multi-label-classification/data/images/train_fov_cc_fov_224.zip
    # !rm ODIR-5K-multi-label-classification/data/images/train_224.zip

    # Move to the experiment folder
    # %cd ODIR-5K-multi-label-classification/experiments/experiment_5/
# Out:
# Cloning into 'ODIR-5K-multi-label-classification'...
# remote: Enumerating objects: 392, done.
# remote: Counting objects: 100% (147/147), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 392 (delta 72), reused 122 (delta 51), pack-reused 245
# Receiving objects: 100% (392/392), 79.76 MiB | 31.50 MiB/s, done.
# Resolving deltas: 100% (184/184), done.
# Unzipping training images...
# /content/ODIR-5K-multi-label-classification/experiments/experiment_5

# %% [markdown]
# # Drop some special patients from the dataset
# The background of some images is quite different from the rest ones. Therefore they wont be used for training.

# %%
import matplotlib.pyplot as plt
from PIL import Image

images_path = '../../data/images/train_fov_cc_fov_224'

special_images = ['2174_right.jpg', '2175_left.jpg', '2176_left.jpg', '2177_left.jpg',
                  '2177_right.jpg', '2178_right.jpg', '2179_left.jpg', '2179_right.jpg',
                  '2180_left.jpg', '2180_right.jpg', '2181_left.jpg', '2181_right.jpg',
                  '2182_left.jpg', '2182_right.jpg', '2957_left.jpg', '2957_right.jpg']

# Show one of this special images
image_path = f'{images_path}/{special_images[7]}'
img = Image.open(image_path)
plt.imshow(img)
plt.axis(False)
plt.title('Example of special image')
# Out:
# Text(0.5, 1.0, 'Example of special image')

# %%
import pandas as pd

original_annotations_path = '../../data/annotations/annotations.xlsx'
annotations_path = 'data/annotations.xlsx'

odir_df = pd.read_excel(original_annotations_path)

patients_to_drop_df = odir_df[odir_df['Left-Fundus'].isin(special_images) | odir_df['Right-Fundus'].isin(special_images)]
patients_to_drop_df # This are all the patients with one ore more of this spetial images
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1634  2174           65      Female  2174_left.jpg  2174_right.jpg
# 1635  2175           63        Male  2175_left.jpg  2175_right.jpg
# 1636  2176           82      Female  2176_left.jpg  2176_right.jpg
# 1637  2177           87        Male  2177_left.jpg  2177_right.jpg
# 1638  2178           84        Male  2178_left.jpg  2178_right.jpg
# 1639  2179           70      Female  2179_left.jpg  2179_right.jpg
# 1640  2180           66      Female  2180_left.jpg  2180_right.jpg
# 1641  2181           79      Female  2181_left.jpg  2181_right.jpg
# 1642  2182           70        Male  2182_left.jpg  2182_right.jpg
# 2334  2957           62      Female  2957_left.jpg  2957_right.jpg
#
#      Left-Diagnostic Keywords Right-Diagnostic Keywords  N  D  G  C  A  H  M  \
# 1634            normal fundus                  cataract  0  0  0  1  0  0  0
# 1635                 cataract             normal fundus  0  0  0  1  0  0  0
# 1636                 cataract                  cataract  0  0  0  1  0  0  0
# 1637  normal fundus，lens dust                  cataract  0  0  0  1  0  0  0
# 1638                 cataract                  cataract  0  0  0  1  0  0  0
# 1639                 cataract                  cataract  0  0  0  1  0  0  0
# 1640                 cataract                  cataract  0  0  0  1  0  0  0
# 1641                 cataract                  cataract  0  0  0  1  0  0  0
# 1642                 cataract                  cataract  0  0  0  1  0  0  0
# 2334            normal fundus             normal fundus  1  0  0  0  0  0  0
#
#       O
# 1634  0
# 1635  0
# 1636  0
# 1637  0
# 1638  0
# 1639  0
# 1640  0
# 1641  0
# 1642  0
# 2334  0

# %%
from pathlib import Path

experiment_data_path = 'data/'

print(f'Annotations length before droping the rows with the special images: {len(odir_df)}')

odir_df = odir_df.drop(patients_to_drop_df.index) # Drop the special patients
Path(experiment_data_path).mkdir(parents=True, exist_ok=True) # Create the experiment data folder
odir_df.to_excel(annotations_path) # Save annotations without the special patients

print(f'Annotations length after droping the rows with the special images: {len(odir_df)}')
# Out:
# Annotations length before droping the rows with the special images: 3500
# Annotations length after droping the rows with the special images: 3490

# %% [markdown]
# # Check dataset label distribution

# %%
label_names = ['N','D','G','C','A','H','M','O']

total_label_list = []
for label in label_names:
    total_label = int(odir_df.loc[:, [label]].sum())
    total_label_list.append(total_label)

plt.figure(figsize=(16,4))

bar = plt.bar(label_names, total_label_list)

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f}', ha='center', va='bottom')

plt.xlabel(f'Label')
plt.ylabel(f'No. of images')
plt.title(f'Label distribution')
# Out:
# Text(0.5, 1.0, 'Label distribution')

# %% [markdown]
# # Split dataset into train and validation

# %%
os.chdir('../../scripts/')
from utils import split_annotations
os.chdir('../experiments/experiment_5/')

# %%
# Split the original annotations file into train and validation annotations files
# val_ratio = 0.2 (value by default)
split_annotations(annotations_path, experiment_data_path, test_split=False)

# Read the previous three created .xlsx files into dataframes
train_df = pd.read_excel(f'{experiment_data_path}/train_annotations.xlsx')
val_df = pd.read_excel(f'{experiment_data_path}/val_annotations.xlsx')

len(train_df), len(val_df)
# Out:
# (2792, 698)

# %% [markdown]
# # Check train and validation datasets label distribution

# %%
for i, label in enumerate(label_names):
    plt.figure(figsize=(4,4))

    total_label_train = int(train_df.loc[:, [label]].sum())
    total_label_val = int(val_df.loc[:, [label]].sum())

    bar = plt.bar(['Train', 'Val'], [total_label_train, total_label_val])

    for rect in bar:
        height = rect.get_height()
        plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f}', ha='center', va='bottom')

    plt.xlabel(f'Dataset')
    plt.ylabel(f'No. of images with label {label}')
    plt.title(f'Distribution of label {label} by dataset')

# %% [markdown]
# # Train the model

# %%
# %run ../../scripts/train.py -h # Run this line to check the train script arguments
# Out:
# usage: train.py [-h] [--random_seed RANDOM_SEED] [--model_name MODEL_NAME]
#                 [--images_path IMAGES_PATH] [--use_normalization]
#                 [--train_annotations_path TRAIN_ANNOTATIONS_PATH]
#                 [--val_annotations_path VAL_ANNOTATIONS_PATH]
#                 [--batch_size BATCH_SIZE] [--num_workers NUM_WORKERS]
#                 [--lr LR] [--momentum MOMENTUM] [--lr_scheduler LR_SCHEDULER]
#                 [--linear_lr_scheduler_total_iters LINEAR_LR_SCHEDULER_TOTAL_ITERS]
#                 [--linear_lr_scheduler_start_factor LINEAR_LR_SCHEDULER_START_FACTOR]
#                 [--linear_lr_scheduler_end_factor LINEAR_LR_SCHEDULER_END_FACTOR]
#                 [--cyclic_lr_scheduler_base_lr CYCLIC_LR_SCHEDULER_BASE_LR]
#                 [--cyclic_lr_scheduler_max_lr CYCLIC_LR_SCHEDULER_MAX_LR]
#                 [--cyclic_lr_scheduler_step_size_up CYCLIC_LR_SCHEDULER_STEP_SIZE_UP]
#                 [--epochs EPOCHS] [--patience PATIENCE]
#                 [--experiment_name EXPERIMENT_NAME] [--extra EXTRA]
#
# Train a network for image multi-label classification on ODIR-5K.
#
# options:
#   -h, --help            show this help message and exit
#   --random_seed RANDOM_SEED
#                         Sets random seed for reproducibility (default: 42).
#   --model_name MODEL_NAME
#                         Model arquitecture for training (default:
#                         resnet50_dual).
#   --images_path IMAGES_PATH
#                         Path of ODIR training images (default:
#                         /kaggle/input/odir-size-512/odir-size-512).
#   --use_normalization   If set the images are normalized the same way the
#                         imagenet images where normalized to train the resnet50
#                         used here.
#   --train_annotations_path TRAIN_ANNOTATIONS_PATH
#                         Path of train annotations file (default:
#                         /kaggle/input/odir-size-512/train_annotations.xlsx).
#   --val_annotations_path VAL_ANNOTATIONS_PATH
#                         Path of validation annotations file (default:
#                         /kaggle/input/odir-size-512/val_annotations.xlsx).
#   --batch_size BATCH_SIZE
#                         Batch size for data loaders (default: 32).
#   --num_workers NUM_WORKERS
#                         Number of workers for data loaders (default:
#                         os.cpu_count()).
#   --lr LR               Specifies learning rate for optimizer (default: 1e-3).
#   --momentum MOMENTUM   Specifies momentum for optimizer (default: 0.9).
#   --lr_scheduler LR_SCHEDULER
#                         Learning rate scheduler (default: None)
#   --linear_lr_scheduler_total_iters LINEAR_LR_SCHEDULER_TOTAL_ITERS
#                         Number of steps that the linear lr scheduler decays
#                         the learning rate (default: 50).
#   --linear_lr_scheduler_start_factor LINEAR_LR_SCHEDULER_START_FACTOR
#                         Start factor of the linear lr scheduler (default: 1).
#   --linear_lr_scheduler_end_factor LINEAR_LR_SCHEDULER_END_FACTOR
#                         End factor of the linear lr scheduler (default: 0.1).
#   --cyclic_lr_scheduler_base_lr CYCLIC_LR_SCHEDULER_BASE_LR
#                         Initial learning rate which is the lower boundary in
#                         the cycle for each parameter group (default: 0.001).
#   --cyclic_lr_scheduler_max_lr CYCLIC_LR_SCHEDULER_MAX_LR
#                         Upper learning rate boundaries in the cycle for each
#                         parameter group (default: 0.1).
#   --cyclic_lr_scheduler_step_size_up CYCLIC_LR_SCHEDULER_STEP_SIZE_UP
#                         Number of training iterations in the increasing half
#                         of a cycle (default: 10).
#   --epochs EPOCHS       Number of training epochs (default: 5).
#   --patience PATIENCE   How long to wait after last time validation loss
#                         improved (default: 1).
#   --experiment_name EXPERIMENT_NAME
#                         Name of the experiment" (default: experiment_0).
#   --extra EXTRA         Extra info about the experiment (default: None).

# %%
# Arguments that will be passed to the train script
model_name = 'resnet50_dual_v1'
images_path = '../../data/images/train_fov_cc_fov_224'
train_annotations_path = 'data/train_annotations.xlsx'
val_annotations_path = 'data/val_annotations.xlsx'
lr = 0.05
lr_scheduler = 'LinearLR'
batch_size = 32
epochs = 100
patience = 20
experiment_name = 'experiment_5'

# %%
# %run ../../scripts/train.py --model {model_name} --images_path {images_path} --train_annotations_path {train_annotations_path} --val_annotations_path {val_annotations_path}\
                            --batch_size {batch_size} --epochs {epochs} --patience {patience} --experiment_name {experiment_name} --use_normalization --lr {lr}\
                            --lr_scheduler {lr_scheduler}
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 60.3MB/s]
# [INFO] Created new resnet50_dual_v1 model.
# [INFO] Created SummaryWriter, saving to: ../runs/resnet50_dual_v1/experiment_5...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ep: 0 | t_loss: 0.3595 | t_kappa: 0.0091 | t_f1: 0.0549 | t_auc: 0.5865 | t_final: 0.2168 | v_loss: 0.3389 | v_kappa: 0.0293 | v_f1: 0.0570 | v_auc: 0.6293 | v_final: 0.2385
# Validation loss decreased (inf --> 0.338871).  Saving model ...
# Ep: 1 | t_loss: 0.3083 | t_kappa: 0.1337 | t_f1: 0.2152 | t_auc: 0.7112 | t_final: 0.3533 | v_loss: 0.3265 | v_kappa: 0.1526 | v_f1: 0.1880 | v_auc: 0.6576 | v_final: 0.3327
# Validation loss decreased (0.338871 --> 0.326542).  Saving model ...
# Ep: 2 | t_loss: 0.2947 | t_kappa: 0.2072 | t_f1: 0.2923 | t_auc: 0.7400 | t_final: 0.4131 | v_loss: 0.3207 | v_kappa: 0.2000 | v_f1: 0.2351 | v_auc: 0.6754 | v_final: 0.3702
# Validation loss decreased (0.326542 --> 0.320697).  Saving model ...
# Ep: 3 | t_loss: 0.2831 | t_kappa: 0.2462 | t_f1: 0.3466 | t_auc: 0.7696 | t_final: 0.4541 | v_loss: 0.3184 | v_kappa: 0.2093 | v_f1: 0.2441 | v_auc: 0.6759 | v_final: 0.3764
# Validation loss decreased (0.320697 --> 0.318351).  Saving model ...
# Ep: 4 | t_loss: 0.2762 | t_kappa: 0.2532 | t_f1: 0.3592 | t_auc: 0.7859 | t_final: 0.4661 | v_loss: 0.3112 | v_kappa: 0.2239 | v_f1: 0.2726 | v_auc: 0.6885 | v_final: 0.3950
# Validation loss decreased (0.318351 --> 0.311169).  Saving model ...
# Ep: 5 | t_loss: 0.2697 | t_kappa: 0.2807 | t_f1: 0.3846 | t_auc: 0.8023 | t_final: 0.4892 | v_loss: 0.3138 | v_kappa: 0.2290 | v_f1: 0.2619 | v_auc: 0.6889 | v_final: 0.3933
# EarlyStopping counter: 1 out of 20
# Ep: 6 | t_loss: 0.2644 | t_kappa: 0.2890 | t_f1: 0.4128 | t_auc: 0.8132 | t_final: 0.5050 | v_loss: 0.3135 | v_kappa: 0.2256 | v_f1: 0.2982 | v_auc: 0.6905 | v_final: 0.4047
# EarlyStopping counter: 2 out of 20
# Ep: 7 | t_loss: 0.2590 | t_kappa: 0.3189 | t_f1: 0.4331 | t_auc: 0.8231 | t_final: 0.5250 | v_loss: 0.3070 | v_kappa: 0.2317 | v_f1: 0.3009 | v_auc: 0.6950 | v_final: 0.4092
# Validation loss decreased (0.311169 --> 0.306971).  Saving model ...
# Ep: 8 | t_loss: 0.2533 | t_kappa: 0.3352 | t_f1: 0.4613 | t_auc: 0.8333 | t_final: 0.5433 | v_loss: 0.3042 | v_kappa: 0.2340 | v_f1: 0.3071 | v_auc: 0.6959 | v_final: 0.4124
# Validation loss decreased (0.306971 --> 0.304215).  Saving model ...
# Ep: 9 | t_loss: 0.2510 | t_kappa: 0.3220 | t_f1: 0.4522 | t_auc: 0.8365 | t_final: 0.5369 | v_loss: 0.3099 | v_kappa: 0.2430 | v_f1: 0.3139 | v_auc: 0.6908 | v_final: 0.4159
# EarlyStopping counter: 1 out of 20
# Ep: 10 | t_loss: 0.2484 | t_kappa: 0.3517 | t_f1: 0.4715 | t_auc: 0.8404 | t_final: 0.5546 | v_loss: 0.3079 | v_kappa: 0.2101 | v_f1: 0.2774 | v_auc: 0.7007 | v_final: 0.3960
# EarlyStopping counter: 2 out of 20
# Ep: 11 | t_loss: 0.2440 | t_kappa: 0.3553 | t_f1: 0.4864 | t_auc: 0.8498 | t_final: 0.5639 | v_loss: 0.3084 | v_kappa: 0.2381 | v_f1: 0.3152 | v_auc: 0.6974 | v_final: 0.4169
# EarlyStopping counter: 3 out of 20
# Ep: 12 | t_loss: 0.2391 | t_kappa: 0.3811 | t_f1: 0.5163 | t_auc: 0.8568 | t_final: 0.5847 | v_loss: 0.3044 | v_kappa: 0.2426 | v_f1: 0.3153 | v_auc: 0.7036 | v_final: 0.4205
# EarlyStopping counter: 4 out of 20
# Ep: 13 | t_loss: 0.2403 | t_kappa: 0.3701 | t_f1: 0.5037 | t_auc: 0.8511 | t_final: 0.5750 | v_loss: 0.3059 | v_kappa: 0.2370 | v_f1: 0.2925 | v_auc: 0.7037 | v_final: 0.4110
# EarlyStopping counter: 5 out of 20
# Ep: 14 | t_loss: 0.2352 | t_kappa: 0.3919 | t_f1: 0.5203 | t_auc: 0.8622 | t_final: 0.5915 | v_loss: 0.3024 | v_kappa: 0.2702 | v_f1: 0.3105 | v_auc: 0.7012 | v_final: 0.4273
# Validation loss decreased (0.304215 --> 0.302420).  Saving model ...
# Ep: 15 | t_loss: 0.2336 | t_kappa: 0.3901 | t_f1: 0.5167 | t_auc: 0.8634 | t_final: 0.5901 | v_loss: 0.3045 | v_kappa: 0.2723 | v_f1: 0.3437 | v_auc: 0.7013 | v_final: 0.4391
# EarlyStopping counter: 1 out of 20
# Ep: 16 | t_loss: 0.2296 | t_kappa: 0.4065 | t_f1: 0.5354 | t_auc: 0.8709 | t_final: 0.6043 | v_loss: 0.3023 | v_kappa: 0.2708 | v_f1: 0.3360 | v_auc: 0.7037 | v_final: 0.4369
# Validation loss decreased (0.302420 --> 0.302326).  Saving model ...
# Ep: 17 | t_loss: 0.2289 | t_kappa: 0.4161 | t_f1: 0.5363 | t_auc: 0.8723 | t_final: 0.6083 | v_loss: 0.3024 | v_kappa: 0.2536 | v_f1: 0.3196 | v_auc: 0.7029 | v_final: 0.4254
# EarlyStopping counter: 1 out of 20
# Ep: 18 | t_loss: 0.2266 | t_kappa: 0.4352 | t_f1: 0.5516 | t_auc: 0.8715 | t_final: 0.6194 | v_loss: 0.3038 | v_kappa: 0.2402 | v_f1: 0.3303 | v_auc: 0.6985 | v_final: 0.4230
# EarlyStopping counter: 2 out of 20
# Ep: 19 | t_loss: 0.2250 | t_kappa: 0.4269 | t_f1: 0.5495 | t_auc: 0.8772 | t_final: 0.6179 | v_loss: 0.3031 | v_kappa: 0.2523 | v_f1: 0.3260 | v_auc: 0.7087 | v_final: 0.4290
# EarlyStopping counter: 3 out of 20
# Ep: 20 | t_loss: 0.2231 | t_kappa: 0.4427 | t_f1: 0.5683 | t_auc: 0.8803 | t_final: 0.6305 | v_loss: 0.3025 | v_kappa: 0.2472 | v_f1: 0.3168 | v_auc: 0.7028 | v_final: 0.4223
# EarlyStopping counter: 4 out of 20
# Ep: 21 | t_loss: 0.2224 | t_kappa: 0.4457 | t_f1: 0.5658 | t_auc: 0.8799 | t_final: 0.6305 | v_loss: 0.3016 | v_kappa: 0.2562 | v_f1: 0.3266 | v_auc: 0.6994 | v_final: 0.4274
# Validation loss decreased (0.302326 --> 0.301622).  Saving model ...
# Ep: 22 | t_loss: 0.2217 | t_kappa: 0.4543 | t_f1: 0.5681 | t_auc: 0.8805 | t_final: 0.6343 | v_loss: 0.3022 | v_kappa: 0.2276 | v_f1: 0.3270 | v_auc: 0.7036 | v_final: 0.4194
# EarlyStopping counter: 1 out of 20
# Ep: 23 | t_loss: 0.2175 | t_kappa: 0.4587 | t_f1: 0.5843 | t_auc: 0.8838 | t_final: 0.6423 | v_loss: 0.3017 | v_kappa: 0.2431 | v_f1: 0.3233 | v_auc: 0.7031 | v_final: 0.4232
# EarlyStopping counter: 2 out of 20
# Ep: 24 | t_loss: 0.2179 | t_kappa: 0.4626 | t_f1: 0.5851 | t_auc: 0.8847 | t_final: 0.6441 | v_loss: 0.3038 | v_kappa: 0.2660 | v_f1: 0.3342 | v_auc: 0.6989 | v_final: 0.4331
# EarlyStopping counter: 3 out of 20
# Ep: 25 | t_loss: 0.2174 | t_kappa: 0.4606 | t_f1: 0.5771 | t_auc: 0.8837 | t_final: 0.6405 | v_loss: 0.3039 | v_kappa: 0.2883 | v_f1: 0.3228 | v_auc: 0.6955 | v_final: 0.4355
# EarlyStopping counter: 4 out of 20
# Ep: 26 | t_loss: 0.2145 | t_kappa: 0.4965 | t_f1: 0.5894 | t_auc: 0.8849 | t_final: 0.6569 | v_loss: 0.2987 | v_kappa: 0.2564 | v_f1: 0.3406 | v_auc: 0.7072 | v_final: 0.4347
# Validation loss decreased (0.301622 --> 0.298679).  Saving model ...
# Ep: 27 | t_loss: 0.2161 | t_kappa: 0.4677 | t_f1: 0.5885 | t_auc: 0.8835 | t_final: 0.6466 | v_loss: 0.2999 | v_kappa: 0.2910 | v_f1: 0.3418 | v_auc: 0.7067 | v_final: 0.4465
# EarlyStopping counter: 1 out of 20
# Ep: 28 | t_loss: 0.2147 | t_kappa: 0.4696 | t_f1: 0.5881 | t_auc: 0.8847 | t_final: 0.6475 | v_loss: 0.3040 | v_kappa: 0.2598 | v_f1: 0.3394 | v_auc: 0.6993 | v_final: 0.4328
# EarlyStopping counter: 2 out of 20
# Ep: 29 | t_loss: 0.2126 | t_kappa: 0.5024 | t_f1: 0.6029 | t_auc: 0.8895 | t_final: 0.6649 | v_loss: 0.2996 | v_kappa: 0.2693 | v_f1: 0.3483 | v_auc: 0.7029 | v_final: 0.4402
# EarlyStopping counter: 3 out of 20
# Ep: 30 | t_loss: 0.2096 | t_kappa: 0.4895 | t_f1: 0.6085 | t_auc: 0.8936 | t_final: 0.6639 | v_loss: 0.3015 | v_kappa: 0.2508 | v_f1: 0.3380 | v_auc: 0.7046 | v_final: 0.4311
# EarlyStopping counter: 4 out of 20
# Ep: 31 | t_loss: 0.2141 | t_kappa: 0.4842 | t_f1: 0.5868 | t_auc: 0.8863 | t_final: 0.6524 | v_loss: 0.2999 | v_kappa: 0.2569 | v_f1: 0.3415 | v_auc: 0.7077 | v_final: 0.4354
# EarlyStopping counter: 5 out of 20
# Ep: 32 | t_loss: 0.2101 | t_kappa: 0.4934 | t_f1: 0.6024 | t_auc: 0.8927 | t_final: 0.6628 | v_loss: 0.3004 | v_kappa: 0.2730 | v_f1: 0.3345 | v_auc: 0.7052 | v_final: 0.4376
# EarlyStopping counter: 6 out of 20
# Ep: 33 | t_loss: 0.2068 | t_kappa: 0.4933 | t_f1: 0.6111 | t_auc: 0.8953 | t_final: 0.6666 | v_loss: 0.3021 | v_kappa: 0.2571 | v_f1: 0.3459 | v_auc: 0.7076 | v_final: 0.4369
# EarlyStopping counter: 7 out of 20
# Ep: 34 | t_loss: 0.2062 | t_kappa: 0.5135 | t_f1: 0.6150 | t_auc: 0.8969 | t_final: 0.6752 | v_loss: 0.3025 | v_kappa: 0.2479 | v_f1: 0.3326 | v_auc: 0.7044 | v_final: 0.4283
# EarlyStopping counter: 8 out of 20
# Ep: 35 | t_loss: 0.2091 | t_kappa: 0.4990 | t_f1: 0.6092 | t_auc: 0.8933 | t_final: 0.6672 | v_loss: 0.3029 | v_kappa: 0.2681 | v_f1: 0.3264 | v_auc: 0.7057 | v_final: 0.4334
# EarlyStopping counter: 9 out of 20
# Ep: 36 | t_loss: 0.2071 | t_kappa: 0.4962 | t_f1: 0.6148 | t_auc: 0.8954 | t_final: 0.6688 | v_loss: 0.3023 | v_kappa: 0.2697 | v_f1: 0.3340 | v_auc: 0.7011 | v_final: 0.4349
# EarlyStopping counter: 10 out of 20
# Ep: 37 | t_loss: 0.2044 | t_kappa: 0.4998 | t_f1: 0.6134 | t_auc: 0.8977 | t_final: 0.6703 | v_loss: 0.3031 | v_kappa: 0.2627 | v_f1: 0.3524 | v_auc: 0.7037 | v_final: 0.4396
# EarlyStopping counter: 11 out of 20
# Ep: 38 | t_loss: 0.2048 | t_kappa: 0.5125 | t_f1: 0.6246 | t_auc: 0.9018 | t_final: 0.6796 | v_loss: 0.2980 | v_kappa: 0.2833 | v_f1: 0.3725 | v_auc: 0.7075 | v_final: 0.4544
# Validation loss decreased (0.298679 --> 0.298043).  Saving model ...
# Ep: 39 | t_loss: 0.2053 | t_kappa: 0.5093 | t_f1: 0.6233 | t_auc: 0.8994 | t_final: 0.6773 | v_loss: 0.3033 | v_kappa: 0.2671 | v_f1: 0.3530 | v_auc: 0.7031 | v_final: 0.4411
# EarlyStopping counter: 1 out of 20
# Ep: 40 | t_loss: 0.2048 | t_kappa: 0.5259 | t_f1: 0.6220 | t_auc: 0.8954 | t_final: 0.6811 | v_loss: 0.3005 | v_kappa: 0.2714 | v_f1: 0.3435 | v_auc: 0.7049 | v_final: 0.4399
# EarlyStopping counter: 2 out of 20
# Ep: 41 | t_loss: 0.2029 | t_kappa: 0.5118 | t_f1: 0.6167 | t_auc: 0.9000 | t_final: 0.6762 | v_loss: 0.2982 | v_kappa: 0.2842 | v_f1: 0.3586 | v_auc: 0.7107 | v_final: 0.4512
# EarlyStopping counter: 3 out of 20
# Ep: 42 | t_loss: 0.2016 | t_kappa: 0.5293 | t_f1: 0.6297 | t_auc: 0.9028 | t_final: 0.6873 | v_loss: 0.3015 | v_kappa: 0.2739 | v_f1: 0.3480 | v_auc: 0.7032 | v_final: 0.4417
# EarlyStopping counter: 4 out of 20
# Ep: 43 | t_loss: 0.2025 | t_kappa: 0.5139 | t_f1: 0.6262 | t_auc: 0.9006 | t_final: 0.6802 | v_loss: 0.3023 | v_kappa: 0.2586 | v_f1: 0.3242 | v_auc: 0.7002 | v_final: 0.4277
# EarlyStopping counter: 5 out of 20
# Ep: 44 | t_loss: 0.2023 | t_kappa: 0.5067 | t_f1: 0.6205 | t_auc: 0.9012 | t_final: 0.6762 | v_loss: 0.3041 | v_kappa: 0.2542 | v_f1: 0.3323 | v_auc: 0.6982 | v_final: 0.4282
# EarlyStopping counter: 6 out of 20
# Ep: 45 | t_loss: 0.2034 | t_kappa: 0.5175 | t_f1: 0.6246 | t_auc: 0.8988 | t_final: 0.6803 | v_loss: 0.3014 | v_kappa: 0.2521 | v_f1: 0.3300 | v_auc: 0.7051 | v_final: 0.4290
# EarlyStopping counter: 7 out of 20
# Ep: 46 | t_loss: 0.1997 | t_kappa: 0.5524 | t_f1: 0.6415 | t_auc: 0.9054 | t_final: 0.6998 | v_loss: 0.2994 | v_kappa: 0.2693 | v_f1: 0.3508 | v_auc: 0.7101 | v_final: 0.4434
# EarlyStopping counter: 8 out of 20
# Ep: 47 | t_loss: 0.2013 | t_kappa: 0.5308 | t_f1: 0.6344 | t_auc: 0.9010 | t_final: 0.6887 | v_loss: 0.3008 | v_kappa: 0.2765 | v_f1: 0.3430 | v_auc: 0.7020 | v_final: 0.4405
# EarlyStopping counter: 9 out of 20
# Ep: 48 | t_loss: 0.1996 | t_kappa: 0.5349 | t_f1: 0.6382 | t_auc: 0.9059 | t_final: 0.6930 | v_loss: 0.3044 | v_kappa: 0.2452 | v_f1: 0.3135 | v_auc: 0.6992 | v_final: 0.4193
# EarlyStopping counter: 10 out of 20
# Ep: 49 | t_loss: 0.1986 | t_kappa: 0.5383 | t_f1: 0.6417 | t_auc: 0.9069 | t_final: 0.6956 | v_loss: 0.3020 | v_kappa: 0.2641 | v_f1: 0.3416 | v_auc: 0.7010 | v_final: 0.4356
# EarlyStopping counter: 11 out of 20
# Ep: 50 | t_loss: 0.1986 | t_kappa: 0.5384 | t_f1: 0.6382 | t_auc: 0.9074 | t_final: 0.6947 | v_loss: 0.3041 | v_kappa: 0.2563 | v_f1: 0.3342 | v_auc: 0.6988 | v_final: 0.4298
# EarlyStopping counter: 12 out of 20
# Ep: 51 | t_loss: 0.1982 | t_kappa: 0.5246 | t_f1: 0.6283 | t_auc: 0.9096 | t_final: 0.6875 | v_loss: 0.3011 | v_kappa: 0.2499 | v_f1: 0.3393 | v_auc: 0.7064 | v_final: 0.4319
# EarlyStopping counter: 13 out of 20
# Ep: 52 | t_loss: 0.2011 | t_kappa: 0.5353 | t_f1: 0.6292 | t_auc: 0.9039 | t_final: 0.6894 | v_loss: 0.2985 | v_kappa: 0.2879 | v_f1: 0.3677 | v_auc: 0.7088 | v_final: 0.4548
# EarlyStopping counter: 14 out of 20
# Ep: 53 | t_loss: 0.2002 | t_kappa: 0.5465 | t_f1: 0.6382 | t_auc: 0.9024 | t_final: 0.6957 | v_loss: 0.3007 | v_kappa: 0.2721 | v_f1: 0.3429 | v_auc: 0.7059 | v_final: 0.4403
# EarlyStopping counter: 15 out of 20
# Ep: 54 | t_loss: 0.2003 | t_kappa: 0.5217 | t_f1: 0.6292 | t_auc: 0.9038 | t_final: 0.6849 | v_loss: 0.3020 | v_kappa: 0.2471 | v_f1: 0.3429 | v_auc: 0.7053 | v_final: 0.4318
# EarlyStopping counter: 16 out of 20
# Ep: 55 | t_loss: 0.2009 | t_kappa: 0.5435 | t_f1: 0.6314 | t_auc: 0.9019 | t_final: 0.6923 | v_loss: 0.3035 | v_kappa: 0.2740 | v_f1: 0.3631 | v_auc: 0.7013 | v_final: 0.4461
# EarlyStopping counter: 17 out of 20
# Ep: 56 | t_loss: 0.1994 | t_kappa: 0.5303 | t_f1: 0.6310 | t_auc: 0.9043 | t_final: 0.6885 | v_loss: 0.3011 | v_kappa: 0.2702 | v_f1: 0.3543 | v_auc: 0.7050 | v_final: 0.4432
# EarlyStopping counter: 18 out of 20
# Ep: 57 | t_loss: 0.1993 | t_kappa: 0.5219 | t_f1: 0.6284 | t_auc: 0.9051 | t_final: 0.6851 | v_loss: 0.2997 | v_kappa: 0.2865 | v_f1: 0.3608 | v_auc: 0.7077 | v_final: 0.4517
# EarlyStopping counter: 19 out of 20
# Ep: 58 | t_loss: 0.2000 | t_kappa: 0.5313 | t_f1: 0.6361 | t_auc: 0.9023 | t_final: 0.6899 | v_loss: 0.3033 | v_kappa: 0.2637 | v_f1: 0.3400 | v_auc: 0.6998 | v_final: 0.4345
# EarlyStopping counter: 20 out of 20
# Early stopping

# %% [markdown]
# Run the next cell to see the metrics trough the epochs using the tensorboard interface

# %%
# %reload_ext tensorboard
# %tensorboard --logdir ../runs

# %% [markdown]
# # Test the model with the validation dataset
# Since there is no access to the test annotatations (only to the images) the test will be performed on the validation dataset, to be able to see some results.

# %%
# %run ../../scripts/test.py -h # Run this line to check the test script arguments
# Out:
# usage: test.py [-h] [--model_name MODEL_NAME] [--model_path MODEL_PATH]
#                [--images_path IMAGES_PATH]
#                [--test_annotations_path TEST_ANNOTATIONS_PATH]
#                [--use_normalization] [--batch_size BATCH_SIZE]
#                [--num_workers NUM_WORKERS]
#                [--ground_truth_path GROUND_TRUTH_PATH]
#                [--probs_path PROBS_PATH]
#
# Test a model with a dataset.
#
# options:
#   -h, --help            show this help message and exit
#   --model_name MODEL_NAME
#                         Model arquitecture for testing (default:
#                         resnet50_dual).
#   --model_path MODEL_PATH
#                         Path to the model to test the dataset with (default:
#                         outputs/resnet50_dual_experiment_0_model.pth).
#   --images_path IMAGES_PATH
#                         Path of test images (default:
#                         ../../data/train_fov_cc_fov_224/).
#   --test_annotations_path TEST_ANNOTATIONS_PATH
#                         Path of test annotations file (default:
#                         data/test_annotations.xlsx).
#   --use_normalization   If set the images are normalized the same way the
#                         imagenet images were normalized to train the resnet50
#                         used here.
#   --batch_size BATCH_SIZE
#                         Batch size for data loaders (default: 32).
#   --num_workers NUM_WORKERS
#                         Number of workers for data loaders (default:
#                         os.cpu_count()).
#   --ground_truth_path GROUND_TRUTH_PATH
#                         Path to store the ground truth labels used in test
#                         (default: None).
#   --probs_path PROBS_PATH
#                         Path to store the result probs of test (default:
#                         None).

# %%
test_annotations_path = 'data/val_annotations.xlsx' # val annotations are used for test
images_path = '../../data/images/train_fov_cc_fov_224'
model_path = 'outputs/resnet50_dual_v1_experiment_5_model.pth'
ground_truth_path = 'outputs/ground_truth.xlsx'
probs_path = 'outputs/probs.xlsx'

# %%
# %run ../../scripts/test.py --model_path {model_path} --model_name {model_name} --images_path {images_path} --test_annotations_path {test_annotations_path} --use_normalization\
                           --ground_truth_path {ground_truth_path} --probs_path {probs_path}
# Out:
# [INFO] Created new resnet50_dual_v1 model.
# test_loss: 0.2980 | test_kappa: 0.2833 | test_f1: 0.3725 | test_auc: 0.7075 | test_final: 0.4544

# %% [markdown]
# # Run the ODIR_evaluation.py script on test (validation) dataset
# This is a file provided along with the data by the challenge. And its supposed to have an example on how to compute the kappa, f1, auc, and final score metrics but i dont think they are well computed here as they are always too good (as shown later, the cualitative results for test are much worst). As a result of this, i use my own version of this metrics (see the function compute_challenge_metrics on the metrics script). Either way i'll run it.

# %%
ground_truth_path = 'outputs/ground_truth.xlsx'
probs_path = 'outputs/probs.xlsx'
probs_csv_path = 'outputs/probs.csv'

probs_df = pd.read_excel(probs_path)
probs_df.to_csv(probs_csv_path, index=False) # The ODIR_evaluation script asks the probs file to be in .csv format

# %run ../../scripts/ODIR_evaluation.py {ground_truth_path} {probs_csv_path}
# Out:
# kappa score: 0.32894992792693933  f-1 score: 0.8619269340974212  AUC vlaue: 0.8631789487639715  Final Score: 0.6846852702627774

# %% [markdown]
# # Cuantitative results
# The test script prints some results as can be seen in the output of the previous cell. Now, lets see some more.

# %%
label_names = ['N','D','G','C','A','H','M','O']

ground_truth = pd.read_excel(ground_truth_path).loc[:, label_names].to_numpy()
probs = pd.read_excel(probs_path).loc[:, label_names].to_numpy()

# %%
from sklearn import metrics
os.chdir('../../scripts')
from metrics import plot_confusion_matrices
os.chdir('../experiments/experiment_5/')

# Print test classification report
print('Clasification report:')
print(
    metrics.classification_report(
        ground_truth,
        probs>0.5,
        output_dict=False,
        target_names=label_names,
        zero_division=0
    )
)

# Plot one confusion matrix for each label
plot_confusion_matrices(ground_truth, probs, label_names)
# Out:
# Clasification report:
#               precision    recall  f1-score   support
#
#            N       0.53      0.44      0.48       214
#            D       0.51      0.34      0.40       226
#            G       0.67      0.12      0.20        34
#            C       0.88      0.59      0.71        37
#            A       0.00      0.00      0.00        37
#            H       0.00      0.00      0.00        29
#            M       0.82      0.77      0.79        30
#            O       0.51      0.17      0.26       217
#
#    micro avg       0.56      0.31      0.40       824
#    macro avg       0.49      0.30      0.36       824
# weighted avg       0.51      0.31      0.37       824
#  samples avg       0.35      0.32      0.33       824

# %% [markdown]
# # Cualitative results
# One patient with each disease (at least) is predicted. The original images are ploted along with their ground truth and predicted labels.

# %%
import torch
from torchvision import transforms
os.chdir('../../scripts')
from utils import load_model
from predict import pred_and_plot_image
os.chdir('../experiments/experiment_5/')

# %%
model = load_model(model_path, model_name)

test_df = pd.read_excel(test_annotations_path)

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# [INFO] Created new resnet50_dual_v1 model.

# %% [markdown]
# You can run the next cell multiple times to see different results

# %%
for label in label_names:
    patient = test_df[test_df[label] == 1].sample(replace=True).reset_index(drop=True)
    pred_and_plot_image(model=model,
                        left_image_path=f'{images_path}/{patient.at[0, "Left-Fundus"]}',
                        right_image_path=f'{images_path}/{patient.at[0, "Right-Fundus"]}',
                        transform=transform,
                        device=device,
                        label_names=label_names,
                        ground_truth=patient.loc[0, label_names].to_numpy())

# %% [markdown]
# # Zip the experiment data folder, the SummaryWriter folder and the experiment outputs
# This is necessary in order to be able to download this folders

# %%
# import shutil

# shutil.make_archive('experiment_data_compressed',
#                     format="zip",
#                     root_dir='data/')

# shutil.make_archive('runs_compressed',
#                     format="zip",
#                     root_dir='../runs/')

# shutil.make_archive('outputs_compressed',
#                     format="zip",
#                     root_dir='outputs/')
# Out:
# '/content/ODIR-5K-multi-label-classification/experiments/experiment_5/outputs_compressed.zip'
