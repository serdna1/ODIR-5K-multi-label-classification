# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/serdna1/ODIR-5K-multi-label-classification/blob/main/experiments/experiment_17/experiment_17.ipynb)

# %% [markdown]
# # Download GitHub repository and data
# The repo wont be downloading in my local machine, since i already have it there. It will if someone is running this notebook on their own machine, colab, ...

# %%
import os
import zipfile

# Unzip images (will only work after upload the file to colab working directory)
with zipfile.ZipFile('train_fov_cc_fov_512.zip', 'r') as zip_ref:
  print("Unzipping training images...")
  zip_ref.extractall(f'train_fov_cc_fov_512')
# !rm train_fov_cc_fov_512.zip

images_path = 'train_fov_cc_fov_512/'

# If the experiments folder doesnt exist im not in my local machine
if not os.path.exists('../../experiments'):
    # Clone project repository
    # !git clone https://github.com/serdna1/ODIR-5K-multi-label-classification.git

    # Move to the experiment folder
    # %cd ODIR-5K-multi-label-classification/experiments/experiment_17/
# Out:
# Unzipping training images...
# Cloning into 'ODIR-5K-multi-label-classification'...
# remote: Enumerating objects: 648, done.
# remote: Counting objects: 100% (138/138), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 648 (delta 61), reused 95 (delta 26), pack-reused 510
# Receiving objects: 100% (648/648), 99.66 MiB | 44.68 MiB/s, done.
# Resolving deltas: 100% (314/314), done.
# /content/ODIR-5K-multi-label-classification/experiments/experiment_15

# %% [markdown]
# # Drop some special patients from the dataset
# The background of some images is quite different from the rest ones. Therefore they wont be used for training.

# %%
import matplotlib.pyplot as plt
from PIL import Image

images_path = '../../../train_fov_cc_fov_512/'

special_images = ['2174_right.jpg', '2175_left.jpg', '2176_left.jpg', '2177_left.jpg',
                  '2177_right.jpg', '2178_right.jpg', '2179_left.jpg', '2179_right.jpg',
                  '2180_left.jpg', '2180_right.jpg', '2181_left.jpg', '2181_right.jpg',
                  '2182_left.jpg', '2182_right.jpg', '2957_left.jpg', '2957_right.jpg']

# Show one of this special images
image_path = f'{images_path}/{special_images[7]}'
img = Image.open(image_path)
plt.imshow(img)
plt.axis(False)
plt.title('Example of special image')
# Out:
# Text(0.5, 1.0, 'Example of special image')

# %%
import pandas as pd

original_annotations_path = '../../data/annotations/annotations.xlsx'
annotations_path = 'data/annotations.xlsx'

odir_df = pd.read_excel(original_annotations_path)

patients_to_drop_df = odir_df[odir_df['Left-Fundus'].isin(special_images) | odir_df['Right-Fundus'].isin(special_images)]
patients_to_drop_df # This are all the patients with one ore more of this spetial images
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1634  2174           65      Female  2174_left.jpg  2174_right.jpg
# 1635  2175           63        Male  2175_left.jpg  2175_right.jpg
# 1636  2176           82      Female  2176_left.jpg  2176_right.jpg
# 1637  2177           87        Male  2177_left.jpg  2177_right.jpg
# 1638  2178           84        Male  2178_left.jpg  2178_right.jpg
# 1639  2179           70      Female  2179_left.jpg  2179_right.jpg
# 1640  2180           66      Female  2180_left.jpg  2180_right.jpg
# 1641  2181           79      Female  2181_left.jpg  2181_right.jpg
# 1642  2182           70        Male  2182_left.jpg  2182_right.jpg
# 2334  2957           62      Female  2957_left.jpg  2957_right.jpg
#
#      Left-Diagnostic Keywords Right-Diagnostic Keywords  N  D  G  C  A  H  M  \
# 1634            normal fundus                  cataract  0  0  0  1  0  0  0
# 1635                 cataract             normal fundus  0  0  0  1  0  0  0
# 1636                 cataract                  cataract  0  0  0  1  0  0  0
# 1637  normal fundus，lens dust                  cataract  0  0  0  1  0  0  0
# 1638                 cataract                  cataract  0  0  0  1  0  0  0
# 1639                 cataract                  cataract  0  0  0  1  0  0  0
# 1640                 cataract                  cataract  0  0  0  1  0  0  0
# 1641                 cataract                  cataract  0  0  0  1  0  0  0
# 1642                 cataract                  cataract  0  0  0  1  0  0  0
# 2334            normal fundus             normal fundus  1  0  0  0  0  0  0
#
#       O
# 1634  0
# 1635  0
# 1636  0
# 1637  0
# 1638  0
# 1639  0
# 1640  0
# 1641  0
# 1642  0
# 2334  0

# %%
from pathlib import Path

experiment_data_path = 'data/'

print(f'Annotations length before droping the rows with the special images: {len(odir_df)}')

odir_df = odir_df.drop(patients_to_drop_df.index) # Drop the special patients
Path(experiment_data_path).mkdir(parents=True, exist_ok=True) # Create the experiment data folder
odir_df.to_excel(annotations_path) # Save annotations without the special patients

print(f'Annotations length after droping the rows with the special images: {len(odir_df)}')
# Out:
# Annotations length before droping the rows with the special images: 3500
# Annotations length after droping the rows with the special images: 3490

# %% [markdown]
# # Check dataset label distribution

# %%
label_names = ['N','D','G','C','A','H','M','O']

total_label_list = []
for label in label_names:
    total_label = int(odir_df.loc[:, [label]].sum().iloc[0])
    total_label_list.append(total_label)

plt.figure(figsize=(16,4))

bar = plt.bar(label_names, total_label_list)

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f}', ha='center', va='bottom')

plt.xlabel(f'Label')
plt.ylabel(f'No. of images')
plt.title(f'Label distribution')
# Out:
# Text(0.5, 1.0, 'Label distribution')

# %% [markdown]
# # Split dataset into train and validation

# %%
os.chdir('../../scripts/')
from utils import split_annotations
os.chdir('../experiments/experiment_17/')

# %%
# Split the original annotations file into train and validation annotations files
# val_ratio = 0.2 (value by default)
split_annotations(annotations_path, experiment_data_path, test_split=False)

# Read the previous three created .xlsx files into dataframes
train_df = pd.read_excel(f'{experiment_data_path}/train_annotations.xlsx')
val_df = pd.read_excel(f'{experiment_data_path}/val_annotations.xlsx')

len(train_df), len(val_df)
# Out:
# (2792, 698)

# %% [markdown]
# # Check train and validation datasets label distribution

# %%
import numpy as np

barWidth = 0.3333
fig = plt.subplots(figsize =(16, 4))

# Set height of bars
total_label_train_list = [int(train_df.loc[:, [label]].sum().iloc[0]) for label in label_names]
total_label_val_list = [int(val_df.loc[:, [label]].sum().iloc[0]) for label in label_names]

# Set position of bar on X axis
br_train = np.arange(len(label_names))
br_val = [x + barWidth for x in br_train]

# Make the plot
bar_train = plt.bar(br_train, total_label_train_list, color ='r', width = barWidth,
                    edgecolor ='grey', label ='train')
bar_val = plt.bar(br_val, total_label_val_list, color ='b', width = barWidth,
                  edgecolor ='grey', label ='val')

# Plot the height label on top of each bar
for bar in [bar_train, bar_val]:
    for rect in bar:
        height = rect.get_height()
        plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f}', ha='center', va='bottom')

plt.title(f'Train/Validation distribution')
plt.xlabel('Label')
plt.ylabel('Nº of images')
plt.xticks([r + barWidth/2 for r in range(len(total_label_train_list))], label_names)

plt.legend()
plt.show()

# %% [markdown]
# # Train the model

# %%
# %run ../../scripts/train.py -h # Run this line to check the train script arguments
# Out:
# usage: train.py [-h] [--random_seed RANDOM_SEED] [--model_name MODEL_NAME] [--fine_tune]
#                 [--images_path IMAGES_PATH] [--use_data_augmentation] [--crop_size CROP_SIZE]
#                 [--use_normalization] [--train_annotations_path TRAIN_ANNOTATIONS_PATH]
#                 [--val_annotations_path VAL_ANNOTATIONS_PATH] [--batch_size BATCH_SIZE]
#                 [--use_multilabel_balanced_random_sampler] [--num_workers NUM_WORKERS]
#                 [--use_weighted_loss] [--lr LR] [--momentum MOMENTUM]
#                 [--lr_scheduler LR_SCHEDULER]
#                 [--linear_lr_scheduler_total_iters LINEAR_LR_SCHEDULER_TOTAL_ITERS]
#                 [--linear_lr_scheduler_start_factor LINEAR_LR_SCHEDULER_START_FACTOR]
#                 [--linear_lr_scheduler_end_factor LINEAR_LR_SCHEDULER_END_FACTOR]
#                 [--cyclic_lr_scheduler_base_lr CYCLIC_LR_SCHEDULER_BASE_LR]
#                 [--cyclic_lr_scheduler_max_lr CYCLIC_LR_SCHEDULER_MAX_LR]
#                 [--cyclic_lr_scheduler_step_size_up CYCLIC_LR_SCHEDULER_STEP_SIZE_UP]
#                 [--epochs EPOCHS] [--patience PATIENCE] [--experiment_name EXPERIMENT_NAME]
#                 [--extra EXTRA]
#
# Train a network for image multi-label classification on ODIR-5K.
#
# options:
#   -h, --help            show this help message and exit
#   --random_seed RANDOM_SEED
#                         Sets random seed for reproducibility (default: 42).
#   --model_name MODEL_NAME
#                         Model arquitecture for training (default: resnet50_dual).
#   --fine_tune           If set dont freeze the backbone weights
#   --images_path IMAGES_PATH
#                         Path of ODIR training images (default: /kaggle/input/odir-size-512/odir-
#                         size-512).
#   --use_data_augmentation
#                         If set augment training data.
#   --crop_size CROP_SIZE
#                         Crop size used in data augmentation. Random crop in train, center crop in
#                         validation (default: 224)
#   --use_normalization   If set the images are normalized the same way the imagenet images where
#                         normalized to train the resnet50 used here.
#   --train_annotations_path TRAIN_ANNOTATIONS_PATH
#                         Path of train annotations file (default: /kaggle/input/odir-
#                         size-512/train_annotations.xlsx).
#   --val_annotations_path VAL_ANNOTATIONS_PATH
#                         Path of validation annotations file (default: /kaggle/input/odir-
#                         size-512/val_annotations.xlsx).
#   --batch_size BATCH_SIZE
#                         Batch size for data loaders (default: 32).
#   --use_multilabel_balanced_random_sampler
#                         Use a custom multilabel random sampler that balance the train dataset.
#   --num_workers NUM_WORKERS
#                         Number of workers for data loaders (default: os.cpu_count()).
#   --use_weighted_loss   If set the loss function uses the pos_weight param to consider the dataset
#                         imbalance.
#   --lr LR               Specifies learning rate for optimizer (default: 1e-3).
#   --momentum MOMENTUM   Specifies momentum for optimizer (default: 0.9).
#   --lr_scheduler LR_SCHEDULER
#                         Learning rate scheduler (default: None)
#   --linear_lr_scheduler_total_iters LINEAR_LR_SCHEDULER_TOTAL_ITERS
#                         Number of steps that the linear lr scheduler decays the learning rate
#                         (default: 50).
#   --linear_lr_scheduler_start_factor LINEAR_LR_SCHEDULER_START_FACTOR
#                         Start factor of the linear lr scheduler (default: 1).
#   --linear_lr_scheduler_end_factor LINEAR_LR_SCHEDULER_END_FACTOR
#                         End factor of the linear lr scheduler (default: 0.1).
#   --cyclic_lr_scheduler_base_lr CYCLIC_LR_SCHEDULER_BASE_LR
#                         Initial learning rate which is the lower boundary in the cycle for each
#                         parameter group (default: 0.001).
#   --cyclic_lr_scheduler_max_lr CYCLIC_LR_SCHEDULER_MAX_LR
#                         Upper learning rate boundaries in the cycle for each parameter group
#                         (default: 0.1).
#   --cyclic_lr_scheduler_step_size_up CYCLIC_LR_SCHEDULER_STEP_SIZE_UP
#                         Number of training iterations in the increasing half of a cycle (default:
#                         10).
#   --epochs EPOCHS       Number of training epochs (default: 5).
#   --patience PATIENCE   How long to wait after last time validation loss improved (default: 1).
#   --experiment_name EXPERIMENT_NAME
#                         Name of the experiment" (default: experiment_0).
#   --extra EXTRA         Extra info about the experiment (default: None).

# %%
# Arguments that will be passed to the train script
images_path = '../../../train_fov_cc_fov_512/'
train_annotations_path = 'data/train_annotations.xlsx'
val_annotations_path = 'data/val_annotations.xlsx'
crop_size = 448
lr = 0.001
lr_scheduler = 'LinearLR'
batch_size = 16
epochs = 100
patience = 30
experiment_name = 'experiment_17'

# %%
# %run ../../scripts/train.py --images_path {images_path} --train_annotations_path {train_annotations_path} --val_annotations_path {val_annotations_path}\
                            --batch_size {batch_size} --epochs {epochs} --patience {patience} --experiment_name {experiment_name} --use_normalization\
                            --lr {lr} --lr_scheduler {lr_scheduler} --use_weighted_loss --fine_tune --use_data_augmentation --crop_size {crop_size}
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 160MB/s]
# /content/ODIR-5K-multi-label-classification/scripts/utils.py:103: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   positives = int(df.loc[:, [label]].sum())
# /content/ODIR-5K-multi-label-classification/scripts/utils.py:103: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   positives = int(df.loc[:, [label]].sum())
# /content/ODIR-5K-multi-label-classification/scripts/utils.py:103: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   positives = int(df.loc[:, [label]].sum())
# /content/ODIR-5K-multi-label-classification/scripts/utils.py:103: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   positives = int(df.loc[:, [label]].sum())
# /content/ODIR-5K-multi-label-classification/scripts/utils.py:103: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   positives = int(df.loc[:, [label]].sum())
# /content/ODIR-5K-multi-label-classification/scripts/utils.py:103: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   positives = int(df.loc[:, [label]].sum())
# /content/ODIR-5K-multi-label-classification/scripts/utils.py:103: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   positives = int(df.loc[:, [label]].sum())
# /content/ODIR-5K-multi-label-classification/scripts/utils.py:103: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   positives = int(df.loc[:, [label]].sum())
# [INFO] Created new resnet50_dual model.
# [INFO] Created SummaryWriter, saving to: ../runs/resnet50_dual/experiment_15...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ep: 0 | t_loss: 1.1031 | t_kappa: 0.0923 | t_f1: 0.3793 | t_auc: 0.5766 | t_final: 0.3494 | v_loss: 0.6191 | v_kappa: 0.1685 | v_f1: 0.4083 | v_auc: 0.6217 | v_final: 0.3995
# Validation loss decreased (inf --> 0.619082).  Saving model ...
# Ep: 1 | t_loss: 0.9649 | t_kappa: 0.1794 | t_f1: 0.4199 | t_auc: 0.6362 | t_final: 0.4118 | v_loss: 0.5396 | v_kappa: 0.2074 | v_f1: 0.4272 | v_auc: 0.6266 | v_final: 0.4204
# Validation loss decreased (0.619082 --> 0.539597).  Saving model ...
# Ep: 2 | t_loss: 0.9193 | t_kappa: 0.1955 | t_f1: 0.4370 | t_auc: 0.6557 | t_final: 0.4294 | v_loss: 0.5521 | v_kappa: 0.2164 | v_f1: 0.4311 | v_auc: 0.6425 | v_final: 0.4300
# EarlyStopping counter: 1 out of 30
# Ep: 3 | t_loss: 0.8882 | t_kappa: 0.2132 | t_f1: 0.4459 | t_auc: 0.6667 | t_final: 0.4419 | v_loss: 0.5348 | v_kappa: 0.2161 | v_f1: 0.4355 | v_auc: 0.6560 | v_final: 0.4359
# Validation loss decreased (0.539597 --> 0.534837).  Saving model ...
# Ep: 4 | t_loss: 0.8739 | t_kappa: 0.2294 | t_f1: 0.4579 | t_auc: 0.6802 | t_final: 0.4558 | v_loss: 0.4895 | v_kappa: 0.2573 | v_f1: 0.4469 | v_auc: 0.6672 | v_final: 0.4571
# Validation loss decreased (0.534837 --> 0.489482).  Saving model ...
# Ep: 5 | t_loss: 0.8581 | t_kappa: 0.2342 | t_f1: 0.4608 | t_auc: 0.6844 | t_final: 0.4598 | v_loss: 0.5156 | v_kappa: 0.2421 | v_f1: 0.3796 | v_auc: 0.6703 | v_final: 0.4307
# EarlyStopping counter: 1 out of 30
# Ep: 6 | t_loss: 0.8425 | t_kappa: 0.2421 | t_f1: 0.4659 | t_auc: 0.6975 | t_final: 0.4685 | v_loss: 0.4645 | v_kappa: 0.2789 | v_f1: 0.4062 | v_auc: 0.6805 | v_final: 0.4552
# Validation loss decreased (0.489482 --> 0.464534).  Saving model ...
# Ep: 7 | t_loss: 0.8284 | t_kappa: 0.2586 | t_f1: 0.4743 | t_auc: 0.7104 | t_final: 0.4811 | v_loss: 0.5009 | v_kappa: 0.2587 | v_f1: 0.4377 | v_auc: 0.6799 | v_final: 0.4587
# EarlyStopping counter: 1 out of 30
# Ep: 8 | t_loss: 0.8176 | t_kappa: 0.2680 | t_f1: 0.4815 | t_auc: 0.7182 | t_final: 0.4892 | v_loss: 0.4470 | v_kappa: 0.3168 | v_f1: 0.4782 | v_auc: 0.6942 | v_final: 0.4964
# Validation loss decreased (0.464534 --> 0.447014).  Saving model ...
# Ep: 9 | t_loss: 0.8032 | t_kappa: 0.2859 | t_f1: 0.4950 | t_auc: 0.7239 | t_final: 0.5016 | v_loss: 0.4956 | v_kappa: 0.2796 | v_f1: 0.4295 | v_auc: 0.6981 | v_final: 0.4691
# EarlyStopping counter: 1 out of 30
# Ep: 10 | t_loss: 0.7870 | t_kappa: 0.2874 | t_f1: 0.4903 | t_auc: 0.7331 | t_final: 0.5036 | v_loss: 0.4746 | v_kappa: 0.2849 | v_f1: 0.4692 | v_auc: 0.7026 | v_final: 0.4856
# EarlyStopping counter: 2 out of 30
# Ep: 11 | t_loss: 0.7680 | t_kappa: 0.3028 | t_f1: 0.5036 | t_auc: 0.7399 | t_final: 0.5154 | v_loss: 0.4421 | v_kappa: 0.3131 | v_f1: 0.4858 | v_auc: 0.7180 | v_final: 0.5057
# Validation loss decreased (0.447014 --> 0.442092).  Saving model ...
# Ep: 12 | t_loss: 0.7558 | t_kappa: 0.3161 | t_f1: 0.5154 | t_auc: 0.7471 | t_final: 0.5262 | v_loss: 0.4622 | v_kappa: 0.3041 | v_f1: 0.4873 | v_auc: 0.7260 | v_final: 0.5058
# EarlyStopping counter: 1 out of 30
# Ep: 13 | t_loss: 0.7434 | t_kappa: 0.3144 | t_f1: 0.5131 | t_auc: 0.7536 | t_final: 0.5270 | v_loss: 0.4548 | v_kappa: 0.3113 | v_f1: 0.4687 | v_auc: 0.7306 | v_final: 0.5036
# EarlyStopping counter: 2 out of 30
# Ep: 14 | t_loss: 0.7294 | t_kappa: 0.3461 | t_f1: 0.5338 | t_auc: 0.7627 | t_final: 0.5476 | v_loss: 0.4453 | v_kappa: 0.3195 | v_f1: 0.5008 | v_auc: 0.7381 | v_final: 0.5195
# EarlyStopping counter: 3 out of 30
# Ep: 15 | t_loss: 0.7175 | t_kappa: 0.3347 | t_f1: 0.5245 | t_auc: 0.7613 | t_final: 0.5402 | v_loss: 0.4263 | v_kappa: 0.3370 | v_f1: 0.5009 | v_auc: 0.7482 | v_final: 0.5287
# Validation loss decreased (0.442092 --> 0.426345).  Saving model ...
# Ep: 16 | t_loss: 0.7149 | t_kappa: 0.3406 | t_f1: 0.5300 | t_auc: 0.7630 | t_final: 0.5446 | v_loss: 0.4361 | v_kappa: 0.3360 | v_f1: 0.5060 | v_auc: 0.7486 | v_final: 0.5302
# EarlyStopping counter: 1 out of 30
# Ep: 17 | t_loss: 0.6855 | t_kappa: 0.3523 | t_f1: 0.5322 | t_auc: 0.7697 | t_final: 0.5514 | v_loss: 0.4290 | v_kappa: 0.3400 | v_f1: 0.5103 | v_auc: 0.7529 | v_final: 0.5344
# EarlyStopping counter: 2 out of 30
# Ep: 18 | t_loss: 0.6802 | t_kappa: 0.3600 | t_f1: 0.5368 | t_auc: 0.7744 | t_final: 0.5571 | v_loss: 0.4177 | v_kappa: 0.3528 | v_f1: 0.5333 | v_auc: 0.7577 | v_final: 0.5479
# Validation loss decreased (0.426345 --> 0.417656).  Saving model ...
# Ep: 19 | t_loss: 0.6790 | t_kappa: 0.3676 | t_f1: 0.5456 | t_auc: 0.7804 | t_final: 0.5645 | v_loss: 0.3941 | v_kappa: 0.3691 | v_f1: 0.5219 | v_auc: 0.7562 | v_final: 0.5491
# Validation loss decreased (0.417656 --> 0.394104).  Saving model ...
# Ep: 20 | t_loss: 0.6683 | t_kappa: 0.3786 | t_f1: 0.5517 | t_auc: 0.7857 | t_final: 0.5720 | v_loss: 0.3971 | v_kappa: 0.3771 | v_f1: 0.5470 | v_auc: 0.7671 | v_final: 0.5637
# EarlyStopping counter: 1 out of 30
# Ep: 21 | t_loss: 0.6565 | t_kappa: 0.3831 | t_f1: 0.5548 | t_auc: 0.7859 | t_final: 0.5746 | v_loss: 0.3838 | v_kappa: 0.3962 | v_f1: 0.5421 | v_auc: 0.7706 | v_final: 0.5696
# Validation loss decreased (0.394104 --> 0.383756).  Saving model ...
# Ep: 22 | t_loss: 0.6388 | t_kappa: 0.3994 | t_f1: 0.5604 | t_auc: 0.7907 | t_final: 0.5835 | v_loss: 0.3675 | v_kappa: 0.4149 | v_f1: 0.5611 | v_auc: 0.7769 | v_final: 0.5843
# Validation loss decreased (0.383756 --> 0.367502).  Saving model ...
# Ep: 23 | t_loss: 0.6228 | t_kappa: 0.4065 | t_f1: 0.5647 | t_auc: 0.7950 | t_final: 0.5888 | v_loss: 0.3573 | v_kappa: 0.4328 | v_f1: 0.5641 | v_auc: 0.7828 | v_final: 0.5932
# Validation loss decreased (0.367502 --> 0.357294).  Saving model ...
# Ep: 24 | t_loss: 0.6236 | t_kappa: 0.4096 | t_f1: 0.5684 | t_auc: 0.7962 | t_final: 0.5914 | v_loss: 0.3766 | v_kappa: 0.4222 | v_f1: 0.5627 | v_auc: 0.7806 | v_final: 0.5885
# EarlyStopping counter: 1 out of 30
# Ep: 25 | t_loss: 0.6179 | t_kappa: 0.4077 | t_f1: 0.5694 | t_auc: 0.7978 | t_final: 0.5916 | v_loss: 0.3671 | v_kappa: 0.4152 | v_f1: 0.5571 | v_auc: 0.7876 | v_final: 0.5867
# EarlyStopping counter: 2 out of 30
# Ep: 26 | t_loss: 0.5908 | t_kappa: 0.4223 | t_f1: 0.5766 | t_auc: 0.8041 | t_final: 0.6010 | v_loss: 0.3511 | v_kappa: 0.4373 | v_f1: 0.5662 | v_auc: 0.7836 | v_final: 0.5957
# Validation loss decreased (0.357294 --> 0.351113).  Saving model ...
# Ep: 27 | t_loss: 0.5839 | t_kappa: 0.4296 | t_f1: 0.5770 | t_auc: 0.8067 | t_final: 0.6044 | v_loss: 0.3534 | v_kappa: 0.4381 | v_f1: 0.5685 | v_auc: 0.7857 | v_final: 0.5975
# EarlyStopping counter: 1 out of 30
# Ep: 28 | t_loss: 0.5964 | t_kappa: 0.4237 | t_f1: 0.5745 | t_auc: 0.8030 | t_final: 0.6004 | v_loss: 0.3780 | v_kappa: 0.4267 | v_f1: 0.5744 | v_auc: 0.7915 | v_final: 0.5975
# EarlyStopping counter: 2 out of 30
# Ep: 29 | t_loss: 0.5759 | t_kappa: 0.4320 | t_f1: 0.5805 | t_auc: 0.8089 | t_final: 0.6071 | v_loss: 0.3503 | v_kappa: 0.4327 | v_f1: 0.5658 | v_auc: 0.7899 | v_final: 0.5961
# Validation loss decreased (0.351113 --> 0.350276).  Saving model ...
# Ep: 30 | t_loss: 0.5590 | t_kappa: 0.4429 | t_f1: 0.5880 | t_auc: 0.8112 | t_final: 0.6141 | v_loss: 0.3647 | v_kappa: 0.4328 | v_f1: 0.5686 | v_auc: 0.7909 | v_final: 0.5974
# EarlyStopping counter: 1 out of 30
# Ep: 31 | t_loss: 0.5709 | t_kappa: 0.4377 | t_f1: 0.5830 | t_auc: 0.8049 | t_final: 0.6085 | v_loss: 0.3524 | v_kappa: 0.4189 | v_f1: 0.5635 | v_auc: 0.7879 | v_final: 0.5901
# EarlyStopping counter: 2 out of 30
# Ep: 32 | t_loss: 0.5544 | t_kappa: 0.4438 | t_f1: 0.5841 | t_auc: 0.8109 | t_final: 0.6129 | v_loss: 0.3370 | v_kappa: 0.4493 | v_f1: 0.5725 | v_auc: 0.7936 | v_final: 0.6051
# Validation loss decreased (0.350276 --> 0.336959).  Saving model ...
# Ep: 33 | t_loss: 0.5449 | t_kappa: 0.4561 | t_f1: 0.5933 | t_auc: 0.8185 | t_final: 0.6226 | v_loss: 0.3432 | v_kappa: 0.4382 | v_f1: 0.5661 | v_auc: 0.7951 | v_final: 0.5998
# EarlyStopping counter: 1 out of 30
# Ep: 34 | t_loss: 0.5422 | t_kappa: 0.4628 | t_f1: 0.5981 | t_auc: 0.8194 | t_final: 0.6268 | v_loss: 0.3423 | v_kappa: 0.4451 | v_f1: 0.5749 | v_auc: 0.7988 | v_final: 0.6063
# EarlyStopping counter: 2 out of 30
# Ep: 35 | t_loss: 0.5251 | t_kappa: 0.4737 | t_f1: 0.6038 | t_auc: 0.8252 | t_final: 0.6342 | v_loss: 0.3427 | v_kappa: 0.4469 | v_f1: 0.5748 | v_auc: 0.7978 | v_final: 0.6065
# EarlyStopping counter: 3 out of 30
# Ep: 36 | t_loss: 0.5415 | t_kappa: 0.4631 | t_f1: 0.5938 | t_auc: 0.8161 | t_final: 0.6243 | v_loss: 0.3575 | v_kappa: 0.4307 | v_f1: 0.5750 | v_auc: 0.7997 | v_final: 0.6018
# EarlyStopping counter: 4 out of 30
# Ep: 37 | t_loss: 0.5116 | t_kappa: 0.4855 | t_f1: 0.6063 | t_auc: 0.8213 | t_final: 0.6377 | v_loss: 0.3497 | v_kappa: 0.4405 | v_f1: 0.5789 | v_auc: 0.7996 | v_final: 0.6063
# EarlyStopping counter: 5 out of 30
# Ep: 38 | t_loss: 0.5147 | t_kappa: 0.4782 | t_f1: 0.6014 | t_auc: 0.8212 | t_final: 0.6336 | v_loss: 0.3237 | v_kappa: 0.4678 | v_f1: 0.5870 | v_auc: 0.8023 | v_final: 0.6190
# Validation loss decreased (0.336959 --> 0.323705).  Saving model ...
# Ep: 39 | t_loss: 0.5136 | t_kappa: 0.4823 | t_f1: 0.6049 | t_auc: 0.8236 | t_final: 0.6370 | v_loss: 0.3386 | v_kappa: 0.4647 | v_f1: 0.5873 | v_auc: 0.8018 | v_final: 0.6179
# EarlyStopping counter: 1 out of 30
# Ep: 40 | t_loss: 0.5140 | t_kappa: 0.4795 | t_f1: 0.6078 | t_auc: 0.8287 | t_final: 0.6387 | v_loss: 0.3378 | v_kappa: 0.4529 | v_f1: 0.5777 | v_auc: 0.8046 | v_final: 0.6117
# EarlyStopping counter: 2 out of 30
# Ep: 41 | t_loss: 0.5067 | t_kappa: 0.4906 | t_f1: 0.6137 | t_auc: 0.8283 | t_final: 0.6442 | v_loss: 0.3284 | v_kappa: 0.4673 | v_f1: 0.5830 | v_auc: 0.8037 | v_final: 0.6180
# EarlyStopping counter: 3 out of 30
# Ep: 42 | t_loss: 0.4936 | t_kappa: 0.4903 | t_f1: 0.6084 | t_auc: 0.8287 | t_final: 0.6425 | v_loss: 0.3251 | v_kappa: 0.4691 | v_f1: 0.5864 | v_auc: 0.8030 | v_final: 0.6195
# EarlyStopping counter: 4 out of 30
# Ep: 43 | t_loss: 0.5052 | t_kappa: 0.4986 | t_f1: 0.6206 | t_auc: 0.8332 | t_final: 0.6508 | v_loss: 0.3259 | v_kappa: 0.4656 | v_f1: 0.5821 | v_auc: 0.8049 | v_final: 0.6175
# EarlyStopping counter: 5 out of 30
# Ep: 44 | t_loss: 0.4955 | t_kappa: 0.4987 | t_f1: 0.6156 | t_auc: 0.8313 | t_final: 0.6485 | v_loss: 0.3259 | v_kappa: 0.4548 | v_f1: 0.5787 | v_auc: 0.8036 | v_final: 0.6124
# EarlyStopping counter: 6 out of 30
# Ep: 45 | t_loss: 0.4918 | t_kappa: 0.4927 | t_f1: 0.6091 | t_auc: 0.8294 | t_final: 0.6438 | v_loss: 0.3250 | v_kappa: 0.4714 | v_f1: 0.5872 | v_auc: 0.8054 | v_final: 0.6213
# EarlyStopping counter: 7 out of 30
# Ep: 46 | t_loss: 0.4886 | t_kappa: 0.5073 | t_f1: 0.6226 | t_auc: 0.8353 | t_final: 0.6551 | v_loss: 0.3244 | v_kappa: 0.4750 | v_f1: 0.5881 | v_auc: 0.8066 | v_final: 0.6232
# EarlyStopping counter: 8 out of 30
# Ep: 47 | t_loss: 0.4885 | t_kappa: 0.5090 | t_f1: 0.6175 | t_auc: 0.8288 | t_final: 0.6518 | v_loss: 0.3242 | v_kappa: 0.4478 | v_f1: 0.5824 | v_auc: 0.8083 | v_final: 0.6129
# EarlyStopping counter: 9 out of 30
# Ep: 48 | t_loss: 0.4814 | t_kappa: 0.5047 | t_f1: 0.6130 | t_auc: 0.8290 | t_final: 0.6489 | v_loss: 0.3307 | v_kappa: 0.4541 | v_f1: 0.5809 | v_auc: 0.8077 | v_final: 0.6142
# EarlyStopping counter: 10 out of 30
# Ep: 49 | t_loss: 0.4743 | t_kappa: 0.5127 | t_f1: 0.6219 | t_auc: 0.8361 | t_final: 0.6569 | v_loss: 0.3206 | v_kappa: 0.4728 | v_f1: 0.5934 | v_auc: 0.8070 | v_final: 0.6244
# Validation loss decreased (0.323705 --> 0.320586).  Saving model ...
# Ep: 50 | t_loss: 0.4671 | t_kappa: 0.5172 | t_f1: 0.6245 | t_auc: 0.8340 | t_final: 0.6586 | v_loss: 0.3173 | v_kappa: 0.4754 | v_f1: 0.5925 | v_auc: 0.8089 | v_final: 0.6256
# Validation loss decreased (0.320586 --> 0.317320).  Saving model ...
# Ep: 51 | t_loss: 0.4811 | t_kappa: 0.5090 | t_f1: 0.6190 | t_auc: 0.8334 | t_final: 0.6538 | v_loss: 0.3100 | v_kappa: 0.4935 | v_f1: 0.6006 | v_auc: 0.8074 | v_final: 0.6338
# Validation loss decreased (0.317320 --> 0.309962).  Saving model ...
# Ep: 52 | t_loss: 0.4747 | t_kappa: 0.5167 | t_f1: 0.6239 | t_auc: 0.8343 | t_final: 0.6583 | v_loss: 0.3185 | v_kappa: 0.4692 | v_f1: 0.5838 | v_auc: 0.8065 | v_final: 0.6198
# EarlyStopping counter: 1 out of 30
# Ep: 53 | t_loss: 0.4792 | t_kappa: 0.5142 | t_f1: 0.6198 | t_auc: 0.8317 | t_final: 0.6553 | v_loss: 0.3250 | v_kappa: 0.4599 | v_f1: 0.5836 | v_auc: 0.8080 | v_final: 0.6171
# EarlyStopping counter: 2 out of 30
# Ep: 54 | t_loss: 0.4695 | t_kappa: 0.5188 | t_f1: 0.6267 | t_auc: 0.8385 | t_final: 0.6613 | v_loss: 0.3218 | v_kappa: 0.4708 | v_f1: 0.5842 | v_auc: 0.8067 | v_final: 0.6205
# EarlyStopping counter: 3 out of 30
# Ep: 55 | t_loss: 0.4617 | t_kappa: 0.5219 | t_f1: 0.6292 | t_auc: 0.8396 | t_final: 0.6636 | v_loss: 0.3213 | v_kappa: 0.4550 | v_f1: 0.5813 | v_auc: 0.8086 | v_final: 0.6150
# EarlyStopping counter: 4 out of 30
# Ep: 56 | t_loss: 0.4660 | t_kappa: 0.5148 | t_f1: 0.6228 | t_auc: 0.8345 | t_final: 0.6574 | v_loss: 0.3199 | v_kappa: 0.4643 | v_f1: 0.5866 | v_auc: 0.8069 | v_final: 0.6192
# EarlyStopping counter: 5 out of 30
# Ep: 57 | t_loss: 0.4711 | t_kappa: 0.5215 | t_f1: 0.6260 | t_auc: 0.8398 | t_final: 0.6624 | v_loss: 0.3232 | v_kappa: 0.4550 | v_f1: 0.5795 | v_auc: 0.8053 | v_final: 0.6133
# EarlyStopping counter: 6 out of 30
# Ep: 58 | t_loss: 0.4549 | t_kappa: 0.5308 | t_f1: 0.6292 | t_auc: 0.8370 | t_final: 0.6657 | v_loss: 0.3199 | v_kappa: 0.4634 | v_f1: 0.5891 | v_auc: 0.8081 | v_final: 0.6202
# EarlyStopping counter: 7 out of 30
# Ep: 59 | t_loss: 0.4733 | t_kappa: 0.5264 | t_f1: 0.6298 | t_auc: 0.8389 | t_final: 0.6650 | v_loss: 0.3141 | v_kappa: 0.4813 | v_f1: 0.5929 | v_auc: 0.8067 | v_final: 0.6269
# EarlyStopping counter: 8 out of 30
# Ep: 60 | t_loss: 0.4612 | t_kappa: 0.5243 | t_f1: 0.6299 | t_auc: 0.8392 | t_final: 0.6645 | v_loss: 0.3193 | v_kappa: 0.4650 | v_f1: 0.5904 | v_auc: 0.8078 | v_final: 0.6210
# EarlyStopping counter: 9 out of 30
# Ep: 61 | t_loss: 0.4632 | t_kappa: 0.5248 | t_f1: 0.6272 | t_auc: 0.8383 | t_final: 0.6634 | v_loss: 0.3173 | v_kappa: 0.4743 | v_f1: 0.5909 | v_auc: 0.8090 | v_final: 0.6247
# EarlyStopping counter: 10 out of 30
# Ep: 62 | t_loss: 0.4572 | t_kappa: 0.5333 | t_f1: 0.6314 | t_auc: 0.8417 | t_final: 0.6688 | v_loss: 0.3096 | v_kappa: 0.4847 | v_f1: 0.5946 | v_auc: 0.8078 | v_final: 0.6290
# Validation loss decreased (0.309962 --> 0.309594).  Saving model ...
# Ep: 63 | t_loss: 0.4445 | t_kappa: 0.5368 | t_f1: 0.6355 | t_auc: 0.8420 | t_final: 0.6715 | v_loss: 0.3133 | v_kappa: 0.4794 | v_f1: 0.5922 | v_auc: 0.8094 | v_final: 0.6270
# EarlyStopping counter: 1 out of 30
# Ep: 64 | t_loss: 0.4535 | t_kappa: 0.5285 | t_f1: 0.6246 | t_auc: 0.8368 | t_final: 0.6633 | v_loss: 0.3152 | v_kappa: 0.4740 | v_f1: 0.5937 | v_auc: 0.8103 | v_final: 0.6260
# EarlyStopping counter: 2 out of 30
# Ep: 65 | t_loss: 0.4484 | t_kappa: 0.5431 | t_f1: 0.6355 | t_auc: 0.8378 | t_final: 0.6721 | v_loss: 0.3214 | v_kappa: 0.4778 | v_f1: 0.5983 | v_auc: 0.8107 | v_final: 0.6289
# EarlyStopping counter: 3 out of 30
# Ep: 66 | t_loss: 0.4588 | t_kappa: 0.5327 | t_f1: 0.6274 | t_auc: 0.8350 | t_final: 0.6651 | v_loss: 0.3199 | v_kappa: 0.4677 | v_f1: 0.5919 | v_auc: 0.8095 | v_final: 0.6230
# EarlyStopping counter: 4 out of 30
# Ep: 67 | t_loss: 0.4556 | t_kappa: 0.5255 | t_f1: 0.6230 | t_auc: 0.8348 | t_final: 0.6611 | v_loss: 0.3149 | v_kappa: 0.4849 | v_f1: 0.5997 | v_auc: 0.8116 | v_final: 0.6321
# EarlyStopping counter: 5 out of 30
# Ep: 68 | t_loss: 0.4552 | t_kappa: 0.5328 | t_f1: 0.6294 | t_auc: 0.8388 | t_final: 0.6670 | v_loss: 0.3177 | v_kappa: 0.4716 | v_f1: 0.5922 | v_auc: 0.8104 | v_final: 0.6247
# EarlyStopping counter: 6 out of 30
# Ep: 69 | t_loss: 0.4380 | t_kappa: 0.5426 | t_f1: 0.6334 | t_auc: 0.8414 | t_final: 0.6725 | v_loss: 0.3171 | v_kappa: 0.4753 | v_f1: 0.5946 | v_auc: 0.8092 | v_final: 0.6263
# EarlyStopping counter: 7 out of 30
# Ep: 70 | t_loss: 0.4534 | t_kappa: 0.5331 | t_f1: 0.6328 | t_auc: 0.8421 | t_final: 0.6693 | v_loss: 0.3241 | v_kappa: 0.4645 | v_f1: 0.5938 | v_auc: 0.8110 | v_final: 0.6231
# EarlyStopping counter: 8 out of 30
# Ep: 71 | t_loss: 0.4579 | t_kappa: 0.5363 | t_f1: 0.6276 | t_auc: 0.8335 | t_final: 0.6658 | v_loss: 0.3185 | v_kappa: 0.4724 | v_f1: 0.5944 | v_auc: 0.8118 | v_final: 0.6262
# EarlyStopping counter: 9 out of 30
# Ep: 72 | t_loss: 0.4476 | t_kappa: 0.5299 | t_f1: 0.6316 | t_auc: 0.8436 | t_final: 0.6684 | v_loss: 0.3173 | v_kappa: 0.4692 | v_f1: 0.5933 | v_auc: 0.8110 | v_final: 0.6245
# EarlyStopping counter: 10 out of 30
# Ep: 73 | t_loss: 0.4453 | t_kappa: 0.5392 | t_f1: 0.6305 | t_auc: 0.8363 | t_final: 0.6687 | v_loss: 0.3236 | v_kappa: 0.4610 | v_f1: 0.5909 | v_auc: 0.8116 | v_final: 0.6212
# EarlyStopping counter: 11 out of 30
# Ep: 74 | t_loss: 0.4509 | t_kappa: 0.5452 | t_f1: 0.6401 | t_auc: 0.8445 | t_final: 0.6766 | v_loss: 0.3154 | v_kappa: 0.4774 | v_f1: 0.5891 | v_auc: 0.8106 | v_final: 0.6257
# EarlyStopping counter: 12 out of 30
# Ep: 75 | t_loss: 0.4500 | t_kappa: 0.5425 | t_f1: 0.6353 | t_auc: 0.8403 | t_final: 0.6727 | v_loss: 0.3046 | v_kappa: 0.4884 | v_f1: 0.5918 | v_auc: 0.8102 | v_final: 0.6301
# Validation loss decreased (0.309594 --> 0.304552).  Saving model ...
# Ep: 76 | t_loss: 0.4382 | t_kappa: 0.5538 | t_f1: 0.6428 | t_auc: 0.8472 | t_final: 0.6813 | v_loss: 0.3187 | v_kappa: 0.4787 | v_f1: 0.5988 | v_auc: 0.8113 | v_final: 0.6296
# EarlyStopping counter: 1 out of 30
# Ep: 77 | t_loss: 0.4466 | t_kappa: 0.5451 | t_f1: 0.6382 | t_auc: 0.8443 | t_final: 0.6758 | v_loss: 0.3094 | v_kappa: 0.4756 | v_f1: 0.5854 | v_auc: 0.8110 | v_final: 0.6240
# EarlyStopping counter: 2 out of 30
# Ep: 78 | t_loss: 0.4348 | t_kappa: 0.5444 | t_f1: 0.6364 | t_auc: 0.8467 | t_final: 0.6758 | v_loss: 0.3113 | v_kappa: 0.4789 | v_f1: 0.5942 | v_auc: 0.8111 | v_final: 0.6281
# EarlyStopping counter: 3 out of 30
# Ep: 79 | t_loss: 0.4276 | t_kappa: 0.5622 | t_f1: 0.6442 | t_auc: 0.8465 | t_final: 0.6843 | v_loss: 0.3118 | v_kappa: 0.4838 | v_f1: 0.5990 | v_auc: 0.8107 | v_final: 0.6312
# EarlyStopping counter: 4 out of 30
# Ep: 80 | t_loss: 0.4298 | t_kappa: 0.5610 | t_f1: 0.6436 | t_auc: 0.8455 | t_final: 0.6833 | v_loss: 0.3075 | v_kappa: 0.4866 | v_f1: 0.5991 | v_auc: 0.8116 | v_final: 0.6324
# EarlyStopping counter: 5 out of 30
# Ep: 81 | t_loss: 0.4326 | t_kappa: 0.5516 | t_f1: 0.6380 | t_auc: 0.8453 | t_final: 0.6783 | v_loss: 0.3062 | v_kappa: 0.4926 | v_f1: 0.5998 | v_auc: 0.8119 | v_final: 0.6348
# EarlyStopping counter: 6 out of 30
# Ep: 82 | t_loss: 0.4302 | t_kappa: 0.5560 | t_f1: 0.6409 | t_auc: 0.8464 | t_final: 0.6811 | v_loss: 0.3087 | v_kappa: 0.4847 | v_f1: 0.5981 | v_auc: 0.8121 | v_final: 0.6317
# EarlyStopping counter: 7 out of 30
# Ep: 83 | t_loss: 0.4252 | t_kappa: 0.5573 | t_f1: 0.6366 | t_auc: 0.8432 | t_final: 0.6790 | v_loss: 0.3054 | v_kappa: 0.4971 | v_f1: 0.6023 | v_auc: 0.8124 | v_final: 0.6372
# EarlyStopping counter: 8 out of 30
# Ep: 84 | t_loss: 0.4364 | t_kappa: 0.5548 | t_f1: 0.6396 | t_auc: 0.8429 | t_final: 0.6791 | v_loss: 0.3120 | v_kappa: 0.4759 | v_f1: 0.5956 | v_auc: 0.8113 | v_final: 0.6276
# EarlyStopping counter: 9 out of 30
# Ep: 85 | t_loss: 0.4385 | t_kappa: 0.5531 | t_f1: 0.6411 | t_auc: 0.8453 | t_final: 0.6799 | v_loss: 0.3077 | v_kappa: 0.4839 | v_f1: 0.5978 | v_auc: 0.8123 | v_final: 0.6313
# EarlyStopping counter: 10 out of 30
# Ep: 86 | t_loss: 0.4309 | t_kappa: 0.5590 | t_f1: 0.6428 | t_auc: 0.8449 | t_final: 0.6822 | v_loss: 0.3064 | v_kappa: 0.4920 | v_f1: 0.5993 | v_auc: 0.8115 | v_final: 0.6342
# EarlyStopping counter: 11 out of 30
# Ep: 87 | t_loss: 0.4385 | t_kappa: 0.5409 | t_f1: 0.6349 | t_auc: 0.8440 | t_final: 0.6733 | v_loss: 0.3166 | v_kappa: 0.4781 | v_f1: 0.6023 | v_auc: 0.8141 | v_final: 0.6315
# EarlyStopping counter: 12 out of 30
# Ep: 88 | t_loss: 0.4266 | t_kappa: 0.5500 | t_f1: 0.6434 | t_auc: 0.8504 | t_final: 0.6813 | v_loss: 0.3114 | v_kappa: 0.4791 | v_f1: 0.5945 | v_auc: 0.8137 | v_final: 0.6291
# EarlyStopping counter: 13 out of 30
# Ep: 89 | t_loss: 0.4308 | t_kappa: 0.5558 | t_f1: 0.6423 | t_auc: 0.8465 | t_final: 0.6815 | v_loss: 0.3147 | v_kappa: 0.4722 | v_f1: 0.5923 | v_auc: 0.8128 | v_final: 0.6258
# EarlyStopping counter: 14 out of 30
# Ep: 90 | t_loss: 0.4191 | t_kappa: 0.5678 | t_f1: 0.6451 | t_auc: 0.8518 | t_final: 0.6882 | v_loss: 0.3045 | v_kappa: 0.5038 | v_f1: 0.6041 | v_auc: 0.8124 | v_final: 0.6401
# Validation loss decreased (0.304552 --> 0.304540).  Saving model ...
# Ep: 91 | t_loss: 0.4242 | t_kappa: 0.5648 | t_f1: 0.6451 | t_auc: 0.8471 | t_final: 0.6857 | v_loss: 0.3026 | v_kappa: 0.4981 | v_f1: 0.6029 | v_auc: 0.8124 | v_final: 0.6378
# Validation loss decreased (0.304540 --> 0.302558).  Saving model ...
# Ep: 92 | t_loss: 0.4322 | t_kappa: 0.5623 | t_f1: 0.6475 | t_auc: 0.8488 | t_final: 0.6862 | v_loss: 0.3096 | v_kappa: 0.4837 | v_f1: 0.5952 | v_auc: 0.8138 | v_final: 0.6309
# EarlyStopping counter: 1 out of 30
# Ep: 93 | t_loss: 0.4226 | t_kappa: 0.5575 | t_f1: 0.6390 | t_auc: 0.8440 | t_final: 0.6802 | v_loss: 0.3017 | v_kappa: 0.5026 | v_f1: 0.6025 | v_auc: 0.8128 | v_final: 0.6393
# Validation loss decreased (0.302558 --> 0.301663).  Saving model ...
# Ep: 94 | t_loss: 0.4352 | t_kappa: 0.5557 | t_f1: 0.6441 | t_auc: 0.8485 | t_final: 0.6828 | v_loss: 0.3123 | v_kappa: 0.4854 | v_f1: 0.5988 | v_auc: 0.8153 | v_final: 0.6332
# EarlyStopping counter: 1 out of 30
# Ep: 95 | t_loss: 0.4204 | t_kappa: 0.5677 | t_f1: 0.6454 | t_auc: 0.8494 | t_final: 0.6875 | v_loss: 0.3050 | v_kappa: 0.5001 | v_f1: 0.5988 | v_auc: 0.8140 | v_final: 0.6376
# EarlyStopping counter: 2 out of 30
# Ep: 96 | t_loss: 0.4230 | t_kappa: 0.5617 | t_f1: 0.6476 | t_auc: 0.8501 | t_final: 0.6865 | v_loss: 0.3109 | v_kappa: 0.4895 | v_f1: 0.5949 | v_auc: 0.8128 | v_final: 0.6324
# EarlyStopping counter: 3 out of 30
# Ep: 97 | t_loss: 0.4279 | t_kappa: 0.5590 | t_f1: 0.6480 | t_auc: 0.8490 | t_final: 0.6853 | v_loss: 0.3133 | v_kappa: 0.4714 | v_f1: 0.5934 | v_auc: 0.8135 | v_final: 0.6261
# EarlyStopping counter: 4 out of 30
# Ep: 98 | t_loss: 0.4225 | t_kappa: 0.5599 | t_f1: 0.6464 | t_auc: 0.8499 | t_final: 0.6854 | v_loss: 0.3072 | v_kappa: 0.4917 | v_f1: 0.5975 | v_auc: 0.8137 | v_final: 0.6343
# EarlyStopping counter: 5 out of 30
# Ep: 99 | t_loss: 0.4147 | t_kappa: 0.5665 | t_f1: 0.6466 | t_auc: 0.8473 | t_final: 0.6868 | v_loss: 0.3131 | v_kappa: 0.4928 | v_f1: 0.6064 | v_auc: 0.8134 | v_final: 0.6375
# EarlyStopping counter: 6 out of 30

# %% [markdown]
# Run the next cell to see the metrics trough the epochs using the tensorboard interface

# %%
# %reload_ext tensorboard
# %tensorboard --logdir ../runs

# %% [markdown]
# # Test the model with the validation dataset
# Since there is no access to the test annotatations (only to the images) the test will be performed on the validation dataset, to be able to see some results.

# %%
# %run ../../scripts/test.py -h # Run this line to check the test script arguments
# Out:
# usage: test.py [-h] [--model_name MODEL_NAME] [--model_path MODEL_PATH]
#                [--images_path IMAGES_PATH] [--crop_size CROP_SIZE]
#                [--test_annotations_path TEST_ANNOTATIONS_PATH] [--use_normalization]
#                [--batch_size BATCH_SIZE] [--num_workers NUM_WORKERS]
#                [--ground_truth_path GROUND_TRUTH_PATH] [--probs_path PROBS_PATH]
#
# Test a model with a dataset.
#
# options:
#   -h, --help            show this help message and exit
#   --model_name MODEL_NAME
#                         Model arquitecture for testing (default: resnet50_dual).
#   --model_path MODEL_PATH
#                         Path to the model to test the dataset with (default:
#                         outputs/resnet50_dual_experiment_0_model.pth).
#   --images_path IMAGES_PATH
#                         Path of test images (default: ../../data/train_fov_cc_fov_224/).
#   --crop_size CROP_SIZE
#                         Crop size used for center cropping the test images (default: 224)
#   --test_annotations_path TEST_ANNOTATIONS_PATH
#                         Path of test annotations file (default: data/test_annotations.xlsx).
#   --use_normalization   If set the images are normalized the same way the imagenet images were
#                         normalized to train the resnet50 used here.
#   --batch_size BATCH_SIZE
#                         Batch size for data loaders (default: 32).
#   --num_workers NUM_WORKERS
#                         Number of workers for data loaders (default: os.cpu_count()).
#   --ground_truth_path GROUND_TRUTH_PATH
#                         Path to store the ground truth labels used in test (default: None).
#   --probs_path PROBS_PATH
#                         Path to store the result probs of test (default: None).

# %%
test_annotations_path = 'data/val_annotations.xlsx' # val annotations are used for test
images_path = '../../../train_fov_cc_fov_512/'
model_path = 'outputs/resnet50_dual_experiment_17_model.pth'
ground_truth_path = 'outputs/ground_truth.xlsx'
probs_path = 'outputs/probs.xlsx'

# %%
# %run ../../scripts/test.py --model_path {model_path} --images_path {images_path} --test_annotations_path {test_annotations_path} --use_normalization\
                           --ground_truth_path {ground_truth_path} --probs_path {probs_path} --crop_size {crop_size}
# Out:
# [INFO] Created new resnet50_dual model.
# test_loss: 0.3008 | test_kappa: 0.5026 | test_f1: 0.6025 | test_auc: 0.8128 | test_final: 0.6393

# %% [markdown]
# # Run the ODIR_evaluation.py script on test (validation) dataset
# This is a file provided along with the data by the challenge. And its supposed to have an example on how to compute the kappa, f1, auc, and final score metrics but i dont think they are well computed here as they are always too good (as shown later, the cualitative results for test are much worst). As a result of this, i use my own version of this metrics (see the function compute_challenge_metrics on the metrics script). Either way i'll run it.

# %%
ground_truth_path = 'outputs/ground_truth.xlsx'
probs_path = 'outputs/probs.xlsx'
probs_csv_path = 'outputs/probs.csv'

probs_df = pd.read_excel(probs_path)
probs_df.to_csv(probs_csv_path, index=False) # The ODIR_evaluation script asks the probs file to be in .csv format

# %run ../../scripts/ODIR_evaluation.py {ground_truth_path} {probs_csv_path}
# Out:
# kappa score: 0.5212437140555108  f-1 score: 0.8585243553008596  AUC vlaue: 0.9118700028555111  Final Score: 0.7638793574039605

# %% [markdown]
# # Cuantitative results
# The test script prints some results as can be seen in the output of the previous cell. Now, lets see some more.

# %%
label_names = ['N','D','G','C','A','H','M','O']

ground_truth = pd.read_excel(ground_truth_path).loc[:, label_names].to_numpy()
probs = pd.read_excel(probs_path).loc[:, label_names].to_numpy()

# %%
from sklearn import metrics
os.chdir('../../scripts')
from metrics import plot_confusion_matrices
os.chdir('../experiments/experiment_17/')

# Print test classification report
print('Clasification report:')
print(
    metrics.classification_report(
        ground_truth,
        probs>0.5,
        output_dict=False,
        target_names=label_names,
        zero_division=0
    )
)

# Plot one confusion matrix for each label
plot_confusion_matrices(ground_truth, probs, label_names)
# Out:
# Clasification report:
#               precision    recall  f1-score   support
#
#            N       0.50      0.86      0.64       214
#            D       0.60      0.74      0.66       226
#            G       0.38      0.74      0.50        34
#            C       0.56      0.97      0.71        37
#            A       0.51      0.68      0.58        37
#            H       0.35      0.45      0.39        29
#            M       0.72      0.97      0.83        30
#            O       0.46      0.57      0.51       217
#
#    micro avg       0.51      0.73      0.60       824
#    macro avg       0.51      0.75      0.60       824
# weighted avg       0.52      0.73      0.60       824
#  samples avg       0.56      0.75      0.61       824

# %% [markdown]
# # Cualitative results
# One patient with each disease (at least) is predicted. The original images are ploted along with their ground truth and predicted labels.

# %%
import torch
from torchvision import transforms
os.chdir('../../scripts')
from utils import load_model
from transforms import ToTensorDual, NormalizeDual, CenterCropDual
from predict import pred_and_plot_image
os.chdir('../experiments/experiment_17/')

# %%
model = load_model(model_path)

test_df = pd.read_excel(test_annotations_path)

transform = transforms.Compose([
    CenterCropDual(size=crop_size),
    ToTensorDual(),
    NormalizeDual(mean=[0.485, 0.456, 0.406],
                    std=[0.229, 0.224, 0.225])
])

device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# [INFO] Created new resnet50_dual model.

# %% [markdown]
# You can run the next cell multiple times to see different results

# %%
for label in label_names:
    patient = test_df[test_df[label] == 1].sample(replace=True).reset_index(drop=True)
    pred_and_plot_image(model=model,
                        left_image_path=f'{images_path}/{patient.at[0, "Left-Fundus"]}',
                        right_image_path=f'{images_path}/{patient.at[0, "Right-Fundus"]}',
                        transform=transform,
                        device=device,
                        label_names=label_names,
                        ground_truth=patient.loc[0, label_names].to_numpy())

# %% [markdown]
# # Zip the experiment data folder, the SummaryWriter folder and the experiment outputs
# This is necessary in order to be able to download this folders

# %%
# import shutil

# shutil.make_archive('experiment_data_compressed',
#                     format="zip",
#                     root_dir='data/')

# shutil.make_archive('runs_compressed',
#                     format="zip",
#                     root_dir='../runs/')

# shutil.make_archive('outputs_compressed',
#                     format="zip",
#                     root_dir='outputs/')
# Out:
# '/content/ODIR-5K-multi-label-classification/experiments/experiment_15/outputs_compressed.zip'
