# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/serdna1/ODIR-5K-multi-label-classification/blob/main/experiments/experiment_14/experiment_14.ipynb)

# %% [markdown]
# # Download GitHub repository and data
# The repo wont be downloading in my local machine, since i already have it there. It will if someone is running this notebook on their own machine, colab, ...

# %%
import os
import zipfile

images_path = 'ODIR-5K-multi-label-classification/data/images/'

# If the experiments folder doesnt exist im not in my local machine
if not os.path.exists('../../experiments'):
    # Clone project repository
    # !git clone https://github.com/serdna1/ODIR-5K-multi-label-classification.git

    # Unzip images
    with zipfile.ZipFile(f'{images_path}/train_fov_cc_fov_224.zip', 'r') as zip_ref:
      print("Unzipping training images...")
      zip_ref.extractall(f'{images_path}/train_fov_cc_fov_224')
    # !rm ODIR-5K-multi-label-classification/data/images/train_fov_cc_fov_224.zip
    # !rm ODIR-5K-multi-label-classification/data/images/train_224.zip

    # Move to the experiment folder
    # %cd ODIR-5K-multi-label-classification/experiments/experiment_14/
# Out:
# Cloning into 'ODIR-5K-multi-label-classification'...
# remote: Enumerating objects: 685, done.
# remote: Counting objects: 100% (175/175), done.
# remote: Compressing objects: 100% (134/134), done.
# remote: Total 685 (delta 76), reused 127 (delta 35), pack-reused 510
# Receiving objects: 100% (685/685), 105.68 MiB | 26.97 MiB/s, done.
# Resolving deltas: 100% (329/329), done.
# Unzipping training images...
# /content/ODIR-5K-multi-label-classification/experiments/experiment_14

# %% [markdown]
# # Drop some special patients from the dataset
# The background of some images is quite different from the rest ones. Therefore they wont be used for training.

# %%
import matplotlib.pyplot as plt
from PIL import Image

images_path = '../../data/images/train_fov_cc_fov_224'

special_images = ['2174_right.jpg', '2175_left.jpg', '2176_left.jpg', '2177_left.jpg',
                  '2177_right.jpg', '2178_right.jpg', '2179_left.jpg', '2179_right.jpg',
                  '2180_left.jpg', '2180_right.jpg', '2181_left.jpg', '2181_right.jpg',
                  '2182_left.jpg', '2182_right.jpg', '2957_left.jpg', '2957_right.jpg']

# Show one of this special images
image_path = f'{images_path}/{special_images[7]}'
img = Image.open(image_path)
plt.imshow(img)
plt.axis(False)
plt.title('Example of special image')
# Out:
# Text(0.5, 1.0, 'Example of special image')

# %%
import pandas as pd

original_annotations_path = '../../data/annotations/annotations.xlsx'
annotations_path = 'data/annotations.xlsx'

odir_df = pd.read_excel(original_annotations_path)

patients_to_drop_df = odir_df[odir_df['Left-Fundus'].isin(special_images) | odir_df['Right-Fundus'].isin(special_images)]
patients_to_drop_df # This are all the patients with one ore more of this spetial images
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1634  2174           65      Female  2174_left.jpg  2174_right.jpg
# 1635  2175           63        Male  2175_left.jpg  2175_right.jpg
# 1636  2176           82      Female  2176_left.jpg  2176_right.jpg
# 1637  2177           87        Male  2177_left.jpg  2177_right.jpg
# 1638  2178           84        Male  2178_left.jpg  2178_right.jpg
# 1639  2179           70      Female  2179_left.jpg  2179_right.jpg
# 1640  2180           66      Female  2180_left.jpg  2180_right.jpg
# 1641  2181           79      Female  2181_left.jpg  2181_right.jpg
# 1642  2182           70        Male  2182_left.jpg  2182_right.jpg
# 2334  2957           62      Female  2957_left.jpg  2957_right.jpg
#
#      Left-Diagnostic Keywords Right-Diagnostic Keywords  N  D  G  C  A  H  M  \
# 1634            normal fundus                  cataract  0  0  0  1  0  0  0
# 1635                 cataract             normal fundus  0  0  0  1  0  0  0
# 1636                 cataract                  cataract  0  0  0  1  0  0  0
# 1637  normal fundus，lens dust                  cataract  0  0  0  1  0  0  0
# 1638                 cataract                  cataract  0  0  0  1  0  0  0
# 1639                 cataract                  cataract  0  0  0  1  0  0  0
# 1640                 cataract                  cataract  0  0  0  1  0  0  0
# 1641                 cataract                  cataract  0  0  0  1  0  0  0
# 1642                 cataract                  cataract  0  0  0  1  0  0  0
# 2334            normal fundus             normal fundus  1  0  0  0  0  0  0
#
#       O
# 1634  0
# 1635  0
# 1636  0
# 1637  0
# 1638  0
# 1639  0
# 1640  0
# 1641  0
# 1642  0
# 2334  0

# %%
from pathlib import Path

experiment_data_path = 'data/'

print(f'Annotations length before droping the rows with the special images: {len(odir_df)}')

odir_df = odir_df.drop(patients_to_drop_df.index) # Drop the special patients
Path(experiment_data_path).mkdir(parents=True, exist_ok=True) # Create the experiment data folder
odir_df.to_excel(annotations_path) # Save annotations without the special patients

print(f'Annotations length after droping the rows with the special images: {len(odir_df)}')
# Out:
# Annotations length before droping the rows with the special images: 3500
# Annotations length after droping the rows with the special images: 3490

# %% [markdown]
# # Check dataset label distribution

# %%
label_names = ['N','D','G','C','A','H','M','O']

total_label_list = []
for label in label_names:
    total_label = int(odir_df.loc[:, [label]].sum().iloc[0])
    total_label_list.append(total_label)

plt.figure(figsize=(16,4))

bar = plt.bar(label_names, total_label_list)

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f}', ha='center', va='bottom')

plt.xlabel(f'Label')
plt.ylabel(f'No. of images')
plt.title(f'Label distribution')
# Out:
# Text(0.5, 1.0, 'Label distribution')

# %% [markdown]
# # Split dataset into train and validation

# %%
os.chdir('../../scripts/')
from utils import split_annotations
os.chdir('../experiments/experiment_14/')

# %%
# Split the original annotations file into train and validation annotations files
# val_ratio = 0.2 (value by default)
split_annotations(annotations_path, experiment_data_path, test_split=False)

# Read the previous three created .xlsx files into dataframes
train_df = pd.read_excel(f'{experiment_data_path}/train_annotations.xlsx')
val_df = pd.read_excel(f'{experiment_data_path}/val_annotations.xlsx')

len(train_df), len(val_df)
# Out:
# (2792, 698)

# %% [markdown]
# # Check train and validation datasets label distribution

# %%
import numpy as np

barWidth = 0.3333
fig = plt.subplots(figsize =(16, 4))

# Set height of bars
total_label_train_list = [int(train_df.loc[:, [label]].sum().iloc[0]) for label in label_names]
total_label_val_list = [int(val_df.loc[:, [label]].sum().iloc[0]) for label in label_names]

# Set position of bar on X axis
br_train = np.arange(len(label_names))
br_val = [x + barWidth for x in br_train]

# Make the plot
bar_train = plt.bar(br_train, total_label_train_list, color ='r', width = barWidth,
                    edgecolor ='grey', label ='train')
bar_val = plt.bar(br_val, total_label_val_list, color ='b', width = barWidth,
                  edgecolor ='grey', label ='val')

# Plot the height label on top of each bar
for bar in [bar_train, bar_val]:
    for rect in bar:
        height = rect.get_height()
        plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f}', ha='center', va='bottom')

plt.title(f'Train/Validation distribution')
plt.xlabel('Label')
plt.ylabel('Nº of images')
plt.xticks([r + barWidth/2 for r in range(len(total_label_train_list))], label_names)

plt.legend()
plt.show()

# %% [markdown]
# # Train the model

# %%
# %run ../../scripts/train.py -h # Run this line to check the train script arguments
# Out:
# usage: train.py [-h] [--random_seed RANDOM_SEED] [--model_name MODEL_NAME] [--fine_tune]
#                 [--images_path IMAGES_PATH] [--use_data_augmentation] [--crop_size CROP_SIZE]
#                 [--use_normalization] [--train_annotations_path TRAIN_ANNOTATIONS_PATH]
#                 [--val_annotations_path VAL_ANNOTATIONS_PATH] [--batch_size BATCH_SIZE]
#                 [--use_multilabel_balanced_random_sampler] [--num_workers NUM_WORKERS]
#                 [--use_weighted_loss] [--lr LR] [--momentum MOMENTUM]
#                 [--lr_scheduler LR_SCHEDULER]
#                 [--linear_lr_scheduler_total_iters LINEAR_LR_SCHEDULER_TOTAL_ITERS]
#                 [--linear_lr_scheduler_start_factor LINEAR_LR_SCHEDULER_START_FACTOR]
#                 [--linear_lr_scheduler_end_factor LINEAR_LR_SCHEDULER_END_FACTOR]
#                 [--cyclic_lr_scheduler_base_lr CYCLIC_LR_SCHEDULER_BASE_LR]
#                 [--cyclic_lr_scheduler_max_lr CYCLIC_LR_SCHEDULER_MAX_LR]
#                 [--cyclic_lr_scheduler_step_size_up CYCLIC_LR_SCHEDULER_STEP_SIZE_UP]
#                 [--epochs EPOCHS] [--patience PATIENCE] [--experiment_name EXPERIMENT_NAME]
#                 [--extra EXTRA]
#
# Train a network for image multi-label classification on ODIR-5K.
#
# options:
#   -h, --help            show this help message and exit
#   --random_seed RANDOM_SEED
#                         Sets random seed for reproducibility (default: 42).
#   --model_name MODEL_NAME
#                         Model arquitecture for training (default: resnet50_dual).
#   --fine_tune           If set dont freeze the backbone weights
#   --images_path IMAGES_PATH
#                         Path of ODIR training images (default: /kaggle/input/odir-size-512/odir-
#                         size-512).
#   --use_data_augmentation
#                         If set augment training data.
#   --crop_size CROP_SIZE
#                         Crop size used in data augmentation. Random crop in train, center crop in
#                         validation (default: 224)
#   --use_normalization   If set the images are normalized the same way the imagenet images where
#                         normalized to train the resnet50 used here.
#   --train_annotations_path TRAIN_ANNOTATIONS_PATH
#                         Path of train annotations file (default: /kaggle/input/odir-
#                         size-512/train_annotations.xlsx).
#   --val_annotations_path VAL_ANNOTATIONS_PATH
#                         Path of validation annotations file (default: /kaggle/input/odir-
#                         size-512/val_annotations.xlsx).
#   --batch_size BATCH_SIZE
#                         Batch size for data loaders (default: 32).
#   --use_multilabel_balanced_random_sampler
#                         Use a custom multilabel random sampler that balance the train dataset.
#   --num_workers NUM_WORKERS
#                         Number of workers for data loaders (default: os.cpu_count()).
#   --use_weighted_loss   If set the loss function uses the pos_weight param to consider the dataset
#                         imbalance.
#   --lr LR               Specifies learning rate for optimizer (default: 1e-3).
#   --momentum MOMENTUM   Specifies momentum for optimizer (default: 0.9).
#   --lr_scheduler LR_SCHEDULER
#                         Learning rate scheduler (default: None)
#   --linear_lr_scheduler_total_iters LINEAR_LR_SCHEDULER_TOTAL_ITERS
#                         Number of steps that the linear lr scheduler decays the learning rate
#                         (default: 50).
#   --linear_lr_scheduler_start_factor LINEAR_LR_SCHEDULER_START_FACTOR
#                         Start factor of the linear lr scheduler (default: 1).
#   --linear_lr_scheduler_end_factor LINEAR_LR_SCHEDULER_END_FACTOR
#                         End factor of the linear lr scheduler (default: 0.1).
#   --cyclic_lr_scheduler_base_lr CYCLIC_LR_SCHEDULER_BASE_LR
#                         Initial learning rate which is the lower boundary in the cycle for each
#                         parameter group (default: 0.001).
#   --cyclic_lr_scheduler_max_lr CYCLIC_LR_SCHEDULER_MAX_LR
#                         Upper learning rate boundaries in the cycle for each parameter group
#                         (default: 0.1).
#   --cyclic_lr_scheduler_step_size_up CYCLIC_LR_SCHEDULER_STEP_SIZE_UP
#                         Number of training iterations in the increasing half of a cycle (default:
#                         10).
#   --epochs EPOCHS       Number of training epochs (default: 5).
#   --patience PATIENCE   How long to wait after last time validation loss improved (default: 1).
#   --experiment_name EXPERIMENT_NAME
#                         Name of the experiment" (default: experiment_0).
#   --extra EXTRA         Extra info about the experiment (default: None).

# %%
# Arguments that will be passed to the train script
images_path = '../../data/images/train_fov_cc_fov_224'
train_annotations_path = 'data/train_annotations.xlsx'
val_annotations_path = 'data/val_annotations.xlsx'
crop_size = 196
lr = 0.05
lr_scheduler = 'LinearLR'
batch_size = 32
epochs = 100
patience = 20
experiment_name = 'experiment_14'

# %%
# %run ../../scripts/train.py --images_path {images_path} --train_annotations_path {train_annotations_path} --val_annotations_path {val_annotations_path}\
                            --batch_size {batch_size} --epochs {epochs} --patience {patience} --experiment_name {experiment_name} --use_normalization\
                            --lr {lr} --lr_scheduler {lr_scheduler} --use_weighted_loss --fine_tune --use_data_augmentation --crop_size {crop_size}
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 160MB/s]
# [INFO] Created new resnet50_dual model.
# [INFO] Created SummaryWriter, saving to: ../runs/resnet50_dual/experiment_11...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Ep: 0 | t_loss: 1.1081 | t_kappa: 0.0793 | t_f1: 0.3661 | t_auc: 0.5809 | t_final: 0.3421 | v_loss: 0.6201 | v_kappa: 0.1352 | v_f1: 0.3494 | v_auc: 0.5819 | v_final: 0.3555
# Validation loss decreased (inf --> 0.620127).  Saving model ...
# Ep: 1 | t_loss: 1.0230 | t_kappa: 0.1316 | t_f1: 0.4007 | t_auc: 0.6125 | t_final: 0.3816 | v_loss: 0.5627 | v_kappa: 0.1734 | v_f1: 0.3977 | v_auc: 0.6303 | v_final: 0.4005
# Validation loss decreased (0.620127 --> 0.562698).  Saving model ...
# Ep: 2 | t_loss: 0.9801 | t_kappa: 0.1632 | t_f1: 0.4167 | t_auc: 0.6324 | t_final: 0.4041 | v_loss: 0.6275 | v_kappa: 0.1884 | v_f1: 0.4115 | v_auc: 0.6275 | v_final: 0.4091
# EarlyStopping counter: 1 out of 20
# Ep: 3 | t_loss: 0.9162 | t_kappa: 0.1971 | t_f1: 0.4349 | t_auc: 0.6520 | t_final: 0.4280 | v_loss: 0.5732 | v_kappa: 0.2025 | v_f1: 0.4510 | v_auc: 0.6505 | v_final: 0.4347
# EarlyStopping counter: 2 out of 20
# Ep: 4 | t_loss: 0.8718 | t_kappa: 0.2328 | t_f1: 0.4617 | t_auc: 0.6747 | t_final: 0.4564 | v_loss: 0.5587 | v_kappa: 0.2390 | v_f1: 0.4462 | v_auc: 0.6610 | v_final: 0.4487
# Validation loss decreased (0.562698 --> 0.558711).  Saving model ...
# Ep: 5 | t_loss: 0.8578 | t_kappa: 0.2424 | t_f1: 0.4610 | t_auc: 0.6773 | t_final: 0.4602 | v_loss: 0.5552 | v_kappa: 0.2300 | v_f1: 0.4153 | v_auc: 0.6634 | v_final: 0.4362
# Validation loss decreased (0.558711 --> 0.555241).  Saving model ...
# Ep: 6 | t_loss: 0.8116 | t_kappa: 0.2653 | t_f1: 0.4759 | t_auc: 0.6963 | t_final: 0.4791 | v_loss: 0.4923 | v_kappa: 0.3340 | v_f1: 0.4698 | v_auc: 0.6887 | v_final: 0.4975
# Validation loss decreased (0.555241 --> 0.492330).  Saving model ...
# Ep: 7 | t_loss: 0.7819 | t_kappa: 0.2988 | t_f1: 0.4994 | t_auc: 0.7177 | t_final: 0.5053 | v_loss: 0.5087 | v_kappa: 0.2837 | v_f1: 0.4809 | v_auc: 0.6879 | v_final: 0.4841
# EarlyStopping counter: 1 out of 20
# Ep: 8 | t_loss: 0.7894 | t_kappa: 0.2829 | t_f1: 0.4804 | t_auc: 0.7078 | t_final: 0.4904 | v_loss: 0.4097 | v_kappa: 0.3330 | v_f1: 0.4945 | v_auc: 0.6988 | v_final: 0.5088
# Validation loss decreased (0.492330 --> 0.409679).  Saving model ...
# Ep: 9 | t_loss: 0.7676 | t_kappa: 0.3059 | t_f1: 0.5026 | t_auc: 0.7293 | t_final: 0.5126 | v_loss: 0.4946 | v_kappa: 0.3212 | v_f1: 0.4887 | v_auc: 0.7230 | v_final: 0.5110
# EarlyStopping counter: 1 out of 20
# Ep: 10 | t_loss: 0.7641 | t_kappa: 0.3146 | t_f1: 0.5054 | t_auc: 0.7238 | t_final: 0.5146 | v_loss: 0.4676 | v_kappa: 0.3684 | v_f1: 0.4989 | v_auc: 0.7179 | v_final: 0.5284
# EarlyStopping counter: 2 out of 20
# Ep: 11 | t_loss: 0.7361 | t_kappa: 0.3321 | t_f1: 0.5158 | t_auc: 0.7383 | t_final: 0.5287 | v_loss: 0.4781 | v_kappa: 0.3498 | v_f1: 0.4979 | v_auc: 0.7207 | v_final: 0.5228
# EarlyStopping counter: 3 out of 20
# Ep: 12 | t_loss: 0.7223 | t_kappa: 0.3399 | t_f1: 0.5165 | t_auc: 0.7323 | t_final: 0.5295 | v_loss: 0.4511 | v_kappa: 0.3745 | v_f1: 0.5290 | v_auc: 0.7301 | v_final: 0.5445
# EarlyStopping counter: 4 out of 20
# Ep: 13 | t_loss: 0.6890 | t_kappa: 0.3578 | t_f1: 0.5345 | t_auc: 0.7521 | t_final: 0.5481 | v_loss: 0.4212 | v_kappa: 0.3780 | v_f1: 0.5095 | v_auc: 0.7324 | v_final: 0.5400
# EarlyStopping counter: 5 out of 20
# Ep: 14 | t_loss: 0.6838 | t_kappa: 0.3625 | t_f1: 0.5314 | t_auc: 0.7532 | t_final: 0.5490 | v_loss: 0.4689 | v_kappa: 0.3190 | v_f1: 0.4814 | v_auc: 0.7313 | v_final: 0.5106
# EarlyStopping counter: 6 out of 20
# Ep: 15 | t_loss: 0.6640 | t_kappa: 0.3617 | t_f1: 0.5258 | t_auc: 0.7509 | t_final: 0.5461 | v_loss: 0.3935 | v_kappa: 0.4161 | v_f1: 0.5421 | v_auc: 0.7450 | v_final: 0.5677
# Validation loss decreased (0.409679 --> 0.393516).  Saving model ...
# Ep: 16 | t_loss: 0.6775 | t_kappa: 0.3570 | t_f1: 0.5339 | t_auc: 0.7552 | t_final: 0.5487 | v_loss: 0.5173 | v_kappa: 0.3142 | v_f1: 0.4983 | v_auc: 0.7390 | v_final: 0.5172
# EarlyStopping counter: 1 out of 20
# Ep: 17 | t_loss: 0.6534 | t_kappa: 0.3712 | t_f1: 0.5369 | t_auc: 0.7629 | t_final: 0.5570 | v_loss: 0.3888 | v_kappa: 0.4022 | v_f1: 0.5356 | v_auc: 0.7470 | v_final: 0.5616
# Validation loss decreased (0.393516 --> 0.388765).  Saving model ...
# Ep: 18 | t_loss: 0.6320 | t_kappa: 0.3963 | t_f1: 0.5474 | t_auc: 0.7666 | t_final: 0.5701 | v_loss: 0.4689 | v_kappa: 0.3645 | v_f1: 0.5208 | v_auc: 0.7417 | v_final: 0.5423
# EarlyStopping counter: 1 out of 20
# Ep: 19 | t_loss: 0.6229 | t_kappa: 0.4025 | t_f1: 0.5552 | t_auc: 0.7726 | t_final: 0.5767 | v_loss: 0.4218 | v_kappa: 0.3912 | v_f1: 0.5245 | v_auc: 0.7489 | v_final: 0.5549
# EarlyStopping counter: 2 out of 20
# Ep: 20 | t_loss: 0.6325 | t_kappa: 0.3869 | t_f1: 0.5399 | t_auc: 0.7666 | t_final: 0.5645 | v_loss: 0.3906 | v_kappa: 0.3967 | v_f1: 0.5262 | v_auc: 0.7489 | v_final: 0.5573
# EarlyStopping counter: 3 out of 20
# Ep: 21 | t_loss: 0.6142 | t_kappa: 0.4100 | t_f1: 0.5540 | t_auc: 0.7712 | t_final: 0.5784 | v_loss: 0.3942 | v_kappa: 0.3983 | v_f1: 0.5369 | v_auc: 0.7458 | v_final: 0.5603
# EarlyStopping counter: 4 out of 20
# Ep: 22 | t_loss: 0.6262 | t_kappa: 0.3980 | t_f1: 0.5529 | t_auc: 0.7756 | t_final: 0.5755 | v_loss: 0.3782 | v_kappa: 0.4222 | v_f1: 0.5465 | v_auc: 0.7530 | v_final: 0.5739
# Validation loss decreased (0.388765 --> 0.378205).  Saving model ...
# Ep: 23 | t_loss: 0.5997 | t_kappa: 0.4107 | t_f1: 0.5516 | t_auc: 0.7711 | t_final: 0.5778 | v_loss: 0.3821 | v_kappa: 0.3758 | v_f1: 0.5194 | v_auc: 0.7421 | v_final: 0.5458
# EarlyStopping counter: 1 out of 20
# Ep: 24 | t_loss: 0.5946 | t_kappa: 0.4118 | t_f1: 0.5627 | t_auc: 0.7859 | t_final: 0.5868 | v_loss: 0.4011 | v_kappa: 0.3944 | v_f1: 0.5350 | v_auc: 0.7485 | v_final: 0.5593
# EarlyStopping counter: 2 out of 20
# Ep: 25 | t_loss: 0.5749 | t_kappa: 0.4263 | t_f1: 0.5680 | t_auc: 0.7869 | t_final: 0.5938 | v_loss: 0.3838 | v_kappa: 0.3924 | v_f1: 0.5309 | v_auc: 0.7582 | v_final: 0.5605
# EarlyStopping counter: 3 out of 20
# Ep: 26 | t_loss: 0.5493 | t_kappa: 0.4446 | t_f1: 0.5712 | t_auc: 0.7876 | t_final: 0.6012 | v_loss: 0.3589 | v_kappa: 0.4459 | v_f1: 0.5517 | v_auc: 0.7623 | v_final: 0.5866
# Validation loss decreased (0.378205 --> 0.358881).  Saving model ...
# Ep: 27 | t_loss: 0.5311 | t_kappa: 0.4601 | t_f1: 0.5809 | t_auc: 0.7947 | t_final: 0.6119 | v_loss: 0.3693 | v_kappa: 0.4145 | v_f1: 0.5448 | v_auc: 0.7568 | v_final: 0.5720
# EarlyStopping counter: 1 out of 20
# Ep: 28 | t_loss: 0.5256 | t_kappa: 0.4584 | t_f1: 0.5798 | t_auc: 0.7985 | t_final: 0.6123 | v_loss: 0.3894 | v_kappa: 0.4297 | v_f1: 0.5468 | v_auc: 0.7704 | v_final: 0.5823
# EarlyStopping counter: 2 out of 20
# Ep: 29 | t_loss: 0.5142 | t_kappa: 0.4747 | t_f1: 0.5905 | t_auc: 0.8037 | t_final: 0.6230 | v_loss: 0.3492 | v_kappa: 0.4134 | v_f1: 0.5340 | v_auc: 0.7561 | v_final: 0.5678
# Validation loss decreased (0.358881 --> 0.349170).  Saving model ...
# Ep: 30 | t_loss: 0.5443 | t_kappa: 0.4524 | t_f1: 0.5837 | t_auc: 0.8029 | t_final: 0.6130 | v_loss: 0.4676 | v_kappa: 0.4198 | v_f1: 0.5399 | v_auc: 0.7619 | v_final: 0.5739
# EarlyStopping counter: 1 out of 20
# Ep: 31 | t_loss: 0.4988 | t_kappa: 0.4843 | t_f1: 0.5932 | t_auc: 0.8090 | t_final: 0.6288 | v_loss: 0.3669 | v_kappa: 0.4177 | v_f1: 0.5488 | v_auc: 0.7652 | v_final: 0.5772
# EarlyStopping counter: 2 out of 20
# Ep: 32 | t_loss: 0.4944 | t_kappa: 0.4854 | t_f1: 0.5963 | t_auc: 0.8147 | t_final: 0.6322 | v_loss: 0.3410 | v_kappa: 0.4266 | v_f1: 0.5462 | v_auc: 0.7669 | v_final: 0.5799
# Validation loss decreased (0.349170 --> 0.340974).  Saving model ...
# Ep: 33 | t_loss: 0.4848 | t_kappa: 0.4833 | t_f1: 0.5932 | t_auc: 0.8117 | t_final: 0.6294 | v_loss: 0.3651 | v_kappa: 0.4293 | v_f1: 0.5417 | v_auc: 0.7639 | v_final: 0.5783
# EarlyStopping counter: 1 out of 20
# Ep: 34 | t_loss: 0.4654 | t_kappa: 0.5165 | t_f1: 0.6127 | t_auc: 0.8222 | t_final: 0.6505 | v_loss: 0.3519 | v_kappa: 0.4439 | v_f1: 0.5445 | v_auc: 0.7659 | v_final: 0.5848
# EarlyStopping counter: 2 out of 20
# Ep: 35 | t_loss: 0.4620 | t_kappa: 0.5130 | t_f1: 0.6108 | t_auc: 0.8236 | t_final: 0.6491 | v_loss: 0.3383 | v_kappa: 0.4401 | v_f1: 0.5230 | v_auc: 0.7634 | v_final: 0.5755
# Validation loss decreased (0.340974 --> 0.338335).  Saving model ...
# Ep: 36 | t_loss: 0.4607 | t_kappa: 0.5174 | t_f1: 0.6153 | t_auc: 0.8224 | t_final: 0.6517 | v_loss: 0.3490 | v_kappa: 0.4467 | v_f1: 0.5515 | v_auc: 0.7680 | v_final: 0.5887
# EarlyStopping counter: 1 out of 20
# Ep: 37 | t_loss: 0.4436 | t_kappa: 0.5345 | t_f1: 0.6210 | t_auc: 0.8294 | t_final: 0.6616 | v_loss: 0.3351 | v_kappa: 0.4789 | v_f1: 0.5688 | v_auc: 0.7719 | v_final: 0.6065
# Validation loss decreased (0.338335 --> 0.335083).  Saving model ...
# Ep: 38 | t_loss: 0.4291 | t_kappa: 0.5465 | t_f1: 0.6286 | t_auc: 0.8345 | t_final: 0.6699 | v_loss: 0.3173 | v_kappa: 0.4932 | v_f1: 0.5700 | v_auc: 0.7706 | v_final: 0.6113
# Validation loss decreased (0.335083 --> 0.317275).  Saving model ...
# Ep: 39 | t_loss: 0.4257 | t_kappa: 0.5608 | t_f1: 0.6353 | t_auc: 0.8390 | t_final: 0.6784 | v_loss: 0.3415 | v_kappa: 0.4801 | v_f1: 0.5730 | v_auc: 0.7734 | v_final: 0.6088
# EarlyStopping counter: 1 out of 20
# Ep: 40 | t_loss: 0.4301 | t_kappa: 0.5372 | t_f1: 0.6294 | t_auc: 0.8398 | t_final: 0.6688 | v_loss: 0.3299 | v_kappa: 0.4857 | v_f1: 0.5737 | v_auc: 0.7770 | v_final: 0.6121
# EarlyStopping counter: 2 out of 20
# Ep: 41 | t_loss: 0.4082 | t_kappa: 0.5669 | t_f1: 0.6428 | t_auc: 0.8431 | t_final: 0.6843 | v_loss: 0.3151 | v_kappa: 0.4922 | v_f1: 0.5764 | v_auc: 0.7812 | v_final: 0.6166
# Validation loss decreased (0.317275 --> 0.315106).  Saving model ...
# Ep: 42 | t_loss: 0.3903 | t_kappa: 0.5939 | t_f1: 0.6576 | t_auc: 0.8526 | t_final: 0.7014 | v_loss: 0.3335 | v_kappa: 0.4746 | v_f1: 0.5583 | v_auc: 0.7763 | v_final: 0.6031
# EarlyStopping counter: 1 out of 20
# Ep: 43 | t_loss: 0.3801 | t_kappa: 0.6006 | t_f1: 0.6541 | t_auc: 0.8520 | t_final: 0.7022 | v_loss: 0.3259 | v_kappa: 0.4776 | v_f1: 0.5537 | v_auc: 0.7745 | v_final: 0.6019
# EarlyStopping counter: 2 out of 20
# Ep: 44 | t_loss: 0.3833 | t_kappa: 0.5914 | t_f1: 0.6470 | t_auc: 0.8495 | t_final: 0.6960 | v_loss: 0.3295 | v_kappa: 0.4745 | v_f1: 0.5669 | v_auc: 0.7818 | v_final: 0.6077
# EarlyStopping counter: 3 out of 20
# Ep: 45 | t_loss: 0.3813 | t_kappa: 0.5980 | t_f1: 0.6637 | t_auc: 0.8611 | t_final: 0.7076 | v_loss: 0.3303 | v_kappa: 0.4921 | v_f1: 0.5528 | v_auc: 0.7774 | v_final: 0.6075
# EarlyStopping counter: 4 out of 20
# Ep: 46 | t_loss: 0.3658 | t_kappa: 0.6158 | t_f1: 0.6683 | t_auc: 0.8649 | t_final: 0.7163 | v_loss: 0.3189 | v_kappa: 0.4957 | v_f1: 0.5754 | v_auc: 0.7858 | v_final: 0.6190
# EarlyStopping counter: 5 out of 20
# Ep: 47 | t_loss: 0.3511 | t_kappa: 0.6312 | t_f1: 0.6724 | t_auc: 0.8628 | t_final: 0.7221 | v_loss: 0.3169 | v_kappa: 0.5000 | v_f1: 0.5799 | v_auc: 0.7820 | v_final: 0.6206
# EarlyStopping counter: 6 out of 20
# Ep: 48 | t_loss: 0.3544 | t_kappa: 0.6305 | t_f1: 0.6786 | t_auc: 0.8670 | t_final: 0.7253 | v_loss: 0.3247 | v_kappa: 0.4904 | v_f1: 0.5713 | v_auc: 0.7785 | v_final: 0.6134
# EarlyStopping counter: 7 out of 20
# Ep: 49 | t_loss: 0.3374 | t_kappa: 0.6492 | t_f1: 0.6840 | t_auc: 0.8706 | t_final: 0.7346 | v_loss: 0.3129 | v_kappa: 0.5150 | v_f1: 0.5841 | v_auc: 0.7840 | v_final: 0.6277
# Validation loss decreased (0.315106 --> 0.312921).  Saving model ...
# Ep: 50 | t_loss: 0.3378 | t_kappa: 0.6608 | t_f1: 0.6883 | t_auc: 0.8731 | t_final: 0.7407 | v_loss: 0.3235 | v_kappa: 0.5093 | v_f1: 0.5830 | v_auc: 0.7840 | v_final: 0.6255
# EarlyStopping counter: 1 out of 20
# Ep: 51 | t_loss: 0.3453 | t_kappa: 0.6479 | t_f1: 0.6820 | t_auc: 0.8727 | t_final: 0.7342 | v_loss: 0.3061 | v_kappa: 0.5203 | v_f1: 0.5844 | v_auc: 0.7868 | v_final: 0.6305
# Validation loss decreased (0.312921 --> 0.306063).  Saving model ...
# Ep: 52 | t_loss: 0.3594 | t_kappa: 0.6570 | t_f1: 0.6926 | t_auc: 0.8753 | t_final: 0.7417 | v_loss: 0.3113 | v_kappa: 0.5087 | v_f1: 0.5756 | v_auc: 0.7841 | v_final: 0.6228
# EarlyStopping counter: 1 out of 20
# Ep: 53 | t_loss: 0.3472 | t_kappa: 0.6248 | t_f1: 0.6826 | t_auc: 0.8745 | t_final: 0.7273 | v_loss: 0.3127 | v_kappa: 0.5178 | v_f1: 0.5750 | v_auc: 0.7778 | v_final: 0.6235
# EarlyStopping counter: 2 out of 20
# Ep: 54 | t_loss: 0.3285 | t_kappa: 0.6587 | t_f1: 0.6918 | t_auc: 0.8764 | t_final: 0.7423 | v_loss: 0.3103 | v_kappa: 0.5207 | v_f1: 0.5814 | v_auc: 0.7837 | v_final: 0.6286
# EarlyStopping counter: 3 out of 20
# Ep: 55 | t_loss: 0.3234 | t_kappa: 0.6741 | t_f1: 0.6971 | t_auc: 0.8788 | t_final: 0.7500 | v_loss: 0.3253 | v_kappa: 0.5076 | v_f1: 0.5768 | v_auc: 0.7845 | v_final: 0.6230
# EarlyStopping counter: 4 out of 20
# Ep: 56 | t_loss: 0.3183 | t_kappa: 0.6740 | t_f1: 0.7010 | t_auc: 0.8837 | t_final: 0.7529 | v_loss: 0.3103 | v_kappa: 0.5258 | v_f1: 0.5846 | v_auc: 0.7866 | v_final: 0.6324
# EarlyStopping counter: 5 out of 20
# Ep: 57 | t_loss: 0.3053 | t_kappa: 0.6926 | t_f1: 0.7097 | t_auc: 0.8875 | t_final: 0.7633 | v_loss: 0.3117 | v_kappa: 0.5179 | v_f1: 0.5845 | v_auc: 0.7865 | v_final: 0.6296
# EarlyStopping counter: 6 out of 20
# Ep: 58 | t_loss: 0.3133 | t_kappa: 0.6753 | t_f1: 0.7000 | t_auc: 0.8843 | t_final: 0.7532 | v_loss: 0.3242 | v_kappa: 0.5364 | v_f1: 0.5936 | v_auc: 0.7849 | v_final: 0.6383
# EarlyStopping counter: 7 out of 20
# Ep: 59 | t_loss: 0.3088 | t_kappa: 0.6855 | t_f1: 0.7081 | t_auc: 0.8870 | t_final: 0.7602 | v_loss: 0.3097 | v_kappa: 0.5368 | v_f1: 0.5870 | v_auc: 0.7899 | v_final: 0.6379
# EarlyStopping counter: 8 out of 20
# Ep: 60 | t_loss: 0.3014 | t_kappa: 0.6938 | t_f1: 0.7140 | t_auc: 0.8905 | t_final: 0.7661 | v_loss: 0.3130 | v_kappa: 0.5124 | v_f1: 0.5809 | v_auc: 0.7850 | v_final: 0.6261
# EarlyStopping counter: 9 out of 20
# Ep: 61 | t_loss: 0.3088 | t_kappa: 0.6905 | t_f1: 0.7113 | t_auc: 0.8910 | t_final: 0.7643 | v_loss: 0.3127 | v_kappa: 0.5267 | v_f1: 0.5887 | v_auc: 0.7865 | v_final: 0.6340
# EarlyStopping counter: 10 out of 20
# Ep: 62 | t_loss: 0.2989 | t_kappa: 0.7011 | t_f1: 0.7159 | t_auc: 0.8929 | t_final: 0.7700 | v_loss: 0.3066 | v_kappa: 0.5296 | v_f1: 0.5855 | v_auc: 0.7880 | v_final: 0.6344
# EarlyStopping counter: 11 out of 20
# Ep: 63 | t_loss: 0.2944 | t_kappa: 0.6971 | t_f1: 0.7130 | t_auc: 0.8902 | t_final: 0.7668 | v_loss: 0.3035 | v_kappa: 0.5191 | v_f1: 0.5845 | v_auc: 0.7906 | v_final: 0.6314
# Validation loss decreased (0.306063 --> 0.303543).  Saving model ...
# Ep: 64 | t_loss: 0.2896 | t_kappa: 0.7048 | t_f1: 0.7186 | t_auc: 0.8973 | t_final: 0.7736 | v_loss: 0.3186 | v_kappa: 0.5253 | v_f1: 0.5949 | v_auc: 0.7875 | v_final: 0.6359
# EarlyStopping counter: 1 out of 20
# Ep: 65 | t_loss: 0.2917 | t_kappa: 0.7053 | t_f1: 0.7240 | t_auc: 0.8999 | t_final: 0.7764 | v_loss: 0.3150 | v_kappa: 0.5260 | v_f1: 0.5785 | v_auc: 0.7855 | v_final: 0.6300
# EarlyStopping counter: 2 out of 20
# Ep: 66 | t_loss: 0.2947 | t_kappa: 0.7072 | t_f1: 0.7248 | t_auc: 0.9014 | t_final: 0.7778 | v_loss: 0.3189 | v_kappa: 0.5252 | v_f1: 0.5874 | v_auc: 0.7836 | v_final: 0.6321
# EarlyStopping counter: 3 out of 20
# Ep: 67 | t_loss: 0.2988 | t_kappa: 0.6972 | t_f1: 0.7162 | t_auc: 0.8954 | t_final: 0.7696 | v_loss: 0.3171 | v_kappa: 0.5253 | v_f1: 0.5841 | v_auc: 0.7800 | v_final: 0.6298
# EarlyStopping counter: 4 out of 20
# Ep: 68 | t_loss: 0.2909 | t_kappa: 0.7046 | t_f1: 0.7178 | t_auc: 0.8971 | t_final: 0.7732 | v_loss: 0.3115 | v_kappa: 0.5246 | v_f1: 0.5902 | v_auc: 0.7844 | v_final: 0.6331
# EarlyStopping counter: 5 out of 20
# Ep: 69 | t_loss: 0.2942 | t_kappa: 0.7007 | t_f1: 0.7203 | t_auc: 0.8976 | t_final: 0.7729 | v_loss: 0.3134 | v_kappa: 0.5224 | v_f1: 0.5833 | v_auc: 0.7837 | v_final: 0.6298
# EarlyStopping counter: 6 out of 20
# Ep: 70 | t_loss: 0.2921 | t_kappa: 0.7126 | t_f1: 0.7288 | t_auc: 0.9024 | t_final: 0.7813 | v_loss: 0.3153 | v_kappa: 0.5240 | v_f1: 0.5920 | v_auc: 0.7888 | v_final: 0.6349
# EarlyStopping counter: 7 out of 20
# Ep: 71 | t_loss: 0.2727 | t_kappa: 0.7259 | t_f1: 0.7370 | t_auc: 0.9060 | t_final: 0.7896 | v_loss: 0.3067 | v_kappa: 0.5404 | v_f1: 0.5960 | v_auc: 0.7880 | v_final: 0.6414
# EarlyStopping counter: 8 out of 20
# Ep: 72 | t_loss: 0.2721 | t_kappa: 0.7311 | t_f1: 0.7389 | t_auc: 0.9073 | t_final: 0.7925 | v_loss: 0.3170 | v_kappa: 0.5445 | v_f1: 0.6019 | v_auc: 0.7869 | v_final: 0.6444
# EarlyStopping counter: 9 out of 20
# Ep: 73 | t_loss: 0.2638 | t_kappa: 0.7353 | t_f1: 0.7401 | t_auc: 0.9102 | t_final: 0.7952 | v_loss: 0.3170 | v_kappa: 0.5360 | v_f1: 0.5891 | v_auc: 0.7842 | v_final: 0.6364
# EarlyStopping counter: 10 out of 20
# Ep: 74 | t_loss: 0.2850 | t_kappa: 0.7147 | t_f1: 0.7390 | t_auc: 0.9122 | t_final: 0.7886 | v_loss: 0.3162 | v_kappa: 0.5223 | v_f1: 0.5853 | v_auc: 0.7857 | v_final: 0.6311
# EarlyStopping counter: 11 out of 20
# Ep: 75 | t_loss: 0.2688 | t_kappa: 0.7339 | t_f1: 0.7463 | t_auc: 0.9133 | t_final: 0.7979 | v_loss: 0.3223 | v_kappa: 0.5279 | v_f1: 0.5948 | v_auc: 0.7871 | v_final: 0.6366
# EarlyStopping counter: 12 out of 20
# Ep: 76 | t_loss: 0.2606 | t_kappa: 0.7441 | t_f1: 0.7484 | t_auc: 0.9144 | t_final: 0.8023 | v_loss: 0.3180 | v_kappa: 0.5279 | v_f1: 0.5790 | v_auc: 0.7823 | v_final: 0.6297
# EarlyStopping counter: 13 out of 20
# Ep: 77 | t_loss: 0.2577 | t_kappa: 0.7486 | t_f1: 0.7570 | t_auc: 0.9218 | t_final: 0.8092 | v_loss: 0.3157 | v_kappa: 0.5312 | v_f1: 0.5839 | v_auc: 0.7854 | v_final: 0.6335
# EarlyStopping counter: 14 out of 20
# Ep: 78 | t_loss: 0.2560 | t_kappa: 0.7479 | t_f1: 0.7525 | t_auc: 0.9169 | t_final: 0.8058 | v_loss: 0.3234 | v_kappa: 0.5371 | v_f1: 0.5983 | v_auc: 0.7885 | v_final: 0.6413
# EarlyStopping counter: 15 out of 20
# Ep: 79 | t_loss: 0.2841 | t_kappa: 0.7337 | t_f1: 0.7541 | t_auc: 0.9203 | t_final: 0.8027 | v_loss: 0.3322 | v_kappa: 0.5348 | v_f1: 0.5849 | v_auc: 0.7829 | v_final: 0.6342
# EarlyStopping counter: 16 out of 20
# Ep: 80 | t_loss: 0.3506 | t_kappa: 0.6521 | t_f1: 0.7082 | t_auc: 0.8919 | t_final: 0.7507 | v_loss: 0.3219 | v_kappa: 0.5196 | v_f1: 0.5826 | v_auc: 0.7796 | v_final: 0.6273
# EarlyStopping counter: 17 out of 20
# Ep: 81 | t_loss: 0.2922 | t_kappa: 0.6967 | t_f1: 0.7328 | t_auc: 0.9067 | t_final: 0.7787 | v_loss: 0.3172 | v_kappa: 0.5244 | v_f1: 0.5834 | v_auc: 0.7795 | v_final: 0.6291
# EarlyStopping counter: 18 out of 20
# Ep: 82 | t_loss: 0.3033 | t_kappa: 0.6885 | t_f1: 0.7271 | t_auc: 0.9054 | t_final: 0.7737 | v_loss: 0.3149 | v_kappa: 0.5262 | v_f1: 0.5747 | v_auc: 0.7752 | v_final: 0.6253
# EarlyStopping counter: 19 out of 20
# Ep: 83 | t_loss: 0.2700 | t_kappa: 0.7157 | t_f1: 0.7438 | t_auc: 0.9172 | t_final: 0.7923 | v_loss: 0.3144 | v_kappa: 0.5216 | v_f1: 0.5773 | v_auc: 0.7780 | v_final: 0.6257
# EarlyStopping counter: 20 out of 20
# Early stopping

# %% [markdown]
# Run the next cell to see the metrics trough the epochs using the tensorboard interface

# %%
# %reload_ext tensorboard
# %tensorboard --logdir ../runs

# %% [markdown]
# # Test the model with the validation dataset
# Since there is no access to the test annotatations (only to the images) the test will be performed on the validation dataset, to be able to see some results.

# %%
# %run ../../scripts/test.py -h # Run this line to check the test script arguments
# Out:
# usage: test.py [-h] [--model_name MODEL_NAME] [--model_path MODEL_PATH]
#                [--images_path IMAGES_PATH] [--crop_size CROP_SIZE]
#                [--test_annotations_path TEST_ANNOTATIONS_PATH]
#                [--use_normalization] [--batch_size BATCH_SIZE]
#                [--num_workers NUM_WORKERS]
#                [--ground_truth_path GROUND_TRUTH_PATH]
#                [--probs_path PROBS_PATH]
#
# Test a model with a dataset.
#
# options:
#   -h, --help            show this help message and exit
#   --model_name MODEL_NAME
#                         Model arquitecture for testing (default:
#                         resnet50_dual).
#   --model_path MODEL_PATH
#                         Path to the model to test the dataset with (default:
#                         outputs/resnet50_dual_experiment_0_model.pth).
#   --images_path IMAGES_PATH
#                         Path of test images (default:
#                         ../../data/train_fov_cc_fov_224/).
#   --crop_size CROP_SIZE
#                         Crop size used for center cropping the test images
#                         (default: 224)
#   --test_annotations_path TEST_ANNOTATIONS_PATH
#                         Path of test annotations file (default:
#                         data/test_annotations.xlsx).
#   --use_normalization   If set the images are normalized the same way the
#                         imagenet images were normalized to train the resnet50
#                         used here.
#   --batch_size BATCH_SIZE
#                         Batch size for data loaders (default: 32).
#   --num_workers NUM_WORKERS
#                         Number of workers for data loaders (default:
#                         os.cpu_count()).
#   --ground_truth_path GROUND_TRUTH_PATH
#                         Path to store the ground truth labels used in test
#                         (default: None).
#   --probs_path PROBS_PATH
#                         Path to store the result probs of test (default:
#                         None).

# %%
test_annotations_path = 'data/val_annotations.xlsx' # val annotations are used for test
images_path = '../../data/images/train_fov_cc_fov_224'
model_path = 'outputs/resnet50_dual_experiment_14_model.pth'
ground_truth_path = 'outputs/ground_truth.xlsx'
probs_path = 'outputs/probs.xlsx'

crop_size = 196

# %%
# %run ../../scripts/test.py --model_path {model_path} --images_path {images_path} --test_annotations_path {test_annotations_path} --use_normalization\
                           --ground_truth_path {ground_truth_path} --probs_path {probs_path} --crop_size {crop_size} --num_workers 0
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 181MB/s]
# [INFO] Created new resnet50_dual model.
# test_loss: 0.3035 | test_kappa: 0.5191 | test_f1: 0.5845 | test_auc: 0.7906 | test_final: 0.6314

# %% [markdown]
# # Run the ODIR_evaluation.py script on test (validation) dataset
# This is a file provided along with the data by the challenge. And its supposed to have an example on how to compute the kappa, f1, auc, and final score metrics but i dont think they are well computed here as they are always too good (as shown later, the cualitative results for test are much worst). As a result of this, i use my own version of this metrics (see the function compute_challenge_metrics on the metrics script). Either way i'll run it.

# %%
ground_truth_path = 'outputs/ground_truth.xlsx'
probs_path = 'outputs/probs.xlsx'
probs_csv_path = 'outputs/probs.csv'

probs_df = pd.read_excel(probs_path)
probs_df.to_csv(probs_csv_path, index=False) # The ODIR_evaluation script asks the probs file to be in .csv format

# %run ../../scripts/ODIR_evaluation.py {ground_truth_path} {probs_csv_path}
# Out:
# kappa score: 0.5026600798023941  f-1 score: 0.8603151862464185  AUC vlaue: 0.9084829077261973  Final Score: 0.7571527245916699

# %% [markdown]
# # Cuantitative results
# The test script prints some results as can be seen in the output of the previous cell. Now, lets see some more.

# %%
label_names = ['N','D','G','C','A','H','M','O']

ground_truth = pd.read_excel(ground_truth_path).loc[:, label_names].to_numpy()
probs = pd.read_excel(probs_path).loc[:, label_names].to_numpy()

# %%
from sklearn import metrics
os.chdir('../../scripts')
from metrics import plot_confusion_matrices
os.chdir('../experiments/experiment_14/')

# Print test classification report
print('Clasification report:')
print(
    metrics.classification_report(
        ground_truth,
        probs>0.5,
        output_dict=False,
        target_names=label_names,
        zero_division=0
    )
)

# Plot one confusion matrix for each label
plot_confusion_matrices(ground_truth, probs, label_names)
# Out:
# Clasification report:
#               precision    recall  f1-score   support
#
#            N       0.50      0.75      0.60       214
#            D       0.54      0.70      0.61       226
#            G       0.41      0.53      0.46        34
#            C       0.76      0.92      0.83        37
#            A       0.66      0.73      0.69        37
#            H       0.34      0.45      0.39        29
#            M       0.85      0.93      0.89        30
#            O       0.47      0.52      0.49       217
#
#    micro avg       0.52      0.67      0.59       824
#    macro avg       0.56      0.69      0.62       824
# weighted avg       0.52      0.67      0.58       824
#  samples avg       0.55      0.69      0.58       824

# %% [markdown]
# # Cualitative results
# One patient with each disease (at least) is predicted. The original images are ploted along with their ground truth and predicted labels.

# %%
import torch
from torchvision import transforms
os.chdir('../../scripts')
from utils import load_model
from transforms import ToTensorDual, NormalizeDual, CenterCropDual
from predict import pred_and_plot_image
os.chdir('../experiments/experiment_14/')

# %%
model = load_model(model_path)

test_df = pd.read_excel(test_annotations_path)

transform = transforms.Compose([
    CenterCropDual(size=crop_size),
    ToTensorDual(),
    NormalizeDual(mean=[0.485, 0.456, 0.406],
                    std=[0.229, 0.224, 0.225])
])

device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# [INFO] Created new resnet50_dual model.

# %% [markdown]
# You can run the next cell multiple times to see different results

# %%
label_names = ['N','D','G','C','A','H','M','O']


for label in label_names:
    patient = test_df[test_df[label] == 1].sample(replace=True).reset_index(drop=True)
    pred_and_plot_image(model=model,
                        left_image_path=f'{images_path}/{patient.at[0, "Left-Fundus"]}',
                        right_image_path=f'{images_path}/{patient.at[0, "Right-Fundus"]}',
                        transform=transform,
                        device=device,
                        label_names=label_names,
                        ground_truth=patient.loc[0, label_names].to_numpy())

# %% [markdown]
# # Zip the experiment data folder, the SummaryWriter folder and the experiment outputs
# This is necessary in order to be able to download this folders

# %%
# import shutil

# shutil.make_archive('experiment_data_compressed',
#                     format="zip",
#                     root_dir='data/')

# shutil.make_archive('runs_compressed',
#                     format="zip",
#                     root_dir='../runs/')

# shutil.make_archive('outputs_compressed',
#                     format="zip",
#                     root_dir='outputs/')
# Out:
# '/content/ODIR-5K-multi-label-classification/experiments/experiment_11/outputs_compressed.zip'
